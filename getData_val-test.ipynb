# %%
#把数据处理成transX输入的格式
import pandas as pd
data=pd.read_excel(r'/workspace/ysn_proj_0409/root/autodl-tmp/transX/val_test.xlsx')
data.head()
# Out:
#    index                                                 PN  \
# 0  52313  WO2010113298-A1; TW201038479-A; JP2011506915-X...
# 1  15770                                      CN208385378-U
# 2  49557  US2013269772-A1; EP2654086-A1; KR2013117344-A;...
# 3  49283                   WO2015013207-A1; US2015056488-A1
# 4    630  DE102019111559-A1; CN110556521-A; US2019372108...
#
#                                                   TI  \
# 0  Gas phase reaction apparatus used for manufact...
# 1  Silicon wafer turning mechanism of silicon sol...
# 2  Inorganic reaction system used in electrocondu...
# 3  Energy storage device e.g. battery, comprises ...
# 4  Producing silicon anode material for          ...
#
#                                                   AB  \
# 0  NOVELTY - The apparatus (10) has a reaction co...
# 1  NOVELTY - The utility model claims a silicon s...
# 2  NOVELTY - Inorganic reaction system comprises ...
# 3  NOVELTY - An energy storage device comprises a...
# 4  NOVELTY - Producing a silicon anode material f...
#
#                                                   AU  \
# 0  TERAUCHI K;NAKAMOTO J;YOSHIZAWA S;MATSUOTO K;K...
# 1                                        PAN J;DAI Q
# 2  HOERTEIS M;WANG L;ZHANG W;HORTHEIS M;GUO C;YAN...
# 3          ZHANG J;XU W;WANG J;CHEN X;ZHANG Y;QIAN J
# 4                                   QI G;LI W;XIAO X
#
#                                                   AE  \
# 0  DENKI KAGAKU KOGYO KK (ELED-C);DENKI KAGAKU KO...
# 1  SUZHOU YINGZHEN INTELLIGENT TECHNOLOGY (SUZH-N...
# 2  HERAEUS PRECIOUS METALS NORTH AMERICA (HERA-C)...
# 3  BATTELLE MEMORIAL INST (BATT-C);BATTELLE MEMOR...
# 4  GM GLOBAL TECHNOLOGY OPERATIONS INC (GENK-C);G...
#
#                                                   CP    TM  \
# 0  WO2010113298-A1:JP62123011-A   KOJUNDO SILICON...  2010
# 1                                                NaN  2019
# 2  US2013269772-A1:JP08097011-A--[EOL]--US2011023...  2013
# 3  WO2015013207-A1:US20040058232-A1--[EOL]--US200...  2015
# 4     CN110556521-A:CN104051714-A   GM GLOBAL TEC...  2019
#
#                                                  IPC  \
# 0             B01J-012/00; C01B-033/107; C01B-007/01
# 1                          H01L-021/677; H01L-031/18
# 2  H01L-031/0224; H01B-001/16; B01J-019/24; C01B-...
# 3  H01M-010/052; H01M-010/0565; H01M-004/13; H01M...
# 4  H01G-011/50; H01G-011/86; H01M-010/052; H01M-0...
#
#                                              IPClass           class1  \
# 0   ['B01J-012/00', ' C01B-033/107', ' C01B-007/01']       ['B', 'C']
# 1                   ['H01L-021/677', ' H01L-031/18']            ['H']
# 2  ['H01L-031/0224', ' H01B-001/16', ' B01J-019/2...  ['H', 'C', 'B']
# 3  ['H01M-010/052', ' H01M-010/0565', ' H01M-004/...            ['H']
# 4  ['H01G-011/50', ' H01G-011/86', ' H01M-010/052...       ['H', 'C']
#
#                                        class3  \
# 0                              ['C01', 'B01']
# 1                                     ['H01']
# 2  ['H01', 'C01', 'H05', 'C09', 'B01', 'C03']
# 3                                     ['H01']
# 4                              ['C01', 'H01']
#
#                                               class4          newClass
# 0                                   ['C01B', 'B01J']          ['C01B']
# 1                                           ['H01L']          ['H01L']
# 2  ['C01G', 'C01B', 'B01J', 'H05K', 'C09D', 'H01L...  ['C01B', 'H01L']
# 3                                           ['H01M']          ['H01M']
# 4                           ['H01M', 'H01G', 'C01B']  ['H01M', 'C01B']

# %%
CP=data['CP']

cp_list=[]
for cp in CP:
    if pd.isna(cp): #是否是缺失值NAN
        cp_list.append([])
        continue
    else:
        List1=cp.split('**[EOP]**')
        #print(List1)
        List1=[l[l.index(':')+1:] for l in List1]#对 List1 中的每个元素，从第一个冒号 ':' 的位置开始截取子字符串，去除冒号及之前的部分
        List2=[i.split('--[EOL]--') for i in List1]
        List=[j for i in List2 for j in i] #将二维列表 List2 扁平化为一维列表 List
        List=[i for i in List if i!='']
        List=[i.split()[0] for i in List]
        
        List=list(set(List))
        cp_list.append(List)

# %%
#看一下cp_list里的每个元素，找pn_list的对应的元素
from tqdm import tqdm #导入了 tqdm 库，用于在循环中显示进度条，提供了对处理进度的可视化

for i in tqdm(range(len(cp_list))):
    for j in range(len(cp_list[i])):
        for pn in data['PN']:
            if cp_list[i][j] in pn:
                cp_list[i][j]=pn
# Out:
# 100%|██████████| 256/256 [00:00<00:00, 789.20it/s]

# %%
cp_list
# Out:
# [['JP62123011-A',
#   'JP87123011-A',
#   'JP2008137885-A',
#   'JP58155343-U',
#   'JP83155343-U'],
#  [],
#  ['EP1713093-B1',
#   'CN102117844-A',
#   'WO2011060341-A1',
#   'EP2317523-A1',
#   'CN101630695-A',
#   'JP05128910-A',
#   'US8889980-B2',
#   'US4945071-A',
#   'EP1713092-A2',
#   'US7736546-B2',
#   'CN101271928-A',
#   'US20110232746-A1',
#   'US20110308597-A1',
#   'US20130228207-A1',
#   'JP2008251324-A',
#   'US5066621-A',
#   'US20120031484-A1',
#   'JP2011082211-A',
#   'US8952245-B2',
#   'US6071437-A',
#   'JP08097011-A',
#   'WO1992000925-A',
#   'US20110192457-A1',
#   'US7935279-B2',
#   'US20110308595-A1',
#   'EP2317561-A2'],
#  ['US20050147883-A1',
#   'US20120214048-A1',
#   'US20040058232-A1',
#   'US20080241685-A1',
#   'US20070003838-A1',
#   'US20090104523-A1',
#   'US20090212743-A1',
#   'US5418091-A',
#   'US20050175894-A1'],
#  ['US20170338490-A1',
#   'US8679680-B2',
#   'US20080044735-A1',
#   'US8642201-B2',
#   'US9012075-B2',
#   'US10326136-B2',
#   'US9379374-B2',
#   'US10141569-B2',
#   'US20130323595-A1',
#   'US20190372114-A1',
#   'CN106848264-A',
#   'CN104051714-A',
#   'US9153353-B2',
#   'US9570752-B2',
#   'US10424784-B2',
#   'US9153819-B2',
#   'US8092922-B2',
#   'US20170352878-A1',
#   'US20130330619-A1',
#   'US8859144-B2',
#   'US20180205114-A1',
#   'US8999584-B2',
#   'US10062898-B2',
#   'US20120077087-A1',
#   'US20100297502-A1',
#   'US20130099159-A1',
#   'US20060127773-A1',
#   'US20170117538-A1',
#   'CN106558687-A',
#   'US20120229096-A1',
#   'US8440350-B1',
#   'CN108023066-A',
#   'US8828481-B2',
#   'US8101152-B1',
#   'US9577251-B2',
#   'US20160172665-A1',
#   'US9583767-B2',
#   'US20090087731-A1',
#   'US8658295-B2',
#   'US20020009639-A1',
#   'US9142830-B2',
#   'US20120328927-A1',
#   'CN104466185-A',
#   'US9356281-B2',
#   'US20110073804-A1',
#   'KR2014135422-A',
#   'US9362552-B2',
#   'US9859554-B2',
#   'DE102017124894-A1',
#   'US9564639-B2',
#   'US20180123124-A1',
#   'CN104269559-A',
#   'US10199643-B2',
#   'US20170141382-A1',
#   'US20170098817-A1',
#   'US9531004-B2',
#   'US7736805-B2',
#   'US9059451-B2',
#   'WO2012064702-A2',
#   'US20150162602-A1',
#   'US8835056-B2',
#   'US9362551-B2',
#   'US9302914-B2',
#   'US9005811-B2',
#   'US20160285090-A1',
#   'CN103779546-A',
#   'US20170271678-A1',
#   'US7718156-B2',
#   'US8399138-B2',
#   'US9093705-B2',
#   'US9034519-B2',
#   'US9780361-B2',
#   'US20090208780-A1',
#   'US8420259-B2',
#   'US20120100403-A1',
#   'US10164245-B2'],
#  ['US6525962-B1',
#   'US5146426-A',
#   'US6479863-B2',
#   'US7074672-B2',
#   'US5714766-A',
#   'US4462090-A',
#   'US7149118-B2',
#   'US6621107-B2',
#   'US5029130-A',
#   'US6745370-B1',
#   'US6953970-B2',
#   'US6469343-B1',
#   'US6211562-B1',
#   'US6449189-B2',
#   'US6882572-B2',
#   'US5563083-A',
#   'US5286994-A',
#   'US5847427-A',
#   'US6303940-B1',
#   'US6534816-B1',
#   'US6791883-B2',
#   'US6080995-A',
#   'US7297634-B2',
#   'US6790727-B2',
#   'US5559735-A',
#   'US5838039-A',
#   'US6709928-B1',
#   'US5557122-A',
#   'US5429965-A',
#   'US20020179958-A1',
#   'US6774433-B2',
#   'US6952033-B2',
#   'US5790455-A',
#   'US5847996-A',
#   'US3944849-A',
#   'US5621738-A',
#   'US7259984-B2',
#   'US5768192-A',
#   'US7018897-B2',
#   'US7115942-B2',
#   'US7274068-B2',
#   'US6756633-B2',
#   'US6580642-B1',
#   'US5095344-A',
#   'US6727545-B2',
#   'US20050167734-A1',
#   'US6873006-B2',
#   'US6566706-B1',
#   'US5792670-A',
#   'US5517044-A',
#   'US6531731-B2',
#   'US6388922-B1',
#   'US6952032-B2',
#   'US6091104-A',
#   'US5161157-A',
#   'US6894343-B2',
#   'US6721205-B2',
#   'US6580124-B1',
#   'US3943543-A',
#   'US20040160824-A1',
#   'US20010029077-A1',
#   'US5070480-A',
#   'US6734105-B2',
#   'US6002152-A',
#   'US5973356-A',
#   'US6593624-B2',
#   'US5822242-A',
#   'US5235544-A',
#   'US6897514-B2',
#   'US6743674-B2',
#   'US7015102-B2',
#   'US5432739-A',
#   'US5268319-A',
#   'US5115289-A',
#   'US5739567-A',
#   'US6103573-A',
#   'US5426316-A',
#   'US5966329-A',
#   'US6747310-B2',
#   'US6894339-B2',
#   'US6407424-B2',
#   'US6368915-B1',
#   'US6680505-B2',
#   'US7411244-B2',
#   'US5153880-A',
#   'US5270980-A',
#   'US6958513-B2',
#   'US4957877-A',
#   'US5883409-A',
#   'US6201732-B1',
#   'US6104057-A',
#   'US6451652-B1',
#   'US6815764-B2',
#   'US6503785-B2',
#   'US6861698-B2',
#   'US7307308-B2',
#   'US5523243-A',
#   'US7550800-B2',
#   'US4698787-A',
#   'US6372617-B1',
#   'US5053839-A',
#   'US6088263-A',
#   'US6847556-B2',
#   'US5280446-A',
#   'US6525371-B2',
#   'US5764096-A',
#   'US6411545-B1',
#   'US7075823-B2',
#   'US6744111-B1',
#   'US6426896-B1',
#   'US6936884-B2',
#   'US6313487-B1',
#   'US6753568-B1',
#   'US7190018-B2',
#   'US6555865-B2',
#   'US6936887-B2',
#   'US6574140-B2',
#   'US20060284236-A1',
#   'US4072977-A',
#   'US5780341-A',
#   'US20040214396-A1',
#   'US6384451-B1',
#   'US6853583-B2',
#   'US20040021170-A1'],
#  ['US7846790-B2',
#   'US20020135027-A1',
#   'US6870231-B2',
#   'JP2004311947-A',
#   'US20100093145-A1',
#   'US20090026520-A1',
#   'JP2004273642-A',
#   'US6642105-B2',
#   'US20080042218-A1',
#   'US20060228860-A1',
#   'US7768128-B2',
#   'US7994582-B2',
#   'JP2005123243-A',
#   'US20040212019-A1',
#   'US6118158-A',
#   'US6720628-B2',
#   'US20040004257-A1',
#   'US8013373-B2',
#   'US6169313-B1',
#   'US6933578-B2',
#   'US6127704-A',
#   'US6555868-B2',
#   'US7663193-B2',
#   'US6232631-B1',
#   'US8063425-B2',
#   'JP2005072185-A',
#   'US20070187721-A1',
#   'US7504295-B2',
#   'US5610419-A',
#   'US6339240-B1',
#   'JP2003203993-A',
#   'US20060006474-A1',
#   'US20070176214-A1',
#   'US20070080423-A1',
#   'JP2001196472-A',
#   'JP2005191454-A',
#   'US20070035028-A1',
#   'US20080099856-A1',
#   'US7119389-B2',
#   'JP2001028401-A',
#   'JP2003273249-A',
#   'US20020009846-A1',
#   'JP2003197768-A',
#   'US20070026603-A1',
#   'US7439153-B2',
#   'WO2002061840-A1',
#   'JP10178110-A'],
#  [],
#  ['US6486041-B2',
#   'WO2009084309-A1',
#   'US20090232981-A1',
#   'US5877070-A',
#   'US20040166651-A1',
#   'US7056808-B2',
#   'US6368938-B1',
#   'US4522657-A',
#   'US6809044-B1',
#   'WO2004008514-A1',
#   'US6033974-A',
#   'US5374564-A',
#   'US4447272-A',
#   'US6537606-B2',
#   'EP1806769-A1',
#   'US6806171-B1',
#   'EP961312-A2',
#   'US7459025-B2',
#   'US20080064182-A1',
#   'US6486008-B1',
#   'US6352909-B1',
#   'US6500732-B1',
#   'US6284631-B1',
#   'US6790747-B2',
#   'US20100207212-A1',
#   'US6346459-B1'],
#  ['CN104167454',
#   'US20150333197-A1',
#   'CN205564774-U',
#   'CN104867535-B',
#   'US20110120531-A1',
#   'US20170306172-A1',
#   'WO2012135551-A1',
#   'US20150280641-A1',
#   'CN104599741-A',
#   'US20100308462-A1',
#   'US20130340815-A1',
#   'CN104103699-A',
#   'US20120017986-A1',
#   'US20120015472-A1',
#   'KR1377555-B1',
#   'CN102779575-A',
#   'US20150364622-A1',
#   'CN104916346-A',
#   'US20130341769-A1',
#   'US20120122272-A1',
#   'US20130118572-A1',
#   'WO2016194882-A1',
#   'US20150243807-A1',
#   'CN104143385-A',
#   'US9209323-B2',
#   'KR2002060926-A',
#   'US20110308597-A1',
#   'US9834470-B1',
#   'US20150129030-A1',
#   'US10079318-B2',
#   'US20160251531-A1',
#   'US20170087633-A1',
#   'US20160170192-A1',
#   'CN101948639-B',
#   'US20090032087-A1',
#   'CN104240793-A',
#   'CN104981911-A',
#   'US20140070148-A1',
#   'CN102290120-B',
#   'US20120000502-A1',
#   'US20130126797-A1',
#   'US20140299187-A1',
#   'US8952245-B2',
#   'US20150249167-A1',
#   'CN102592708-B',
#   'US7300606-B2',
#   'CN104036842-B',
#   'CN106297956-A',
#   'US20150280024-A1',
#   'US20110315217-A1',
#   'US20150144183-A1',
#   'CN104282357-B',
#   'CN106158068-A',
#   'US20140373898-A1',
#   'US20140338747-A1',
#   'US20130255770-A1',
#   'US20140124014-A1',
#   'CN105261669-A',
#   'CN104021836-A',
#   'US8093491-B2',
#   'JP2013074165-A',
#   'CN103597547-A',
#   'US20140141164-A1',
#   'CN104681648-B'],
#  [],
#  [],
#  ['US20180108936-A1', 'CN110690421-A', 'CN108306018-A', 'CN103500850-A'],
#  [],
#  ['US7525141-B1',
#   'US7629638-B2',
#   'US7785923-B2',
#   'US7811879-B2',
#   'US2010314598-A1',
#   'US7397060-B2',
#   'US7767568-B2'],
#  ['JP2010109201-A', 'KR2010032161-A', 'KR2010124683-A'],
#  ['KR2008024559-A', 'KR783766-B1', 'KR2010098897-A', 'KR2008049168-A'],
#  ['US20080128772-A1',
#   'US6972267-B2',
#   'US6593484-B2',
#   'US5508063-A',
#   'US20070259110-A1',
#   'US20060223245-A9',
#   'US3255257-A',
#   'US6774038-B2',
#   'GB1335408-A'],
#  ['US20110136309-A1', 'US20050242392-A1'],
#  ['CN101692493-A',
#   'CN101916846-A',
#   'US20120064409-A1',
#   'CN102024989-A',
#   'CN102468515-A',
#   'CN101436664-A',
#   'CN101796672-A',
#   'US20070178370-A1',
#   'US20090092892-A1',
#   'CN102412396-A',
#   'JP2002373643-A',
#   'CN102437337-A',
#   'US20090098458-A1',
#   'US6465127-B1'],
#  ['JP2003234169-A',
#   'JP08092746-A',
#   'JP2004091885-A',
#   'JP61024304-A',
#   'JP2006261612-A',
#   'JP10183353-A',
#   'JP2005093858-A',
#   'JP04006791-A',
#   'JP2003306772-A',
#   'JP07249623-A',
#   'JP2005150590-A',
#   'JP2003224114-A',
#   'JP11219907-A',
#   'JP2003223979-A',
#   'JP2003231970-A'],
#  ['US20070141797-A1',
#   'US4767641-A',
#   'US4757360-A',
#   'US4920071-A',
#   'US5855675-A',
#   'US6548405-B2',
#   'US4333808-A',
#   'US6059885-A',
#   'US5610099-A',
#   'US20070004186-A1',
#   'US3865654-A',
#   'US5198029-A',
#   'US20070164367-A1',
#   'US6218293-B1',
#   'US5429966-A',
#   'US6225168-B1',
#   'US20040036129-A1',
#   'US4947221-A',
#   'US7018933-B2',
#   'US6873020-B2',
#   'US6057271-A',
#   'US6921702-B2',
#   'US4590042-A',
#   'US6514828-B2',
#   'US6380579-B1',
#   'US6197628-B1',
#   'US4215156-A',
#   'US20070065594-A1',
#   'US7473637-B2',
#   'US5901271-A',
#   'US3171900-A',
#   'US20070116887-A1',
#   'US6911381-B2',
#   'US20070164323-A1',
#   'US3381114-A',
#   'US6203613-B1',
#   'US6391769-B1',
#   'US6674109-B1',
#   'US6206972-B1',
#   'US6348386-B1',
#   'US20030017717-A1',
#   'US20070020923-A1',
#   'US6599781-B1',
#   'US5747116-A',
#   'US6342277-B1',
#   'US6399491-B2',
#   'US6849298-B2',
#   'US20050042373-A1',
#   'US6521911-B2',
#   'US20020089023-A1',
#   'US5627785-A',
#   'US20040023810-A1',
#   'US6175129-B1',
#   'US6211035-B1',
#   'US6214662-B1',
#   'US20060113603-A1',
#   'US5280205-A',
#   'US5916365-A',
#   'US7351628-B2',
#   'US6204172-B1',
#   'US4811078-A',
#   'US6727169-B1',
#   'US5595606-A',
#   'US20040140513-A1',
#   'US20060113605-A1',
#   'US6423619-B1',
#   'US6338880-B1',
#   'US20050127461-A1',
#   'US6881667-B2',
#   'US5866205-A',
#   'US6420279-B1',
#   'US20050064636-A1',
#   'US4897709-A',
#   'US20050032342-A1',
#   'US20010009695-A1',
#   'US4931411-A',
#   'US20060134870-A1',
#   'US5080928-A',
#   'US6387712-B1',
#   'US6919273-B1',
#   'US6534420-B2',
#   'US4993358-A',
#   'US4814854-A',
#   'US6365519-B2',
#   'US6020024-A',
#   'US5192589-A',
#   'US7208779-B2',
#   'US6908849-B2',
#   'US5006192-A',
#   'US5735960-A',
#   'US6081034-A',
#   'US20020004299-A1',
#   'US6531192-B2',
#   'US20020001906-A1',
#   'US4647947-A',
#   'US6027961-A',
#   'US4435896-A',
#   'US6537901-B2',
#   'US5399379-A'],
#  [],
#  ['US4319923-A', 'US6641948-B1', 'US5966633-A', 'US5610082-A'],
#  ['US7018701-B2',
#   'JP2000306563-A',
#   'KR2005069075-A',
#   'KR2007106813-A',
#   'KR2010109872-A',
#   'KR427596-B1',
#   'US20020155333-A1',
#   'US7682690-B2',
#   'KR2042007596-Y1',
#   'KR2011019490-A',
#   'KR994509-B1',
#   'KR2009069467-A',
#   'US20070292751-A1',
#   'KR1025394-B1',
#   'US5020586-A',
#   'JP2010192333-A',
#   'KR2004027596-Y1'],
#  ['EP349248-A',
#   'US5908888-A',
#   'US5973067-A',
#   'EP1156546-A1',
#   'US6338492-B1',
#   'US6399234-B2',
#   'US6596427-B1',
#   'US4269991-A',
#   'JP2001338673-A',
#   'US5176966-A',
#   'US6371489-B1',
#   'US3377309-A',
#   'EP870587-A2',
#   'WO2002017422-A2',
#   'US2614906-A',
#   'EP1075034-A1',
#   'US5877256-A',
#   'US6057054-A',
#   'WO2002043173-A1',
#   'US4050700-A',
#   'US20020117780-A1',
#   'US4772031-A',
#   'US6495278-B1',
#   'US20020068212-A1',
#   'US4719262-A',
#   'US3794556-A',
#   'US6761991-B2',
#   'US4874667-A',
#   'US5977249-A',
#   'US6165634-A',
#   'US4784879-A',
#   'US5077249-A',
#   'US3677998-A',
#   'US6086643-A',
#   'US20040258977-A1',
#   'US4397917-A',
#   'US6670017-B2',
#   'US5116558-A',
#   'JP61227368-A',
#   'US6436568-B1',
#   'US6716550-B1',
#   'US6130272-A',
#   'US4786568-A',
#   'EP1009052-A1',
#   'EP122150-A',
#   'US6231053-B1',
#   'US3043660-A',
#   'EP1263068-A1',
#   'US3960800-A',
#   'US6080503-A',
#   'US4766176-A',
#   'US6153326-A'],
#  [],
#  ['JP11026025-A',
#   'US5460904-A',
#   'JP2000003728-A',
#   'JP07014608-A',
#   'JP06052891-A',
#   'US20020018935-A1',
#   'US20030143461-A1',
#   'JP11214039-A',
#   'JP08180853-A',
#   'WO1998059384-A1',
#   'JP2000012097-A',
#   'JP11080416-A',
#   'US6120940-A'],
#  [],
#  ['JP2000183053-A',
#   'US20040079972-A1',
#   'US6130168-A',
#   'CN1428846-A',
#   'JP2002064157-A',
#   'US6455374-B1',
#   'US20040056293-A1',
#   'US20050258471-A1',
#   'US6281050-B1'],
#  ['JP2010074004-A', 'JP06045627-A', 'WO1998043304-A1', 'JP2009070933-A'],
#  ['US5422188-A'],
#  [],
#  ['US5071490-A',
#   'US5458694-A',
#   'US4914044-A',
#   'US4847669-A',
#   'US6368892-B1',
#   'US6111188-A',
#   'US20030047207-A1',
#   'US5578503-A',
#   'US4680422-A',
#   'US6288323-B1',
#   'US20060207645-A1',
#   'US20010007262-A1',
#   'US4784701-A'],
#  ['CN1603897-A',
#   'US5437734-A',
#   'US4547621-A',
#   'KR96001192-B1',
#   'KR495925-B1',
#   'KR280838-B1',
#   'KR2004104004-A',
#   'US20040149330-A1',
#   'KR1996001192-B1',
#   'CN1255235-A',
#   'CN1650416-A',
#   'JP08250753-A',
#   'JP2002076409-A',
#   'JP2003008038-A',
#   'US5252142-A',
#   'US6071350-A'],
#  ['CN110047949-A',
#   'CN110752274-A',
#   'CN108649079-A',
#   'CN105428452-A',
#   'CN111816731-A; WO2022007532-A1; CN111816731-B',
#   'US20180309010-A1',
#   'US20160190382-A1',
#   'CN103646983-A',
#   'US20160079463-A1',
#   'CN109378356-A',
#   'CN107302039-A'],
#  [],
#  ['US20090196764-A1',
#   'US20120146437-A1',
#   'US20160197566-A1',
#   'US20140176088-A1',
#   'US20170366082-A1',
#   'US20120250369-A1',
#   'US20120051100-A1',
#   'US20060233000-A1',
#   'US20170126163-A1',
#   'US20160203907-A1',
#   'US20150003124-A1',
#   'US20160195891-A1',
#   'US20080266042-A1',
#   'US20120262953-A1',
#   'US20120223792-A1',
#   'US20150357946-A1',
#   'US8644037-B2',
#   'US20130063184-A1',
#   'US20140146582-A1',
#   'US20170261246-A1',
#   'US20160204689-A1',
#   'US20170126114-A1',
#   'US20180026550-A1',
#   'US20170045249-A1',
#   'US20170040890-A1',
#   'US20130258729-A1',
#   'US20170163042-A1',
#   'US20060152085-A1',
#   'US20140036418-A1',
#   'US20150365003-A1',
#   'US20090200290-A1'],
#  ['GB2019091-A', 'US4234889-A', 'EP48610-A', 'EP97595-A'],
#  ['US3903428-A',
#   'US4838952-A',
#   'US3903427-A',
#   'US4726850-A',
#   'US4427839-A',
#   'JP02051282-A',
#   'US4626613-A',
#   'US4227942-A',
#   'US4748130-A'],
#  ['US20130200470-A1',
#   'US20160111543-A1',
#   'US8487378-B2',
#   'US20160200975-A1',
#   'US6251763-B1',
#   'US20180171226-A1',
#   'US8887106-B2',
#   'US8729634-B2',
#   'US8826213-B1',
#   'US20140282326-A1',
#   'US20130196497-A1',
#   'US20160343605-A1'],
#  ['US4631803-A',
#   'US6255194-B1',
#   'JP58118126-A',
#   'JP11220017-A',
#   'JP07176606-A'],
#  [],
#  ['US6218245-B1', 'US5972765-A'],
#  ['US20030006470-A1',
#   'US20050077619-A1',
#   'US5956569-A',
#   'JP06338636-A',
#   'US6674128-B1',
#   'US20050029637-A1'],
#  ['US6093956-A',
#   'US4996081-A',
#   'US20060157801-A1',
#   'US20040238878-A1',
#   'US6756634-B2'],
#  ['US6211455-B1',
#   'US5413959-A',
#   'US6509204-B2',
#   'US20100255627-A1',
#   'US7498058-B2',
#   'US5192991-A',
#   'US6320117-B1',
#   'US20090162966-A1',
#   'US5667597-A',
#   'US4824489-A',
#   'US6420643-B2',
#   'US7091411-B2',
#   'US7592198-B2',
#   'US6180871-B1',
#   'US6111191-A',
#   'US5714404-A',
#   'US5677240-A'],
#  [],
#  ['US20100044778-A1', 'US20120032250-A1'],
#  [],
#  ['JP09183606-A', 'JP11021120-A'],
#  ['US20040245547-A1',
#   'US20050037546-A1',
#   'WO2003085675-A2',
#   'US6849564-B2',
#   'US20040105305-A1',
#   'US6057603-A',
#   'US20040114428-A1',
#   'US6356477-B1',
#   'US6569745-B2',
#   'US6778421-B2',
#   'WO2006121837-A2',
#   'US6774004-B1',
#   'EP1335417-A2',
#   'US20050243595-A1',
#   'US6753561-B1',
#   'US6625055-B1',
#   'US20040228172-A1',
#   'US20030185038-A1',
#   'US6579729-B2',
#   'US6849891-B1',
#   'US5536947-A',
#   'US20040235309-A1',
#   'US20050052915-A1'],
#  ['US6043607-A', 'US5573595-A', 'US4539068-A', 'US4795529-A'],
#  ['US20120003448-A1',
#   'US20120034451-A1',
#   'CN102362369-A',
#   'CN101228217-A',
#   'CN102214803-A',
#   'KR2012001778-A',
#   'US20040195960-A1',
#   'US6450025-B1',
#   'CN103430345-A',
#   'US20090202743-A1',
#   'KR2010053970-A',
#   'US20100117522-A1',
#   'CN1543514-A',
#   'CN101295768-A'],
#  ['US6140179-A',
#   'US5724299-A',
#   'US6057587-A',
#   'US6165855-A',
#   'US6025624-A',
#   'US6268295-B1',
#   'US6258691-B1',
#   'US6428894-B1',
#   'US5527739-A',
#   'US5763327-A',
#   'US6255151-B1',
#   'US5741626-A',
#   'US6218292-B1',
#   'US6297170-B1',
#   'US5733712-A',
#   'US6200734-B1',
#   'US20020039820-A1',
#   'US5821160-A',
#   'US6287959-B1'],
#  [],
#  ['US20210091058-A1',
#   'US20190362804-A1',
#   'US20120105093-A1',
#   'US20120069685-A1',
#   'WO2021067070-A1',
#   'US20170301667-A1',
#   'US20130082404-A1',
#   'US20170110206-A1',
#   'US20190067359-A1',
#   'US20120114086-A1',
#   'US20180247876-A1',
#   'US20170227605-A1',
#   'US20120106229-A1',
#   'US20150262648-A1',
#   'US20180277216-A1',
#   'US20100295600-A1',
#   'US10930363-B1',
#   'US20090135638-A1',
#   'US20180122686-A1',
#   'US20190096776-A1',
#   'US9401312-B1',
#   'US10916489-B1',
#   'US20170110169-A1',
#   'US20150206825-A1',
#   'US20130230932-A1',
#   'US20170154655-A1',
#   'US20160064357-A1',
#   'US20150363258-A1',
#   'US20200027521-A1'],
#  [],
#  [],
#  ['JP11031799-A',
#   'US6486508-B1',
#   'US5281050-A',
#   'US6420223-B2',
#   'US6417051-B1',
#   'US6104059-A',
#   'US5688705-A',
#   'WO1998044567-A1',
#   'JP07302853-A',
#   'US6287907-B1',
#   'US6403421-B1',
#   'JP11026731-A',
#   'US5994733-A',
#   'US6342715-B1',
#   'US6441426-B1',
#   'US6159799-A',
#   'US6281050-B1'],
#  ['US6187248-B1',
#   'US6396122-B1',
#   'US5627406-A',
#   'US5883219-A',
#   'US5308749-A',
#   'US5858871-A',
#   'US5776990-A',
#   'US6541107-B1',
#   'US6130472-A',
#   'US6019906-A',
#   'US6097095-A',
#   'US6107357-A',
#   'US6268294-B1',
#   'US6365971-B1',
#   'US6426372-B1',
#   'US6372666-B1',
#   'US5767014-A'],
#  ['US20080070340-A1',
#   'US20070277874-A1',
#   'US6743524-B2',
#   'US20020134425-A1',
#   'US20060219293-A1'],
#  ['EP1671766-A2',
#   'JP2006027934-A',
#   'WO2005019134-A1',
#   'CN100577608-C',
#   'CN1330610-A'],
#  ['US20120080725-A1',
#   'US20100052029-A1',
#   'US20160233333-A1',
#   'US20150129945-A1',
#   'US20160013292-A1',
#   'US20200013827-A1',
#   'US20140339631-A1',
#   'US20140061745-A1',
#   'US9640636-B1',
#   'US20140110816-A1',
#   'US10686009-B2',
#   'US20110253981-A1',
#   'US20100059837-A1',
#   'US20160260775-A1'],
#  [],
#  [],
#  ['US5050125-A',
#   'US6486028-B1',
#   'US20060255395-A1',
#   'US20050087892-A1',
#   'US6885586-B2',
#   'US6992929-B2',
#   'US4959812-A',
#   'US20040251906-A1',
#   'US7038267-B2',
#   'US6531732-B2',
#   'US7006378-B1'],
#  [],
#  [],
#  ['US6674149-B2',
#   'US20010039095-A1',
#   'US20030219963-A1',
#   'US6762106-B2',
#   'US6346453-B1',
#   'US6472262-B2',
#   'US6777302-B1',
#   'US5668022-A',
#   'US6531369-B1',
#   'US6699741-B1',
#   'US6706583-B1'],
#  ['US5811205-A',
#   'US5338625-A',
#   'US5270635-A',
#   'US5314765-A',
#   'US5362581-A',
#   'US5654084-A',
#   'US4654281-A',
#   'US5336573-A',
#   'US4614905-A',
#   'US5919587-A',
#   'US5597660-A',
#   'US5291116-A',
#   'US5778515-A',
#   'US6017651-A',
#   'US5567210-A',
#   'US5612152-A',
#   'US5821733-A',
#   'US3237078-A',
#   'US4719401-A',
#   'US5569520-A',
#   'US4303877-A',
#   'US5455126-A',
#   'US5399246-A',
#   'US5783928-A',
#   'US5561004-A',
#   'US5387857-A',
#   'US3393355-A',
#   'US5445906-A',
#   'US5512147-A',
#   'US5411592-A'],
#  [],
#  [],
#  ['JP57178207-A',
#   'TW201037843-A',
#   'CN2422291-Y',
#   'CN108642447-A',
#   'JP06381404-A',
#   'CN109180019-A'],
#  ['US20200144599-A1', 'WO2019079258-A2', 'US20200176810-A1'],
#  ['US4443651-A',
#   'US3902920-A',
#   'US3255047-A',
#   'US4428110-A',
#   'US4042418-A',
#   'US4166918-A'],
#  ['US20100117203-A1', 'US20080302416-A1', 'CN1619783-A', 'CN101431121-A'],
#  ['US20010032664-A1',
#   'US20030227017-A1',
#   'US20030168578-A1',
#   'US20110272012-A1',
#   'US20140224313-A1',
#   'US20120000506-A1',
#   'US20130000722-A1',
#   'US20120222731-A1',
#   'US20090084425-A1',
#   'US20150280031-A1',
#   'US20120152330-A1',
#   'JP2003324209-A',
#   'US20120100665-A1'],
#  ['US3597281-A', 'US4237150-A', 'US4142195-A', 'US4291318-A'],
#  [],
#  ['US6495023-B1',
#   'WO2005001981-A2',
#   'JP62256382-A',
#   'KR3052789-A',
#   'US20060251959-A1',
#   'CN1364146-A',
#   'US20060147763-A1',
#   'WO2005001981-A3',
#   'KR2003052789-A'],
#  [],
#  [],
#  [],
#  ['EP2472601-A2', 'US6982218-B2', 'US7842596-B2'],
#  ['US4141955-A',
#   'US3926558-A',
#   'US5265417-A',
#   'JP07128268-A',
#   'JP11340519-A',
#   'US4063898-A',
#   'GB2167192-A',
#   'US4029472-A',
#   'US5507879-A',
#   'US20040179970-A1',
#   'US4098617-A',
#   'JP55156847-A',
#   'US20050097941-A1',
#   'JP3051922-C1',
#   'US5070024-A',
#   'US5880352-A'],
#  [],
#  ['US6489201-B2'],
#  [],
#  ['JP2013106006-A', 'CN102201480-A'],
#  ['CN103050553-A',
#   'CN103050573-A',
#   'CN203260605-U',
#   'US20090165855-A1',
#   'CN102804407-A'],
#  [],
#  ['RU2453013-C1',
#   'US20100037943-A1',
#   'RU2127472-C1',
#   'RU2502156-C1',
#   'RU2377695-C1'],
#  [],
#  ['US6380583-B1',
#   'US7227219-B2',
#   'US6720611-B2',
#   'US20050009290-A1',
#   'US6323107-B1',
#   'US20060220088-A1'],
#  ['US8546231-B2',
#   'US20160133671-A1',
#   'US20130341587-A1',
#   'EP621604-A1',
#   'US20180040370-A1',
#   'US6369406-B1',
#   'US8729523-B2',
#   'US5977591-A',
#   'US6507067-B1',
#   'US20190088714-A1',
#   'US20140198565-A1',
#   'US20190115532-A1',
#   'US5915185-A',
#   'US5920776-A',
#   'US20130126822-A1',
#   'US8975148-B2',
#   'US9793207-B1',
#   'US20130235654-A1',
#   'US20150144864-A1',
#   'US8841649-B2',
#   'US20140217349-A1',
#   'US8154006-B2',
#   'US5712814-A',
#   'US20190067571-A1',
#   'US20190044063-A1',
#   'US20190044060-A1'],
#  ['WO2019111983-A1',
#   'JP2002134169-A',
#   'WO2019117101-A1',
#   'JP2016157679-A',
#   'JP2008181831-A',
#   'JP2005353579-A'],
#  ['EP1918245-A2',
#   'US6248171-B1',
#   'US5720820-A',
#   'US4976999-A',
#   'US20020166232-A1',
#   'US20120156364-A1',
#   'US20070108229-A1',
#   'US39399-E',
#   'US20060158473-A1',
#   'US5756163-A',
#   'CN101219446-A',
#   'US5770129-A',
#   'US20040247794-A1',
#   'US6749414-B1',
#   'US20030180409-A1',
#   'US7799371-B2',
#   'US4521457-A',
#   'JP2013165269-A',
#   'US7467452-B2',
#   'US8707891-B2',
#   'US4476165-A',
#   'US4774109-A',
#   'US20050037145-A1',
#   'US7255896-B2',
#   'US20030084845-A1',
#   'US20110052811-A1',
#   'US5685911-A',
#   'US6695923-B1',
#   'US6998087-B1',
#   'US7040555-B2',
#   'US4938994-A',
#   'WO2010061394-A1',
#   'US4411218-A',
#   'US6270335-B2',
#   'CN101863162-A',
#   'US20080138456-A1',
#   'US20060251796-A1',
#   'JP2010141326-A',
#   'US4356217-A',
#   'US6669779-B2',
#   'JP2008114225-A',
#   'US20050241575-A1',
#   'US5725814-A',
#   'US20140034682-A1',
#   'US6890167-B1',
#   'US20010046551-A1',
#   'US5700325-A',
#   'CN102227387-A',
#   'US20120180936-A1',
#   'US20060060135-A1',
#   'US6697694-B2',
#   'US7332035-B1',
#   'US20110052812-A1',
#   'US5533675-A',
#   'US5335825-A',
#   'US6689215-B2',
#   'US20080110939-A1',
#   'US4488665-A',
#   'US6534129-B1'],
#  [],
#  ['JP1016405-B2',
#   'JP10156993-A',
#   'JP2000114564-A',
#   'JP2000031509-A',
#   'JP10025357-A',
#   'JP2004214342-A',
#   'CN1590457-A',
#   'JP2001089625-A',
#   'JP2002327018-A',
#   'US6369316-B1',
#   'JP08330618-A',
#   'JP10284745-A',
#   'JP2002100788-A',
#   'JP10306129-A',
#   'JP07176775-A',
#   'JP2008089625-A',
#   'JP1016405-B',
#   'JP62007767-A',
#   'US6369316-A',
#   'JP2002026343-A',
#   'JP2002520820-A',
#   'JP06350117-A',
#   'JP10016405-A',
#   'JP2000138388-A',
#   'JP2002289889-A'],
#  ['US20120061637-A1', 'US20150179662-A1'],
#  ['WO2009133607-A1',
#   'US20060283539-A1',
#   'CN101299410-A',
#   'EP2278632-A1',
#   'JP2006073832-A',
#   'JP2009246019-A'],
#  ['US20060188774-A1',
#   'JP09013188-A',
#   'US20080280169-A1',
#   'JP2000313982-A',
#   'JP2008230905-A'],
#  ['US20100019304-A1',
#   'US20070211512-A1',
#   'US20070195578-A1',
#   'US20080165565-A1',
#   'US20090213637-A1',
#   'US20080180985-A1',
#   'US20060023485-A1'],
#  ['KR2017119893-A', 'CN204558501-U', 'CN107230519-A'],
#  ['JP2016514371-A',
#   'US20140339624-A1',
#   'US20170018571-A1',
#   'US20180006050-A1',
#   'US20180138190-A1',
#   'US20170271021-A1',
#   'US20150380422-A1',
#   'US9496355-B2',
#   'US20150187789-A1',
#   'US20150236112-A1',
#   'TW605575-B1',
#   'US20190139983-A1',
#   'US20180040623-A1',
#   'US20170250189-A1',
#   'US9837435-B1',
#   'US7355238-B2',
#   'US20110260237-A1',
#   'US20150200199-A1',
#   'US9184175-B2',
#   'US20150249093-A1',
#   'US20100155810-A1',
#   'US20140061770-A1',
#   'JP2014147125-A'],
#  [],
#  [],
#  ['US5918130-A',
#   'US20050179054-A1',
#   'US7871490-B2',
#   'US8114717-B2',
#   'US20080308813-A1',
#   'US20070295993-A1',
#   'US5448086-A',
#   'US6410947-B1',
#   'US20070114569-A1',
#   'US6884704-B2',
#   'US20050212049-A1',
#   'US20090032820-A1',
#   'US7648867-B2',
#   'US8124505-B1',
#   'US6281528-B1',
#   'US20090072269-A1',
#   'US8076699-B2',
#   'US20070278518-A1',
#   'US20100025730-A1'],
#  ['CN102290601-A', 'US20060269843-A1', 'CN101663790-A', 'CN102263292-A'],
#  ['EP1732137-A2',
#   'JP2010283340-A',
#   'EP2323171-A1',
#   'US20060272700-A1',
#   'CN1881621-A',
#   'WO2012083291-A1',
#   'US20110192457-A1',
#   'US7494607-B2',
#   'CN1687992-A',
#   'CN101164943-A',
#   'WO2012116052-A1',
#   'US20110308597-A1',
#   'US20130000714-A1',
#   'WO2010123967-A2'],
#  [],
#  [],
#  [],
#  ['US4795718-A',
#   'US5272100-A',
#   'US5225360-A',
#   'US5445983-A',
#   'US4988635-A',
#   'US5352618-A',
#   'US5674768-A',
#   'US5773333-A',
#   'US4670090-A',
#   'US5756384-A',
#   'US5550065-A',
#   'US4495693-A'],
#  ['US4766006-A',
#   'US6351036-B1',
#   'US6174809-B1',
#   'US20050202171-A1',
#   'US6379748-B1',
#   'US5981331-A',
#   'US7122464-B2',
#   'US6534395-B2',
#   'US6153519-A',
#   'US6706115-B2',
#   'JP63109172-A',
#   'US6794284-B2',
#   'US6683381-B2',
#   'US7005392-B2',
#   'US5350719-A',
#   'US6989457-B2',
#   'US6960675-B2',
#   'US5087593-A',
#   'US6287965-B1',
#   'US6391785-B1',
#   'US6015917-A',
#   'US5256244-A',
#   'US6869638-B2',
#   'US6642567-B1',
#   'US6995081-B2',
#   'US6511539-B1',
#   'US5840897-A',
#   'US6585823-B1',
#   'US7208427-B2',
#   'US5997949-A',
#   'US6117692-A',
#   'US6590251-B2',
#   'US6479364-B2',
#   'US5576579-A',
#   'US6527855-B2',
#   'US6967159-B2',
#   'US5453527-A',
#   'US5849071-A',
#   'US7300870-B2',
#   'US7521356-B2',
#   'US20020086111-A1',
#   'US5916634-A',
#   'US20030211736-A1',
#   'US6884466-B2',
#   'US7196007-B2',
#   'US6969539-B2',
#   'US20060048711-A1',
#   'JP03183776-A',
#   'US6846516-B2',
#   'US6703708-B2'],
#  ['US20050227455-A1',
#   'US20100230711-A1',
#   'US20110168976-A1',
#   'KR2011042065-A',
#   'US20030064535-A1',
#   'US20040012337-A1',
#   'US20090102028-A1',
#   'JP2003045652-A',
#   'FR2930839-A1',
#   'US20030003614-A1',
#   'CN101916831-A',
#   'KR2012065273-A',
#   'US20060255341-A1',
#   'CN102769104-A',
#   'KR2010026590-A',
#   'KR662993-B1',
#   'US20120222732-A1',
#   'US20110297994-A1',
#   'US20070200497-A1',
#   'US20090068918-A1',
#   'KR2009047977-A',
#   'KR2007115961-A',
#   'US20080218068-A1',
#   'US4962985-A',
#   'WO2010132552-A1'],
#  ['US6775175-B2', 'US20040066695-A1', 'US5812466-A', 'US5675547-A'],
#  ['CN104241449-A'],
#  [],
#  [],
#  ['JP07263730-A', 'US4387387-A', 'US4400409-A', 'US4070206-A'],
#  ['US7439577-B2',
#   'US6617204-B2',
#   'US20090014778-A1',
#   'US6774432-B1',
#   'US20070108509-A1',
#   'US7098107-B2'],
#  [],
#  ['WO2009152238-A2', 'KR2002010584-A', 'KR2008014751-A', 'KR2011061785-A'],
#  ['CN102931262-A',
#   'CN103895304-A',
#   'CN104201226-A',
#   'CN103074023-A',
#   'CN202384363-U',
#   'CN104201224-A'],
#  ['CN103579324-A', 'US20020175273-A1', 'JP2010057161-A', 'CN104316498-A'],
#  ['CN106409978-A', 'CN102844876-A', 'CN105934828-A', 'CN104701424-A'],
#  ['US20100209330-A1',
#   'US20090068471-A1',
#   'US20090110627-A1',
#   'US20030104280-A1',
#   'US8075864-B2',
#   'KR2006038910-A',
#   'US20150274530-A1',
#   'US8361853-B2',
#   'US3285697-A',
#   'US4887273-A',
#   'US20080286541-A1',
#   'US8361813-B1'],
#  ['US4124455-A',
#   'US5075763-A',
#   'US5330585-A',
#   'US5928438-A',
#   'US7285720-B2',
#   'US3736180-A',
#   'US5103268-A',
#   'US4468853-A',
#   'US4340803-A'],
#  ['CN101593812-A'],
#  [],
#  ['KR2009010427-A', 'KR2007094194-A', 'KR2008111206-A', 'KR2008098237-A'],
#  ['US20090110627-A1',
#   'US20110064370-A1',
#   'KR2011020443-A',
#   'US20110045282-A1',
#   'KR2010107403-A',
#   'US20090155561-A1',
#   'US20100200839-A1',
#   'KR2009124330-A',
#   'KR2010055098-A',
#   'KR2011014847-A',
#   'US20100285639-A1',
#   'US20110033677-A1',
#   'US20100323113-A1',
#   'US20110091647-A1',
#   'US20100038629-A1',
#   'US20090169919-A1',
#   'JP2010153793-A',
#   'US20070212538-A1',
#   'KR2009017454-A',
#   'US20070187694-A1',
#   'KR2010076857-A'],
#  ['US7157342-B1',
#   'US6479868-B1',
#   'US6998298-B1',
#   'US6812504-B2',
#   'US6506654-B1',
#   'US6653175-B1',
#   'US6528851-B1',
#   'US7118980-B2',
#   'US20050026337-A1',
#   'US6690038-B1',
#   'US6653174-B1'],
#  ['US20090035636-A1',
#   'US20150155589-A1',
#   'JP2006294521-A',
#   'JP2002216779-A',
#   'US7785749-B2',
#   'US6103417-A',
#   'US20120148892-A1',
#   'US9368830-B2',
#   'US7211348-B2',
#   'US20090023030-A1',
#   'US20160197373-A1',
#   'JP2007179870-A',
#   'US20070099068-A1',
#   'US20050158619-A1',
#   'KR874110-B1',
#   'US6432576-B1',
#   'WO2013062623-A1'],
#  [],
#  [],
#  ['CN101714591-A', 'CN101950769-A', 'CN103383917-A'],
#  ['US4042447-A',
#   'US3382114-A',
#   'US4087571-A',
#   'US4113532-A',
#   'US4099986-A',
#   'US4113531-A',
#   'US3950187-A',
#   'US4003770-A',
#   'US4059461-A',
#   'US3290189-A'],
#  ['US4152824-A',
#   'US20110177652-A1',
#   'US2794846-A',
#   'DE102013211746-A1',
#   'US6998288-B1'],
#  ['US20030091751-A1',
#   'US4753735-A',
#   'US20020096666-A1',
#   'US20040191419-A1',
#   'US5881476-A',
#   'US20120219725-A1',
#   'JP01262069-A',
#   'US6184458-B1',
#   'US20080032018-A1',
#   'US20120045852-A1',
#   'CN1252893-A',
#   'US20120034382-A1',
#   'US7851727-B2',
#   'US20120269226-A1',
#   'US8236596-B2',
#   'US5263265-A',
#   'US4738868-A',
#   'US6347583-B1',
#   'US6705413-B1',
#   'US20120136476-A1',
#   'US3216127-A',
#   'US4951401-A',
#   'US20110165316-A1',
#   'JP2004181483-A',
#   'US20080012499-A1',
#   'US20080130750-A1',
#   'US4694586-A',
#   'US4798007-A',
#   'US5314711-A',
#   'US4565917-A',
#   'US5741622-A',
#   'US20060194417-A1',
#   'US7161103-B1',
#   'US5261165-A',
#   'US20070022883-A1',
#   'US20030108349-A1',
#   'US4757759-A',
#   'US4764402-A',
#   'US5883362-A',
#   'US20060003480-A1',
#   'US3961569-A',
#   'WO2006069256-A2',
#   'US20070045382-A1',
#   'US20030215746-A1',
#   'US6024904-A',
#   'US20060130750-A1',
#   'US3924569-A',
#   'US4545131-A',
#   'US20040226513-A1',
#   'US5467912-A',
#   'US20120048132-A1',
#   'US4952145-A'],
#  [],
#  [],
#  ['US4141756-A',
#   'US20100059362-A1',
#   'US6732031-B1',
#   'US5885896-A',
#   'US20090162970-A1',
#   'US20040232414-A1',
#   'US6221740-B1',
#   'US6265328-B1',
#   'JP2002217430-A',
#   'US6338313-B1',
#   'US20070290283-A1',
#   'JP87237766-A',
#   'US20030106643-A1',
#   'US4522657-A',
#   'US20100041176-A1',
#   'US20120122273-A1',
#   'US6263941-B1',
#   'US7228211-B1',
#   'CN1638015-A',
#   'US7498245-B2',
#   'JP2005123447-A',
#   'US20070081138-A1',
#   'US20080078444-A1',
#   'US4021276-A',
#   'JP2000123778-A',
#   'US20080092944-A1',
#   'US7867409-B2',
#   'US5421889-A',
#   'US20070148336-A1',
#   'US6544862-B1',
#   'US7225065-B1',
#   'US20010002584-A1',
#   'US4179311-A',
#   'US6248649-B1',
#   'US20080001139-A1',
#   'US6391740-B1',
#   'US6180496-B1',
#   'US6213050-B1',
#   'US7532963-B1',
#   'US20050045835-A1',
#   'US4131488-A',
#   'WO2002075816-A1',
#   'US20070032044-A1',
#   'JP2004031648-A',
#   'US6417515-B1',
#   'US20090124064-A1',
#   'US20080128019-A1',
#   'US20070087574-A1',
#   'US6271566-B1',
#   'US6217724-B1',
#   'US20080092947-A1',
#   'US6383876-B1',
#   'US20040067644-A1',
#   'US7479441-B2',
#   'US7022984-B1',
#   'US6010579-A',
#   'US20090142875-A1',
#   'US20100055874-A1',
#   'US6221774-B1',
#   'US7354815-B2',
#   'US6083324-A',
#   'US6186091-B1',
#   'US20080038908-A1',
#   'US6204151-B1',
#   'US20040112426-A1',
#   'US20070217020-A1',
#   'JP2002083981-A',
#   'US1637-H',
#   'CN1198597-A',
#   'US6949895-B2',
#   'US4847504-A',
#   'US6013563-A',
#   'US6552414-B1',
#   'US20080121276-A1',
#   'US6171965-B1',
#   'US20070084505-A1',
#   'US7390724-B2',
#   'US7547609-B2',
#   'US20070277875-A1',
#   'JP98084125-A',
#   'US6051073-A',
#   'DE4217428-A1',
#   'US20070134840-A1',
#   'US5760405-A',
#   'US20030137050-A1',
#   'US6228176-B1',
#   'US7477968-B1',
#   'US20020109233-A1',
#   'US7011733-B2',
#   'US7166520-B1',
#   'US20060279970-A1',
#   'US6033974-A',
#   'US5969366-A',
#   'US20020090758-A1',
#   'US3786359-A',
#   'US7532962-B1',
#   'US7174243-B1',
#   'US20100124799-A1',
#   'US6507689-B2',
#   'DE19820152-A1',
#   'US5883391-A',
#   'JP2005322780-A',
#   'US20040198028-A1',
#   'US7521699-B2',
#   'US20030015700-A1',
#   'US20070029043-A1',
#   'US6534381-B2',
#   'US7674687-B2',
#   'US20090152162-A1',
#   'US7523159-B1',
#   'US4676845-A',
#   'US7225047-B2',
#   'US20100110239-A1',
#   'US20070035847-A1',
#   'US20020109824-A1',
#   'US20090227094-A1',
#   'US20120129325-A1',
#   'US6048411-A',
#   'US20080128641-A1',
#   'US5516725-A',
#   'US4830678-A',
#   'US20050181584-A1',
#   'US6200883-B1',
#   'US7480551-B1',
#   'US6245161-B1',
#   'US20070169806-A1',
#   'US6184111-B1',
#   'JP92221059-A',
#   'JP97321327-A',
#   'JP95135329-A',
#   'US4834805-A',
#   'US5132544-A',
#   'US6093625-A',
#   'US20010020485-A1',
#   'US6874515-B2',
#   'US6138606-A',
#   'US6084175-A',
#   'US20090124065-A1',
#   'US5125983-A',
#   'US5554854-A',
#   'US6335534-B1',
#   'US20040025932-A1',
#   'US20070012503-A1',
#   'US20120125259-A1',
#   'US4719355-A',
#   'JP89290267-A',
#   'US6207005-B1',
#   'US5831321-A',
#   'US20080121275-A1',
#   'US20080044964-A1'],
#  ['JP11317508-A',
#   'US6514831-B1',
#   'JP09074146-A',
#   'JP01125976-A',
#   'US20050202672-A1',
#   'US20030222294-A1',
#   'JP01025483-A',
#   'JP11144483-A',
#   'US20040070018-A1',
#   'JP2000049244-A',
#   'US20040256677-A1',
#   'JP63221673-A'],
#  [],
#  [],
#  ['US20120204928-A1',
#   'US20100197061-A1',
#   'US20130098434-A1',
#   'US5679176-A',
#   'US20100323508-A1'],
#  ['US4059669-A',
#   'US3998668-A',
#   'US3914138-A',
#   'US3354005-A',
#   'US4104091-A',
#   'US3303070-A'],
#  ['CN101780956-A',
#   'US20100135888-A1',
#   'CN102205219-A',
#   'CN2389714-Y',
#   'DE2539880-A',
#   'CN102083522-A',
#   'CN102392296-A',
#   'US5260538-A',
#   'CN103523786-A',
#   'WO1999003308-A1',
#   'US20090129429-A1',
#   'US20110248430-A1',
#   'US6127004-A',
#   'WO1993020933-A1'],
#  ['US20030082448-A1',
#   'JP2005268017-A',
#   'US20050196674-A1',
#   'US20030211391-A1',
#   'JP2003331840-A',
#   'JP11016569-A',
#   'JP2007234350-A',
#   'JP06168722-A',
#   'US7157186-B2',
#   'CN1458704-A',
#   'US20070292764-A1',
#   'JP2004220785-A',
#   'US7135251-B2',
#   'JP2007335331-A',
#   'US7335446-B2',
#   'KR2007016431-A',
#   'JP2005243301-A',
#   'US7378190-B2',
#   'WO2006123572-A1',
#   'JP2006169048-A',
#   'US20080118835-A1',
#   'JP2003272704-A',
#   'US7473493-B2',
#   'JP2003331846-A',
#   'US8003252-B2',
#   'US20100173197-A1'],
#  ['US7101764-B2', 'US6680231-B1', 'US20020140047-A1', 'US20060017114-A1'],
#  ['EP148608-A',
#   'EP1847575-A1',
#   'DE2411872-A',
#   'EP594932-A1',
#   'US4450100-A',
#   'US20080286448-A1',
#   'US5706064-A',
#   'US4456549-A',
#   'JP60245779-A',
#   'JP60245780-A'],
#  ['US7402850-B2',
#   'US6284603-B1',
#   'US5491655-A',
#   'US7075140-B2',
#   'US5999444-A',
#   'US6107659-A',
#   'US6606265-B2',
#   'US6703661-B2',
#   'US6314037-B1',
#   'US5978264-A',
#   'US6524914-B1',
#   'US5140192-A',
#   'US5316961-A'],
#  [],
#  ['CN101447528-A',
#   'CN201658972-U',
#   'CN102789960-A',
#   'KR2012113548-A',
#   'CN101540350-A',
#   'CN103069551-A',
#   'CN103132054-A',
#   'CN201536670-U',
#   'CN103078008-A'],
#  [],
#  [],
#  ['CN101255532-A', 'JP2009035782-A', 'EP429793-A', 'JP06248395-A'],
#  ['CN102709313-A', 'CN104134700-A', 'WO2018035502-A1', 'CN109427912-A'],
#  ['US4471155-A',
#   'JP57043477-A',
#   'JP56094674-A',
#   'JP56150876-A',
#   'US4379943-A',
#   'JP58067073-A',
#   'US4542256-A'],
#  ['JP2010192870-A',
#   'JP2012186233-A',
#   'JP2011511464-A',
#   'JP2008135740-A',
#   'JP06326339-A',
#   'JP2009200126-A'],
#  ['US20060258791-A1', 'US20090205715-A1', 'US20060160373-A1'],
#  ['US3954623-A',
#   'US5235028-A',
#   'US5698089-A',
#   'US5891656-A',
#   'WO1999067024-A1',
#   'US5846396-A',
#   'US5965695-A',
#   'US4855225-A',
#   'US5071076-A',
#   'US5985120-A',
#   'US4661445-A',
#   'US4069017-A',
#   'US4189382-A',
#   'US4938742-A',
#   'US5773307-A',
#   'US5547682-A',
#   'US6355431-B1',
#   'US3696932-A',
#   'US5252494-A',
#   'US20060257991-A1',
#   'US5374530-A',
#   'US4753776-A',
#   'US4965188-A',
#   'US5707502-A',
#   'US5382512-A',
#   'US6713298-B2',
#   'US6254830-B1',
#   'US4795698-A',
#   'US4988618-A',
#   'US4683195-A',
#   'US5550373-A',
#   'US20050136548-A1',
#   'US4344743-A',
#   'US3843696-A',
#   'US4588665-A',
#   'US5147606-A',
#   'WO1992000880-A',
#   'US6591124-B2',
#   'WO2000020117-A2',
#   'US6426050-B1',
#   'US5872623-A',
#   'US6514415-B2',
#   'US6171780-B1',
#   'US5223393-A',
#   'US5863957-A',
#   'US5866430-A',
#   'US6037137-A',
#   'US5518887-A',
#   'US4050898-A',
#   'US5480723-A',
#   'EP339623-A',
#   'US5840256-A',
#   'US5587128-A',
#   'WO2000066766-A1',
#   'US5156972-A',
#   'US6103479-A',
#   'US6083763-A',
#   'US3709868-A',
#   'WO1998025701-A1',
#   'US5385709-A',
#   'US6074616-A',
#   'US5843655-A',
#   'US5366860-A',
#   'US5869241-A',
#   'US4294817-A',
#   'US6413786-B1',
#   'US6171489-B1',
#   'US5307144-A',
#   'US5843767-A',
#   'US5922617-A',
#   'US20010002984-A1',
#   'US6355491-B1',
#   'US5866099-A',
#   'GB2315131-A',
#   'US5698271-A',
#   'US5130238-A',
#   'US5846708-A',
#   'US6406848-B1',
#   'WO1999017139-A1',
#   'WO2000004372-A1',
#   'US6288220-B1',
#   'US5616698-A',
#   'US6245296-B1',
#   'US5788814-A',
#   'US5700897-A',
#   'US3775742-A',
#   'US4672028-A',
#   'US6210910-B1',
#   'US5219763-A',
#   'EP518557-A2',
#   'WO1994019690-A1',
#   'WO1997035189-A1',
#   'US5240640-A',
#   'US5797898-A',
#   'US4246107-A',
#   'US5854141-A',
#   'US5168044-A',
#   'US5942443-A',
#   'US6063581-A',
#   'US5053197-A',
#   'US5879632-A',
#   'US5631130-A',
#   'US4908112-A',
#   'US3701433-A',
#   'US5512490-A',
#   'US5714122-A',
#   'WO200155702-A1; AU200133200-A; EP1255980-A1; US2003186228-A1; AU2001233200-A8; US7316899-B2; EP1255980-B1; DE60135092-E; US2008219891-A1; EP2230314-A1; WO200155702-A9',
#   'EP439182-A',
#   'US5244813-A',
#   'US20090215646-A1',
#   'US5827748-A',
#   'US4997577-A',
#   'US6151973-A',
#   'US6133047-A',
#   'US5945334-A',
#   'US6602702-B1',
#   'US4810378-A',
#   'US4813277-A',
#   'US4200613-A',
#   'US4683202-A',
#   'US5126276-A',
#   'US5804451-A',
#   'US4378429-A',
#   'US5262127-A',
#   'US5583054-A',
#   'US4245041-A',
#   'US5980704-A',
#   'US5162863-A',
#   'US5156810-A',
#   'US6589779-B1',
#   'US6023540-A',
#   'US3964974-A',
#   'US5747349-A',
#   'US5491097-A',
#   'US4115277-A',
#   'WO1990001069-A',
#   'US5858804-A',
#   'US5637469-A',
#   'US20040029259-A1',
#   'US5770370-A',
#   'US7491552-B2',
#   'US6083761-A',
#   'US5597531-A',
#   'US5965590-A',
#   'US6127139-A',
#   'US5914042-A',
#   'US4623461-A',
#   'US6013440-A',
#   'US5248742-A',
#   'US5856174-A',
#   'US3856469-A',
#   'US5288214-A',
#   'US6485690-B1',
#   'US20060257992-A1',
#   'US3709838-A',
#   'US6908770-B1',
#   'US5405784-A',
#   'US5616790-A',
#   'US5814524-A',
#   'US5876605-A',
#   'US5244636-A',
#   'US4477575-A',
#   'US6168948-B1',
#   'US6411207-B2',
#   'GB2300258-A',
#   'US5872170-A',
#   'US5211850-A',
#   'US5632876-A',
#   'WO1998053300-A2',
#   'US5137833-A',
#   'US6008031-A',
#   'US5252294-A',
#   'US3876504-A',
#   'US6309889-B1',
#   'US5748091-A',
#   'US4828386-A',
#   'US6331441-B1',
#   'US5182366-A',
#   'US5992820-A',
#   'US5563042-A',
#   'US5981297-A',
#   'US3587040-A',
#   'US5209904-A',
#   'WO1999018434-A1',
#   'US5278303-A',
#   'US6048732-A',
#   'US7022517-B1',
#   'US5759015-A',
#   'WO1998040726-A1',
#   'US5654497-A',
#   'US4567149-A',
#   'US4036946-A',
#   'US20060257993-A1',
#   'US5108933-A',
#   'US6680206-B1',
#   'US4925800-A',
#   'US5499909-A',
#   'US4874499-A',
#   'US5779907-A',
#   'US5611676-A',
#   'US5837552-A',
#   'US4360611-A',
#   'US4596657-A',
#   'US6045579-A',
#   'US5677195-A',
#   'US6482593-B2',
#   'US5391272-A',
#   'US5143853-A',
#   'US5188934-A',
#   'US5705018-A',
#   'US5250264-A',
#   'US5755942-A',
#   'US5677196-A',
#   'US6692696-B1',
#   'US4681742-A',
#   'US5503985-A',
#   'US5567627-A',
#   'US5834318-A',
#   'US5690807-A',
#   'US4843259-A',
#   'WO1998017383-A1'],
#  ['FR2936651-A1',
#   'FR2958795-A1',
#   'US20130049580-A1',
#   'US20110031514-A1',
#   'US7781967-B2',
#   'US20110198627-A1',
#   'JP2005353500-A',
#   'FR1001522-A'],
#  ['CN109326827-A',
#   'CN108321436-A',
#   'CN108511826-A',
#   'CN108183262-A',
#   'CN107403908-A',
#   'JP2015172146-A',
#   'CN102820487-A',
#   'CN107579302-A',
#   'CN108110333-A'],
#  ['US20110272012-A1',
#   'CN101866991-A',
#   'WO2010104726-A2',
#   'CN101499497-A',
#   'US20120055547-A1',
#   'US20110056544-A1',
#   'US20090211627-A1'],
#  [],
#  [],
#  ['US20100127394-A1',
#   'US9059127-B1',
#   'US8198716-B2',
#   'US20160211191-A1',
#   'US20020066591-A1',
#   'US20150349526-A1',
#   'US20200098849-A1',
#   'US6351391-B1',
#   'US9406561-B2',
#   'US20170207214-A1',
#   'US20200286871-A1',
#   'US20200243487-A1',
#   'US20150243609-A1',
#   'US20190245543-A1',
#   'US20190006192-A1',
#   'US20170047312-A1',
#   'US8802454-B1',
#   'US20100140779-A1',
#   'US20150192633-A1',
#   'US20180351507-A1',
#   'US20160334991-A1',
#   'US5914533-A',
#   'US20130049213-A1',
#   'US20110012244-A1',
#   'US5644163-A',
#   'US20130082365-A1',
#   'US20200212018-A1',
#   'US8264067-B2',
#   'US8803305-B2',
#   'US20170365581-A1',
#   'US20150371971-A1',
#   'US20190238134-A1',
#   'US20170084596-A1',
#   'US20150285998-A1',
#   'US20150054149-A1',
#   'US9331062-B1',
#   'US20120146711-A1',
#   'US20210043607-A1',
#   'US20110170266-A1',
#   'US20110042795-A1',
#   'US20150348954-A1',
#   'US20090251862-A1',
#   'US20100246152-A1',
#   'US20080237310-A1',
#   'US20180102470-A1',
#   'US8373230-B1',
#   'US20190019693-A1',
#   'US20150206838-A1',
#   'US20190013213-A1',
#   'US20200066679-A1',
#   'US9640531-B1',
#   'US20190295952-A1',
#   'US8212343-B2',
#   'US20170200716-A1',
#   'US20180176006-A1',
#   'US20180331028-A1',
#   'US20160293497-A1',
#   'US20170263518-A1',
#   'US20110121811-A1',
#   'US6282095-B1',
#   'US20120193752-A1',
#   'US20110215457-A1',
#   'US20190006222-A1',
#   'US20210020457-A1',
#   'US20150108604-A1',
#   'US20100314711-A1',
#   'US5587882-A',
#   'US20020113244-A1',
#   'US20110115064-A1'],
#  [],
#  ['JP2003031693-A',
#   'US20040262679-A1',
#   'US7933139-B2',
#   'JP2005079314-A',
#   'US20040262635-A1',
#   'JP2005026366-A',
#   'US6617651-B2',
#   'US20040025866-A1',
#   'US6825524-B1',
#   'JP2008091492-A',
#   'US20080237695-A1',
#   'JP2008041157-A',
#   'JP2005010448-A',
#   'JP2007188603-A',
#   'US20060211231-A1',
#   'US20040258866-A1',
#   'US7433222-B2',
#   'US7085156-B2',
#   'US20030146469-A1',
#   'JP2003229537-A'],
#  ['CN101055896-A',
#   'CN101401189-A',
#   'US20060231804-A1',
#   'US20100308462-A1',
#   'US20120161081-A1',
#   'EP1713092-A2',
#   'US20090029057-A1',
#   'CN101952903-A',
#   'CN1933183-A',
#   'US20120164777-A1',
#   'US5126921-A',
#   'US20070215202-A1',
#   'US20060231801-A1',
#   'US6225392-B1',
#   'US20110186121-A1',
#   'WO2011026852-A1',
#   'US20090229665-A1',
#   'WO2010003619-A1',
#   'WO2011026769-A1'],
#  ['US20030211701-A1',
#   'US6417074-B2',
#   'US6569700-B2',
#   'US6069058-A',
#   'US6089058-A',
#   'US6794698-B1'],
#  [],
#  ['JP58220477-A; US4640001-A',
#   'JP58151070-A',
#   'US4451969-A',
#   'US4359487-A',
#   'US4253881-A'],
#  ['US4488262-A',
#   'US6600188-B1',
#   'US5627779-A',
#   'US20040014304-A1',
#   'US20040041206-A1',
#   'US6104045-A',
#   'US20020048190-A1',
#   'US5814853-A',
#   'US20030151948-A1',
#   'US6653174-B1',
#   'US6294427-B1',
#   'US6611452-B1',
#   'US6653175-B1',
#   'US6243296-B1',
#   'US20030160277-A1',
#   'US20040007734-A1',
#   'US6574143-B2',
#   'US20030072126-A1',
#   'US3978577-A',
#   'US6248626-B1',
#   'US20020105023-A1',
#   'US5488243-A',
#   'US4791604-A',
#   'US20030089942-A1',
#   'US5396454-A',
#   'US6660616-B2',
#   'US4870470-A',
#   'US5557569-A',
#   'US6462359-B1',
#   'US20030042534-A1',
#   'US3918033-A',
#   'US6638627-B2',
#   'US6545297-B1'],
#  ['KR2010128282-A',
#   'US20130171340-A1',
#   'US20100178531-A1',
#   'WO2012150012-A1',
#   'US9705136-B2',
#   'WO2014008433-A1',
#   'US20120115049-A1',
#   'WO2013130677-A1',
#   'US7854991-B2',
#   'US20060046144-A1',
#   'WO2009108731-A3',
#   'US6863942-B2',
#   'US20060057433-A1',
#   'US20100159305-A1',
#   'WO2011152190-A1',
#   'US9412998-B2',
#   'US5674642-A',
#   'WO2012084570-A1',
#   'JP2006179431-A1',
#   'US20060165988-A1',
#   'JP2003123749-A',
#   'US9431181-B2',
#   'WO2011068911-A2',
#   'US20110281156-A1',
#   'US6815121-B2',
#   'FR2895752-B1',
#   'US8119288-B2',
#   'US3775216-A',
#   'US20080020193-A1',
#   'US20110229761-A1',
#   'WO2010100599-A1',
#   'US20120229096-A1',
#   'US20050064291-A1',
#   'US20050230270-A1',
#   'US20120107582-A1',
#   'US20090068553-A1',
#   'JP2010103051-A1',
#   'US20020018935-A1',
#   'US8481214-B2',
#   'WO2012054767-A2',
#   'US6875536-B2',
#   'US20120250225-A1',
#   'US7094499-B1',
#   'JP2011018575-A',
#   'US20050287440-A1',
#   'US20080220329-A1',
#   'US20110165462-A1',
#   'WO2013126372-A1',
#   'US20100159331-A1',
#   'US20110143198-A1',
#   'WO2012002136-A1',
#   'US20090214944-A1',
#   'US4329403-A',
#   'WO2011041468-A1',
#   'US20070148549-A1',
#   'WO2007095013-A1',
#   'US8236452-B2',
#   'DE112007000185-T5',
#   'US20060029857-A1',
#   'US20100015933-A1',
#   'US20080020282-A1',
#   'US5795672-A',
#   'WO2010129827-A1',
#   'US8450012-B2',
#   'US8389157-B2',
#   'WO2012069245-A1',
#   'US20110027655-A1',
#   'US7442284-B2',
#   'WO2007071778-A1',
#   'US6194099-B1',
#   'US20090208834-A1',
#   'US20100297502-A1',
#   'US7938996-B2',
#   'US20110076542-A1',
#   'US20110070488-A1',
#   'WO2011149958-A3',
#   'US20050130043-A1',
#   'US3053113-A1',
#   'US9941709-B2',
#   'US20040234844-A1',
#   'US20110104553-A1',
#   'US8329293-B2',
#   'US8669009-B2',
#   'US20060147797-A1',
#   'US20080261116-A1',
#   'WO2011060017-A2',
#   'US7745047-B2',
#   'US20060003226-A1',
#   'US20070202403-A1',
#   'US20100203362-A1',
#   'US8241793-B2',
#   'WO2011119614-A3',
#   'US8890211-B1',
#   'US9917300-B2',
#   'US20080193840-A1',
#   'US20150236342-A1',
#   'US20070212538-A1',
#   'US7147966-B2',
#   'EP2037516-A1',
#   'JP2001210315-A1',
#   'US20130143124-A1',
#   'US8556996-B2',
#   'US20100136431-A1',
#   'US7189476-B1',
#   'US20060002842-A1',
#   'US20110104551-A1',
#   'JP2004319390-A',
#   'US20040141908-A1',
#   'US20030044686-A1',
#   'US20080160409-A1',
#   'JP2002313319-A1',
#   'US20110165466-A1',
#   'JP2004319390-A1',
#   'US20100258525-A1',
#   'US9362549-B2',
#   'US20100221596-A1',
#   'US8492029-B2',
#   'US8426052-B2',
#   'WO2013096931-A1',
#   'KR2011125807-A',
#   'US20140234712-A1',
#   'US20080013258-A1',
#   'US20120115048-A1',
#   'US20080096110-A1',
#   'US20080299455-A1',
#   'US20100216026-A1',
#   'US20070190422-A1',
#   'US8551657-B2',
#   'JP2010525549-A1',
#   'US20080311472-A1',
#   'US7402829-B2',
#   'US20090004566-A1',
#   'US20090053608-A1',
#   'WO2011076475-A1',
#   'WO2007069389-A1',
#   'WO2008033827-A1',
#   'US20130244107-A1',
#   'US20090169996-A1',
#   'US20040258984-A1',
#   'US20100178417-A1',
#   'US20090042102-A1',
#   'US20070167101-A1',
#   'US20090305135-A1',
#   'US8257866-B2',
#   'WO2010135446-A1',
#   'US20090186276-A1',
#   'KR2011125808-A'],
#  ['US20150187787-A1'],
#  ['US20070153177-A1',
#   'US20090103161-A1',
#   'US20080303018-A1',
#   'US20090185120-A1',
#   'US20080179762-A1',
#   'TW200807736-A',
#   'US20090278121-A1',
#   'US20020146871-A1',
#   'US20090009675-A1'],
#  [],
#  ['CN103050554-A', 'CN110299418-A', 'CN111816726-A'],
#  ['EP1923934-A1',
#   'JP62237679-A',
#   'JP61183867-A',
#   'US20100062341-A1',
#   'EP269855-A',
#   'US20080199781-A1',
#   'US5470675-A',
#   'US7951480-B1',
#   'US4778479-A',
#   'US5470676-A',
#   'WO2008147751-A1',
#   'US20110076544-A1',
#   'US4063978-A',
#   'JP7034555-U',
#   'WO2011098233-A2',
#   'JP10188938-A',
#   'US6280878-B1',
#   'EP240915-A',
#   'US6511773-B1',
#   'US20030165736-A1',
#   'EP2355203-A1',
#   'JP63143759-A',
#   'US20110189536-A1',
#   'EP472232-A',
#   'US6887620-B2',
#   'US20100283429-A1',
#   'WO2003021697-A3',
#   'JP2011071134-A',
#   'US20050031942-A1',
#   'US20090136834-A1',
#   'WO2008058685-A1'],
#  ['DE102004003760-A1',
#   'WO2010045041-A2',
#   'DE19713215-A1',
#   'WO2008133770-A1',
#   'US20090014065-A1',
#   'JP2002025350-A',
#   'US20070193624-A1',
#   'WO2009099517-A2'],
#  ['FR2521125-A',
#   'US4397924-A',
#   'US4042482-A',
#   'EP36105-A',
#   'US4432891-A',
#   'US4331750-A'],
#  ['US4084108-A',
#   'US4476475-A',
#   'US4487635-A',
#   'US3868654-A',
#   'EP147151-A',
#   'EP117339-A'],
#  [],
#  [],
#  [],
#  [],
#  ['JP08213562-A',
#   'US6323082-B1',
#   'US20030003651-A1',
#   'JP10107233-A',
#   'US6335248-B1',
#   'JP2000357784-A',
#   'JP2002134631-A',
#   'US6410399-B1',
#   'US6121651-A',
#   'JP2002124642-A',
#   'US6429068-B1',
#   'US6258659-B1',
#   'US6350653-B1',
#   'US6391706-B2',
#   'JP2002198501-A',
#   'US6553561-B2',
#   'JP2001237307-A',
#   'JP2001244327-A',
#   'US6391703-B1',
#   'JP02033969-A',
#   'JP2001044273-A'],
#  [],
#  [],
#  ['US5474949-A',
#   'US5290729-A',
#   'US5543347-A',
#   'US5390729-A',
#   'JP04252018-A',
#   'US5318920-A',
#   'US5387531-A',
#   'EP553791-A1',
#   'US5110752-A',
#   'US5466626-A',
#   'US5474950-A',
#   'US5427974-A',
#   'US5302540-A',
#   'EP630055-A2',
#   'US5182232-A',
#   'US5256587-A'],
#  ['CN102534622-A',
#   'CN101136978-A',
#   'CN202772145-U',
#   'CN102007599-A',
#   'CN101523616-A'],
#  ['KR2008064545-A', 'JP09036404-A', 'JP2009054722-A'],
#  ['JP2009200075-A', 'JP09063911-A', 'KR2009037363-A'],
#  ['US20160285077-A1',
#   'CN1663065-A',
#   'US20130337332-A1',
#   'US7241533-B1',
#   'JP2005044672-A',
#   'US20120160866-A1',
#   'TW201206826-A1',
#   'US20110262809-A1',
#   'US20150044513-A1',
#   'US20080118837-A1',
#   'JP2013131432-A',
#   'US7811709-B2',
#   'JP2007026926-A',
#   'WO2011065504-A1',
#   'US20080003503-A1',
#   'US20090239151-A1',
#   'US20140353546-A1',
#   'US20100119942-A1',
#   'US7195842-B1',
#   'US9325003-B2',
#   'JP2006202647-A',
#   'US9070935-B2',
#   'US20060051675-A1',
#   'US20100167126-A1',
#   'WO2012091060-A1',
#   'KR2012081987-A',
#   'JP2005011650-A',
#   'JP2004185984-A',
#   'JP2002083594-A',
#   'US20060115735-A1',
#   'US20150295228-A1',
#   'US7732095-B2',
#   'JP2012142154-A',
#   'EP1313158-A2',
#   'US9496065-B2',
# ...
#   'WO2013115390-A1',
#   'JP2013161785-A',
#   'WO2012161190-A1',
#   'US6680143-B2',
#   'US20150303450-A1',
#   'WO2013161445-A1',
#   'WO2013088846-A1',
#   'WO2010150513-A1',
#   'JP2009099328-A',
#   'KR2003041816-A',
#   'CN1714463-A',
#   'US20070148544-A1',
#   'CN101233632-A',
#   'US20070128517-A1',
#   'US20090098458-A1',
#   'WO2011065503-A1',
#   'EP2717357-A1',
#   'WO2013055646-A1',
#   'US20110183209-A1',
#   'JP2009224239-A',
#   'US20130288122-A1',
#   'WO2013145913-A1',
#   'US8221918-B2',
#   'US7192673-B1',
#   'EP2800176-A1',
#   'JP2011048969-A',
#   'US20120208087-A1',
#   'US20120301786-A1',
#   'JP2001196052-A',
#   'US7141187-B2',
#   'WO2012070306-A1',
#   'JP2006120324-A',
#   'WO2012000854-A1',
#   'JP2012094454-A',
#   'US20020071991-A1',
#   'WO2008086041-A1'],
#  [],
#  ['JP2005100891-A',
#   'JP2003183649-A',
#   'JP2004292804-A',
#   'JP2003342563-A',
#   'US7261917-B2',
#   'JP2004063192-A',
#   'US20040239245-A1',
#   'JP2006052363-A',
#   'JP2003183650-A',
#   'US7452485-B2',
#   'JP2004323576-A',
#   'JP2004197042-A',
#   'JP2004143398-A',
#   'US7423368-B2',
#   'US20040075386-A1'],
#  [],
#  ['WO2013018602-A1',
#   'JP2009028946-A',
#   'JP08234181-A',
#   'JP08179291-A',
#   'JP2017043058-A'],
#  ['JP83060530-A',
#   'WO2003075329-A2',
#   'FR2859820-A1',
#   'EP32211-A',
#   'US6110813-A',
#   'WO2001080300-A1',
#   'US20060043367-A1',
#   'JP2007507897-A',
#   'US6573161-B1',
#   'JP86070713-A',
#   'EP1083590-A1',
#   'EP90565-A',
#   'US20030040130-A1',
#   'US4476375-A',
#   'US7642205-B2',
#   'JP61056409-A',
#   'WO2003075329-A3',
#   'US20030160233-A1',
#   'US20070036994-A1',
#   'JP83010822-A'],
#  [],
#  ['US5256566-A',
#   'US6022786-A',
#   'US6316806-B1',
#   'US6184555-B1',
#   'US5198376-A',
#   'US5310698-A',
#   'US6057558-A',
#   'US6114730-A',
#   'US5430315-A',
#   'US4859621-A',
#   'US4414242-A',
#   'US6252277-B1',
#   'US6291310-B1',
#   'US6040600-A',
#   'US6020600-A',
#   'US4754310-A',
#   'US5885878-A',
#   'US5354701-A',
#   'US6316807-B1',
#   'US5148247-A',
#   'US6337499-B1',
#   'US5416736-A',
#   'US5366914-A',
#   'JP07099241-A',
#   'US20050167742-A1',
#   'US3930300-A',
#   'US6255190-B1',
#   'DE19748523-A1',
#   'WO1997029518-A1',
#   'US6984864-B2',
#   'JP02045973-A',
#   'US5122851-A',
#   'US4296429-A',
#   'US20030209750-A1',
#   'JP09036323-A',
#   'US5854500-A'],
#  [],
#  ['US20050212111-A1',
#   'WO2007144868-A1',
#   'US20050139644-A1',
#   'US20020069929-A1',
#   'US20080035669-A1',
#   'US20040237346-A1',
#   'US5804237-A',
#   'US20060280978-A1',
#   'US20030226356-A1',
#   'US20070259236-A1',
#   'US20070178335-A1'],
#  ['US20130327927-A1',
#   'US20150323385-A1',
#   'JP4741015-B2',
#   'US20090250594-A1',
#   'US20110074960-A1',
#   'KR2012029324-A',
#   'US20160274282-A1',
#   'US20120001285-A1',
#   'US20130240708-A1',
#   'KR2014029933-A'],
#  ['KR2010041486-A', 'KR540157-B1', 'WO2010083041-A1', 'KR2008052596-A'],
#  ['US20030153165-A1',
#   'US20070012241-A1',
#   'US20050028860-A1',
#   'US4094704-A',
#   'US5282902-A',
#   'US4430149-A',
#   'US20100147379-A1',
#   'US20080217622-A1',
#   'US20070065577-A1'],
#  [],
#  ['US20130011608-A1',
#   'CN102712140-A',
#   'US20140299844-A1',
#   'US9279918-B2',
#   'WO2009089137-A2',
#   'US20170101556-A1',
#   'US20160155967-A1',
#   'WO2012054165-A2',
#   'US8547015-B2',
#   'DE102013109898-A1',
#   'US20150192728-A1',
#   'US20120098421-A1',
#   'CN102574151-A',
#   'US20120038990-A1',
#   'CN103502855-A',
#   'CN103168259-A',
#   'US8427747-B2',
#   'US8557378-B2',
#   'US8808811-B2',
#   'US20100028564-A1',
#   'US20120313508-A1',
#   'US20110126968-A1',
#   'US7241437-B2',
#   'US20090087629-A1',
#   'US8469551-B2',
#   'US20130202867-A1',
#   'CN103155199-A',
#   'US20130193416-A1',
#   'US8692446-B2',
#   'CN102272973-A',
#   'US20120027945-A1',
#   'CN104379675-A',
#   'US20160001521-A1',
#   'US20100040842-A1',
#   'US20120099323-A1',
#   'WO2008128073-A3',
#   'US8343622-B2',
#   'US8538224-B2',
#   'US9541701-B2',
#   'WO2009085926-A3',
#   'US20130181242-A1'],
#  ['US20020071082-A1',
#   'US6645645-B1',
#   'US5703436-A',
#   'US20040012980-A1',
#   'US6107734-A',
#   'US5969474-A',
#   'US20040048688-A1',
#   'US5917280-A',
#   'US20050073251-A1',
#   'WO2004097954-A1',
#   'US7473410-B1',
#   'WO2005089288-A3',
#   'WO2001027910-A1',
#   'US20050173700-A1',
#   'US20020030440-A1',
#   'JP2003203769-A',
#   'JP59031865-A',
#   'US20050255334-A1',
#   'US6897473-B1',
#   'US20040191952-A1',
#   'US6555840-B1',
#   'US20030127973-A1',
#   'US20040214041-A1',
#   'US20030170491-A1',
#   'US20020098379-A1',
#   'US20030230980-A1',
#   'KR522687-B1',
#   'JP05034692-A',
#   'US6580027-B2',
#   'US6579422-B1',
#   'US7001536-B2',
#   'US20050040392-A1',
#   'US6573651-B2',
#   'US20040150330-A1',
#   'US20060065904-A1',
#   'US20050053801-A1',
#   'US6310360-B1',
#   'US20060038170-A1',
#   'WO2003088271-A1',
#   'US6979414-B2',
#   'US6337492-B1',
#   'US20070034860-A1',
#   'US7301167-B2',
#   'DE19916745-A1',
#   'GB2392023-A',
#   'US20050269943-A1',
#   'WO2002093664-A3',
#   'DE10209789-A1',
#   'US6303238-B1',
#   'US20040235209-A1',
#   'US20030178619-A1',
#   'US20060033115-A1',
#   'WO2004025615-A1',
#   'US20040183067-A1',
#   'JP2004119197-A',
#   'US20050040390-A1',
#   'US6023073-A',
#   'GB2390215-A',
#   'US20030020073-A1',
#   'US20040062949-A1',
#   'US20050218797-A1',
#   'US20060202196-A1',
#   'US6911666-B2',
#   'EP1282101-A1',
#   'US6835470-B1',
#   'US6566807-B1',
#   'WO2002037580-A1',
#   'US20040119400-A1',
#   'JP2005156925-A',
#   'US20070278479-A1',
#   'US20010033136-A1',
#   'US6965197-B2',
#   'GB2361356-A',
#   'JP07142169-A',
#   'US20080164807-A1',
#   'US5093698-A',
#   'US6274980-B1',
#   'US5757026-A',
#   'JP2000231992-A',
#   'US5500537-A',
#   'US6936961-B2',
#   'US20030042848-A1',
#   'WO2005089288-A2',
#   'US5989785-A',
#   'US20030148619-A1',
#   'US20040032220-A1',
#   'US20050086251-A1',
#   'DE10307125-A1',
#   'US6437769-B1',
#   'US6734457-B2',
#   'US6900588-B2',
#   'WO1999048160-A1',
#   'US20040227460-A1',
#   'JP2003297561-A',
#   'US20060061266-A1',
#   'US6908783-B1',
#   'US7161292-B2',
#   'US20050029933-A1',
#   'US20050061232-A1',
#   'US6589673-B1',
#   'US20040067324-A1',
#   'US6878297-B1',
#   'US20060250076-A1',
#   'JP2004234942-A',
#   'US20080203406-A1',
#   'US5811833-A',
#   'US20040251816-A1',
#   'US20090009072-A1',
#   'WO2005008801-A1',
#   'US20030189401-A1',
#   'US20050110009-A1',
#   'US20070051946-A1',
#   'EP1227466-A2',
#   'WO2003069958-A1',
#   'JP11283750-A',
#   'US6406804-B1',
#   'US20060273310-A1',
#   'TW200401017-A',
#   'US20020048688-A1',
#   'US6867538-B2',
#   'US6933522-B2',
#   'CA2549309-A1',
#   'US20050270279-A1',
#   'US20060238112-A1',
#   'US20060145365-A1',
#   'US6720573-B2',
#   'US20020041975-A1',
#   'US20040104394-A1',
#   'US20040027849-A1',
#   'US20040201018-A1',
#   'US20030146443-A1',
#   'US4769292-A',
#   'EP1318499-A2',
#   'JP2004214120-A',
#   'US20050118745-A1',
#   'US20030098946-A1',
#   'US7074500-B2',
#   'US20090009071-A1',
#   'GB2388236-A',
#   'US20020084993-A1',
#   'US5840217-A',
#   'US20030052616-A1',
#   'JP03208689-A',
#   'US20050095736-A1',
#   'US20060232992-A1',
#   'WO2004059606-A3',
#   'US20080143250-A1',
#   'US6872969-B2',
#   'US20060231843-A1',
#   'US20040113547-A1',
#   'US4356429-A',
#   'US20020109136-A1',
#   'DE10229231-A1',
#   'US20050189875-A1'],
#  [],
#  ['WO2016017393-A1',
#   'US6143443-A',
#   'JP2005298870-A',
#   'JP2007311209-A',
#   'CN105474446-A',
#   'JP09507950-W',
#   'JP01316481-A',
#   'WO2015019974-A1',
#   'US20160013506-A1',
#   'JP2002367657-A',
#   'WO2015019973-A1',
#   'US20150017494-A1',
#   'JP71038745-B1',
#   'US20040191623-A1',
#   'CN104641018-A',
#   'CN1515045-A',
#   'JP71038745-B',
#   'CN105009344-A'],
#  [],
#  ['CN103681942-A',
#   'CN103107212-A',
#   'CN102299200-A',
#   'CN103456843-A',
#   'CN101241861-A',
#   'CN1477913-A',
#   'CN103022163-A'],
#  ['US20090179254-A1',
#   'US20110027956-A1',
#   'US8120095-B2',
#   'US20130092989-A1',
#   'US20080296661-A1',
#   'US9356035-B2',
#   'US7939863-B2',
#   'US7825444-B2',
#   'US20120115292-A1',
#   'US20040110390-A1',
#   'US7514323-B2',
#   'US8502299-B2',
#   'US8409950-B1',
#   'US20130178031-A1',
#   'US8861271-B1',
#   'US6949787-B2',
#   'US20120126305-A1',
#   'US7504704-B2',
#   'US20080296664-A1',
#   'US20100032771-A1',
#   'US20090086548-A1',
#   'US6946349-B1',
#   'US20050205859-A1',
#   'US7666703-B2',
#   'US7811887-B2',
#   'US20150041881-A1',
#   'US8796098-B1',
#   'US20070087503-A1',
#   'US20050245081-A1',
#   'US7390718-B2',
#   'US7972929-B2',
#   'US20100096685-A1',
#   'US7651915-B2',
#   'US6251744-B1',
#   'US20090104780-A1',
#   'US7678662-B2',
#   'US8158478-B2',
#   'US20140239374-A1',
#   'US8022459-B2',
#   'US20090032880-A1',
#   'US8071453-B1',
#   'US20060158538-A1',
#   'US8093128-B2',
#   'US20070132054-A1',
#   'US20080090350-A1',
#   'US20110175160-A1',
#   'US8236709-B2',
#   'US20080293207-A1',
#   'US9620516-B2',
#   'US20080296693-A1',
#   'US7816728-B2',
#   'US20160260730-A1',
#   'CN102044424-A'],
#  ['US20090209050-A1', 'US20120074511-A1'],
#  [],
#  ['US20130149605-A1',
#   'US5503948-A',
#   'US8190384-B2',
#   'CN103151492-A',
#   'US20100035152-A1',
#   'US20110111304-A1',
#   'US20120058380-A1',
#   'US20140333317-A1',
#   'US20120041698-A1'],
#  ['CN107482014-A; WO2019007009-A1; CN107482014-B; US2020119033-A1; US11011534-B2',
#   'US20120056175-A1',
#   'CN105206615-A',
#   'CN102593065-A',
#   'US20130264632-A1',
#   'CN106560928-A',
#   'CN102623459-A'],
#  [],
#  ['US6537869-B1',
#   'US6528844-B1',
#   'US6165845-A',
#   'US6656854-B2',
#   'US6573153-B2',
#   'US6171906-B1',
#   'US6479859-B2'],
#  ['CN102169923-A', 'CN205452299-U', 'CN104412394-A', 'CN105322043-A'],
#  ['US5605550-A',
#   'US20100291443-A1',
#   'US20080286649-A1',
#   'US20050170255-A1',
#   'US20100075225-A1',
#   'US20090246636-A1',
#   'US20050132562-A1',
#   'US8778546-B2',
#   'US20090239132-A1',
#   'US20050026037-A1',
#   'US7449033-B2',
#   'US20100291444-A1',
#   'US20060036064-A1',
#   'US20060063074-A1',
#   'US20040161667-A1',
#   'US20070190407-A1'],
#  [],
#  ['JP2002057116-A', 'JP2001247396-A', 'US20010044163-A1'],
#  ['US20100275984-A1',
#   'WO2009030299-A2',
#   'JP2006073617-A',
#   'US20110005582-A1',
#   'US20100317146-A1',
#   'WO2009071561-A2',
#   'US20040200520-A1',
#   'DE102006046726-A1',
#   'US20090223562-A1',
#   'DE102007041392-A1',
#   'US20060054937-A1'],
#  ['US6338913-B1',
#   'US20140272595-A1',
#   'US20080290022-A1',
#   'WO2008030215-A2',
#   'US20130157147-A1',
#   'US20130337189-A1',
#   'US20110045349-A1',
#   'US20150044517-A1',
#   'US20140308585-A1',
#   'US20090317723-A1',
#   'US20020009635-A1',
#   'US20110006738-A1',
#   'US20050256290-A1',
#   'US20090029261-A1',
#   'US20080209876-A1'],
#  ['US5112408-A',
#   'US5180442-A',
#   'US5575861-A',
#   'US20120052614-A1',
#   'US20120118355-A1',
#   'CN101138096-A',
#   'US5741370-A',
#   'US20070251567-A1',
#   'WO2009137348-A2',
#   'GB2453723-A',
#   'US4830038-A',
#   'US20090159118-A1'],
#  [],
#  [],
#  ['US20070090336-A1',
#   'US20030161195-A1',
#   'US20070053221-A1',
#   'US20080121862-A1',
#   'US20060181895-A1',
#   'US20040113232-A1',
#   'US20040142557-A1',
#   'US20040234895-A1',
#   'US20060138393-A1'],
#  [],
#  ['DE102009049704-A1',
#   'EP1024369-A1',
#   'US20030117155-A1',
#   'US20070018674-A1',
#   'US20100117671-A1',
#   'US7064565-B1',
#   'US20110003404-A1',
#   'US7649365-B1',
#   'DE102008019703-A1',
#   'CN101943744-A',
#   'DE4412297-A1',
#   'EP1274760-B1',
#   'DE102009049806-A1',
#   'JP2002164557-A',
#   'US20010040453-A1',
#   'WO2001077203-A3',
#   'US20100045265-A1',
#   'US20070246094-A1',
#   'JP2005236051-A',
#   'US20100304512-A1',
#   'US20110148432-A1'],
#  [],
#  ['US5190834-A',
#   'CA2408587-A1',
#   'JP2001319665-A',
#   'US6680139-B2',
#   'US20040209136-A1',
#   'CA2408588-A1',
#   'JP2002141084-A',
#   'US5861221-A',
#   'US5587253-A',
#   'CA2408588-C',
#   'JP2001319664-A',
#   'US20040081878-A1',
#   'US5310765-A',
#   'US20030104273-A1',
#   'CA2446121-A1',
#   'US5989741-A',
#   'US20030162076-A1',
#   'US20030049516-A1',
#   'CA2408538-C',
#   'US20040053100-A1',
#   'US20070166590-A1',
#   'JP2004152761-A',
#   'EP1291944-A1',
#   'CA2408538-A1',
#   'CA2408587-C'],
#  [],
#  ['US3929529-A',
#   'US4231809-A',
#   'US4929564-A',
#   'US4637123-A',
#   'US4053335-A',
#   'US4410395-A',
#   'US4314595-A',
#   'US4732874-A',
#   'JP63136531-A',
#   'US4994399-A'],
#  ['JP55148775-A',
#   'US4345986-A',
#   'WO2013191140-A1',
#   'JP59173281-A',
#   'RU2532561-C2',
#   'CN103261485-A'],
#  [],
#  [],
#  [],
#  [],
#  ['US5930623-A', 'US6037211-A'],
#  ['WO2007084776-A2',
#   'US20030012994-A1',
#   'US20030012995-A1',
#   'WO2006004957-A2',
#   'US20020012825-A1',
#   'US20040191594-A1'],
#  [],
#  ['CN104134707-A', 'US20090293948-A1', 'CN103021492-A', 'CN103646983-A'],
#  [],
#  ['US8450779-B2',
#   'US20120074387-A1',
#   'TW201201340-A',
#   'US20110296368-A1',
#   'US20050235232-A1',
#   'WO2012010934-A1',
#   'US20110114919-A1',
#   'US20110067029-A1',
#   'US20120181510-A1',
#   'US20110191776-A1',
#   'US20040172603-A1',
#   'US20120181508-A1',
#   'US20050204316-A1'],
#  ['US20110200848-A1',
#   'US20160218375-A1',
#   'US20130065122-A1',
#   'US9786944-B2',
#   'US20170214034-A1',
#   'US9362583-B2',
#   'US8722226-B2',
#   'US20160042877-A1',
#   'US20160056491-A1',
#   'US9831519-B2',
#   'US20170033389-A1',
#   'US20170025646-A1',
#   'US9401501-B2',
#   'US20190245242-A1',
#   'US20030194605-A1',
#   'US9437864-B2',
#   'US10411310-B2',
#   'US8778552-B2',
#   'US8722227-B2',
#   'US20140315097-A1',
#   'US8993159-B2',
#   'US20140154546-A1',
#   'US20150171406-A1',
#   'US10181587-B2',
#   'US20110189520-A1',
#   'US20150129081-A1',
#   'US20150140371-A1',
#   'US20140170524-A1',
#   'US20150357626-A1',
#   'US20170025674-A1',
#   'US20160056490-A1',
#   'US20180287220-A1',
#   'US20160028071-A1',
#   'US20170237111-A1',
#   'US20160105042-A1',
#   'US20100047671-A1',
#   'US9614231-B2',
#   'US20160308218-A1',
#   'US20140039710-A1',
#   'US20150024279-A1',
#   'US20170288281-A1',
#   'US20100323264-A1',
#   'US20160133916-A1',
#   'US20140030623-A1',
#   'US9583780-B2',
#   'US20170237112-A1',
#   'US20150295272-A1',
#   'US9812674-B2',
#   'US20140248521-A1',
#   'US20130055559-A1',
#   'US20180175428-A1',
#   'US10153651-B2',
#   'US9831518-B2',
#   'US9184464-B2',
#   'US20160372802-A1',
#   'US9178200-B2',
#   'US20180233722-A1',
#   'US20160013507-A1',
#   'US10115970-B2',
#   'US20170077464-A1',
#   'US20180034090-A1',
#   'US20160190544-A1',
#   'US9153833-B2',
#   'US20170033390-A1',
#   'US9385392-B2',
#   'US10122044-B2',
#   'US20180233708-A1',
#   'US20190058184-A1',
#   'US20180175445-A1',
#   'US9831522-B2',
#   'US20190036101-A1',
#   'US20130337319-A1',
#   'US9203092-B2',
#   'US9293781-B2',
#   'US20160126543-A1',
#   'US20170018798-A1',
#   'US20120164499-A1',
#   'US20140004437-A1',
#   'US20110274948-A1',
#   'US10236518-B2',
#   'US20170162863-A1',
#   'US9484569-B2',
#   'US20160268621-A1',
#   'US10230128-B2',
#   'US20130309547-A1',
#   'US20150280267-A1'],
#  ['US5541425-A',
#   'US4893160-A',
#   'US5072266-A',
#   'US5929481-A',
#   'US5442214-A',
#   'US5866931-A',
#   'US6084268-A',
#   'JP06021468-A'],
#  ['US20020097205-A1',
#   'US20050023267-A1',
#   'US4654502-A',
#   'US6639189-B2',
#   'US6027244-A',
#   'US7115837-B2',
#   'US7317175-B2',
#   'US6461036-B1',
#   'US5433368-A',
#   'US20060086713-A1',
#   'US6483083-B2',
#   'US6034357-A',
#   'US4460821-A',
#   'US4924073-A',
#   'US7094993-B2',
#   'US4517448-A',
#   'US20080012499-A1',
#   'US6965093-B2',
#   'US6093911-A',
#   'US4565917-A',
#   'US5650082-A',
#   'US7112763-B2',
#   'US4833301-A',
#   'US4876437-A',
#   'US6501051-B1',
#   'US20100220983-A1',
#   'US6876816-B2',
#   'US6301434-B1',
#   'US6825615-B2',
#   'US5790750-A',
#   'US20050136623-A1',
#   'US20010030184-A1',
#   'US6288368-B1',
#   'US20030085216-A1',
#   'US5315092-A',
#   'US5387546-A',
#   'US6903306-B2',
#   'US4477718-A',
#   'US5409155-A',
#   'US4640224-A',
#   'US6190040-B1',
#   'US5577157-A',
#   'US6204483-B1',
#   'US20070116860-A1',
#   'US7170036-B2',
#   'US5481087-A',
#   'US4649261-A',
#   'US6299346-B1',
#   'US5048719-A',
#   'US20100267188-A1',
#   'US4997364-A',
#   'US7075037-B2',
#   'US6566630-B2',
#   'US20010027971-A1',
#   'US5042895-A',
#   'US5325601-A',
#   'US6410888-B2',
#   'US6375348-B1',
#   'US5020411-A',
#   'US6259062-B1',
#   'US5951896-A',
#   'US20100272544-A1',
#   'US6247830-B1',
#   'US6183127-B1',
#   'US6717158-B1',
#   'US5259546-A',
#   'US6018144-A',
#   'US6072160-A',
#   'US6265696-B1',
#   'US5194401-A',
#   'US4698486-A',
#   'US20020150395-A1',
#   'US6437290-B1',
#   'US4406944-A',
#   'US6849831-B2',
#   'US5059013-A',
#   'US5740314-A',
#   'US5452396-A',
#   'US20010025841-A1',
#   'US7041931-B2',
#   'US6655946-B2',
#   'US6376804-B1',
#   'US20070131671-A1',
#   'US7737385-B2',
#   'US6310327-B1',
#   'US5607609-A',
#   'US20020030047-A1',
#   'US20040079746-A1',
#   'US5960158-A',
#   'US5997175-A',
#   'US6426486-B1',
#   'US4245613-A',
#   'US7618599-B2',
#   'US7805064-B2',
#   'US5864119-A',
#   'US6529686-B2',
#   'WO2006059387-A1',
#   'US6331212-B1',
#   'US6495800-B2',
#   'US4436985-A'],
#  ['CN106104806-A', 'CN107580725-A', 'US20070181909-A1']]

# %%
PN=data['PN']

#pn的列表
pn_list=[]
for pn in PN:
    pn=pn.split(';')
    pn=list(set([i.strip() for i in pn])) #去除每个元素两端的空格
    pn_list.append(pn)

# %%
data.columns
# Out:
# Index(['index', 'PN', 'TI', 'AB', 'AU', 'AE', 'CP', 'TM', 'IPC', 'IPClass',
#        'class1', 'class3', 'class4', 'newClass'],
#       dtype='object')

# %%
from tqdm import tqdm #导入了 tqdm 库，用于在循环中显示进度条，提供了对处理进度的可视化

relationList=[]
for i in tqdm(range(len(data))):
#for i in range(10):
    #print(i)
    #生成四种关系的三元组
    #专利-专利
    if cp_list[i]!=[]:
        for cp in cp_list[i]: 
            relationList.append(data['PN'][i]+'\t'+'patent_patent'+'\t'+cp)
    #专利-权利人
    #权利人-权利人
    if data['AE'][i]!='':
        ae_list=data['AE'][i].split(';')
        ae_list=[i.strip() for i in ae_list]
        ae_list=list(set(ae_list)) #获得不重复的所有权利人的列表

        for ae in ae_list:
            relationList.append(data['PN'][i]+'\t'+'patent_author'+'\t'+ae)
        for a in range(len(ae_list)):
            for b in range(len(ae_list)):
                if a<b:
                    relationList.append(ae_list[a]+'\t'+'author_author'+'\t'+ae_list[b])
    #专利-年份
    relationList.append(data['PN'][i]+'\t'+'patent_year'+'\t'+str(data['TM'][i]).strip())
    #专利-国家
    for pn in pn_list[i]:
        relationList.append(data['PN'][i]+'\t'+'patent_nation'+'\t'+pn[:2]) #表示获取 pn 中的前两个字符，即国家代码
    

#然后存成txt文件
with open(r'/root/autodl-tmp/transX/data/val_test.txt','w') as fp:
    for i in range(len(relationList)):
        fp.write(relationList[i])
        fp.write('\n')
# Out:
# 100%|██████████| 256/256 [00:00<00:00, 6357.94it/s]

# %%
len(data['PN'])
# Out:
# 256

# %%
len(relationList)
# Out:
# 5516
