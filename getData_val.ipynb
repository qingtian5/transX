# %%
#把数据处理成transX输入的格式
import pandas as pd
data=pd.read_excel(r'/root/autodl-tmp/模型代码/DeepModel_Gui/val_df.xlsx')
data.head()
# Out:
#    index                                                 PN  \
# 0  42867                                      CN112018100-A
# 1  52870                     US2020335599-A1; US11282940-B2
# 2  32342  US9960170-B1; US2018122811-A1; CN108010882-A; ...
# 3  10972                       CN113629157-A; CN216563147-U
# 4  24535  WO2012138576-A1; TW201314997-A; AU2012240401-A...
#
#                                                   TI  \
# 0  Silicon/perovskite laminated solar cell, has  ...
# 1  Semiconductor structure used for fabricating h...
# 2  Method for fabricating semiconductor memory de...
# 3  Solar cell contact structure useful in battery...
# 4  Electrochemical power system, useful to genera...
#
#                                                   AB  \
# 0  NOVELTY - The solar cell has a silicon cell i....
# 1  NOVELTY - A semiconductor structure comprises ...
# 2  NOVELTY - The method involves forming a mask p...
# 3  NOVELTY - Solar cell contact structure compris...
# 4  NOVELTY - The electrochemical power system com...
#
#                                                   AU  \
# 0                                       MAO L;TANG Z
# 1              LIN C;LAM K T;YEONG S;CHUI C O;FANG Z
# 2  KIM D;LEE K;KIM K;KIM B;PARK J;YOON C;HWANG Y;...
# 3                   CHEN G;YANG X;WANG Y;LIN W;QIU K
# 4      MILLS R L;MILLS R;RANDELL L M;MILLS RANDELL L
#
#                                                   AE  \
# 0  BEIJING HONGTAI INNOVATION TECHNOLOGY CO (HANH-C)
# 1  TAIWAN SEMICONDUCTOR MFG CO LTD (TSMC-C);TAIWA...
# 2  SAMSUNG ELECTRONICS CO LTD (SMSU-C);SAMSUNG EL...
# 3  TIANJIN AIKO SOLAR ENERGY TECHNOLOGY CO (TIAN-...
# 4  BLACKLIGHT POWER INC (BLAC-Non-standard);BLACK...
#
#                                                   CP      TM  \
# 0                                                NaN  2020.0
# 1     US11282940-B2:US20160372478-A1--[EOL]--US20...  2020.0
# 2  US9960170-B1:US20090057778-A1--[EOL]--US201600...  2018.0
# 3                                                NaN  2021.0
# 4  WO2012138576-A1:US20090098421-A1--[EOL]--WO201...  2012.0
#
#                                                  IPC  \
# 0  H01L-025/16; H01L-031/075; H01L-031/076; H01L-...
# 1  H01L-021/28; H01L-021/768; H01L-029/49; H01L-0...
# 2  H01L-021/8242; H01L-027/108; H01L-021/8238; H0...
# 3  H01L-031/02; H01L-031/0216; H01L-031/0224; H01...
# 4  H01M-014/00; H01M-004/86; H01M-004/94; H01M-00...
#
#                                              IPClass                class1  \
# 0  ['H01L-025/16', ' H01L-031/075', ' H01L-031/07...                 ['H']
# 1  ['H01L-021/28', ' H01L-021/768', ' H01L-029/49...                 ['H']
# 2  ['H01L-021/8242', ' H01L-027/108', ' H01L-021/...                 ['H']
# 3  ['H01L-031/02', ' H01L-031/0216', ' H01L-031/0...                 ['H']
# 4  ['H01M-014/00', ' H01M-004/86', ' H01M-004/94'...  ['B', 'H', 'C', 'G']
#
#                                        class3  \
# 0                                     ['H01']
# 1                                     ['H01']
# 2                                     ['H01']
# 3                                     ['H01']
# 4  ['H01', 'C25', 'H04', 'C01', 'G21', 'B01']
#
#                                               class4          newClass
# 0                                           ['H01L']          ['H01L']
# 1                                           ['H01L']          ['H01L']
# 2                                           ['H01L']          ['H01L']
# 3                                           ['H01L']          ['H01L']
# 4  ['C01B', 'B01J', 'G21B', 'H04M', 'C25B', 'G21D...  ['C01B', 'H01M']

# %%
CP=data['CP']

cp_list=[]
for cp in CP:
    if pd.isna(cp): #是否是缺失值NAN
        cp_list.append([])
        continue
    else:
        List1=cp.split('**[EOP]**')
        #print(List1)
        List1=[l[l.index(':')+1:] for l in List1]#对 List1 中的每个元素，从第一个冒号 ':' 的位置开始截取子字符串，去除冒号及之前的部分
        List2=[i.split('--[EOL]--') for i in List1]
        List=[j for i in List2 for j in i] #将二维列表 List2 扁平化为一维列表 List
        List=[i for i in List if i!='']
        List=[i.split()[0] for i in List]
        
        List=list(set(List))
        cp_list.append(List)

# %%
#看一下cp_list里的每个元素，找pn_list的对应的元素
from tqdm import tqdm #导入了 tqdm 库，用于在循环中显示进度条，提供了对处理进度的可视化

for i in tqdm(range(len(cp_list))):
    for j in range(len(cp_list[i])):
        for pn in data['PN']:
            if cp_list[i][j] in pn:
                cp_list[i][j]=pn
# Out:
# 100%|██████████| 5577/5577 [01:47<00:00, 52.02it/s]

# %%
cp_list
# Out:
# [[],
#  ['US20170141235-A1',
#   'US20030157766-A1',
#   'US9349833-B1',
#   'US20180337055-A1',
#   'US20160372478-A1',
#   'US20190019875-A1',
#   'US9978868-B2'],
#  ['US20160079246-A1',
#   'KR2015088634-A',
#   'US9082647-B2',
#   'US2013026564-A1; US8557664-B2',
#   'JP2012054291-A',
#   'KR2015121767-A',
#   'US9305928-B2',
#   'US20140246729-A1',
#   'US20090057778-A1',
#   'CN101009243-A',
#   'US20050186741-A1',
#   'US8536009-B2',
#   'KR2014110146-A',
#   'KR2015051513-A',
#   'US20160148934-A1',
#   'US20160163708-A1',
#   'KR2016067618-A',
#   'US20150303201-A1',
#   'US8357600-B2'],
#  [],
#  ['WO2010014684-A2',
#   'WO2008134451-A1',
#   'WO2011006878-A1',
#   'WO2011116236-A2',
#   'JP2005504956-A',
#   'JP2012505810-A',
#   'US4377625-A',
#   'JP2001511429-A',
#   'US20090148731-A1',
#   'WO2010014684-A8',
#   'US20090098421-A1'],
#  [],
#  ['US20050191821-A1',
#   'US5216275-A',
#   'US5786769-A',
#   'US20030146470-A1',
#   'US20050006699-A1',
#   'US20030057481-A1',
#   'US6590240-B1',
#   'US6184555-B1',
#   'US6475864-B1',
#   'US6362505-B1'],
#  ['JP01045161-A',
#   'EP395084-A',
#   'US5502009-A',
#   'EP85551-A',
#   'JP07142614-A',
#   'US5576226-A',
#   'JP02028380-A',
#   'JP05335591-A',
#   'US5432114-A',
#   'US4833096-A',
#   'JP01293631-A',
#   'US5550078-A',
#   'US4859619-A',
#   'EP395084-A3',
#   'JP01089457-A',
#   'US5254489-A',
#   'JP04199683-A',
#   'US5393683-A',
#   'JP08306809-A',
#   'EP154670-A',
#   'US4780424-A'],
#  [],
#  ['JP2004063433-A',
#   'JP2005243431-A',
#   'JP2002093415-A',
#   'JP2005310759-A',
#   'JP2002298842-A',
#   'JP2003197191-A',
#   'JP2004047404-A',
#   'JP2002231225-A',
#   'JP2004119176-A',
#   'JP2000268879-A',
#   'JP2006244813-A',
#   'JP2000173667-A'],
#  [],
#  [],
#  ['KR2012090394-A',
#   'JP2016197744-A',
#   'CN103346211-A',
#   'CN104916709-A',
#   'CN105789342-A',
#   'WO2014206240-A1',
#   'CN106449982-A'],
#  ['US6299742-B1',
#   'US7458384-B1',
#   'US7623340-B1',
#   'US20100038263-A1',
#   'US20060133982-A1',
#   'US5059407-A',
#   'US7732859-B2',
#   'US3748282-A',
#   'US6676920-B1',
#   'US7785492-B1',
#   'US20090068470-A1',
#   'US7601321-B2',
#   'US7718155-B2',
#   'US4368182-A',
#   'US7357903-B2',
#   'US6805832-B2',
#   'US7666915-B2',
#   'US4943301-A',
#   'US20090075847-A1',
#   'US7514489-B2',
#   'US7662321-B2',
#   'US4188192-A',
#   'US20090020764-A1',
#   'US20090075083-A1',
#   'US20090110627-A1',
#   'US20100176337-A1',
#   'US20090033164-A1',
#   'US6936233-B2',
#   'US5855678-A',
#   'US6819034-B1',
#   'US5279716-A',
#   'US7601668-B2',
#   'US20090082474-A1',
#   'US7718156-B2',
#   'US20100044646-A1',
#   'US20080269086-A1',
#   'US6143689-A',
#   'US7670588-B2',
#   'US7060246-B2',
#   'US3915657-A',
#   'US20080118407-A1',
#   'US4192758-A',
#   'US20080279755-A1',
#   'US5989517-A',
#   'US20100024542-A1',
#   'US7071258-B1',
#   'US7540890-B2',
#   'US20100000441-A1',
#   'US6130282-A',
#   'US6043306-A',
#   'US20090298684-A1'],
#  [],
#  ['JP2010232513-A',
#   'KR1487962-B1',
#   'KR2013056115-A',
#   'KR1145898-B1',
#   'JP2010238727-A'],
#  [],
#  ['KR2008024559-A',
#   'CN101080842-A',
#   'WO2004044948-A2',
#   'US20080041446-A1',
#   'US20040115858-A1',
#   'KR2007048527-A'],
#  [],
#  [],
#  ['US20160109799-A1',
#   'CN101581879-A',
#   'US20150291815-A1',
#   'US20100109201-A1',
#   'KR1017403-B1',
#   'US20150283846-A1',
#   'US20110064925-A1',
#   'US20050255237-A1',
#   'CN103328176-A',
#   'CN101477304-A',
#   'US20080182072-A1',
#   'CN102135728-A',
#   'US20150140837-A1',
#   'EP2904058-A1',
#   'US20140072720-A1'],
#  [],
#  ['KR2010126986-A', 'KR1012123-B1', 'US20040084080-A1', 'US20060046504-A1'],
#  [],
#  ['KR2013056941-A'],
#  [],
#  ['CN105428450-A; CN105428450-B', 'CN108922941-A'],
#  [],
#  ['US20100167012-A1', 'CN101960919-A', 'CN1786747-A', 'CN1941421-A'],
#  ['US20130008603-A1',
#   'US20040261720-A1',
#   'US20170069464-A1',
#   'EP855452-A1',
#   'WO2005103333-A2'],
#  ['WO2006057146-A3',
#   'US20090117022-A1',
#   'JP2006511038-A',
#   'US6702961-B2',
#   'WO2003038930-A2',
#   'US20120012797-A1',
#   'JP2006516172-A',
#   'DE102005015613-A1',
#   'US20030082454-A1',
#   'CN1547273-A',
#   'JP2008293661-A',
#   'US20140147586-A1',
#   'WO2006097324-A2',
#   'JP2008130526-A',
#   'US20080241043-A1',
#   'WO2007049815-A2',
#   'US20090233096-A1',
#   'US6203946-B1',
#   'DE102005012640-A1',
#   'WO2007093856-A1',
#   'JP2006331992-A',
#   'WO2009127674-A1'],
#  ['KR2010096819-A; KR1578356-B1', 'CN101447528-A', 'CN102437246-A'],
#  ['WO2014064126-A1',
#   'DE10326546-A1',
#   'US20100062550-A1',
#   'US20120205709-A1',
#   'DE102007009530-A1',
#   'US20150144899-A1'],
#  ['US5770484-A',
#   'US5959322-A',
#   'US6724046-B2',
#   'US5525531-A',
#   'US6858491-B1',
#   'US6855976-B2',
#   'US20020064913-A1',
#   'US6399447-B1',
#   'US6566177-B1',
#   'US6635915-B2'],
#  ['US5545578-A',
#   'JP11261059-A',
#   'JP2001036072-A',
#   'US6448140-B1',
#   'US6458646-B1',
#   'US6417084-B1'],
#  ['CN101023516-A',
#   'US20080029027-A1',
#   'WO2007058365-A1',
#   'CN1881577-A',
#   'US5886229-A',
#   'US20060286814-A1',
#   'US6100202-A',
#   'US5646075-A',
#   'GB2434376-A',
#   'US20080038585-A1',
#   'WO1998028463-A1',
#   'EP1788119-A1'],
#  ['US20090302300-A1',
#   'US7422926-B2',
#   'US6661330-B1',
#   'US20090115020-A1',
#   'US20070075347-A1',
#   'US20080128677-A1',
#   'US8110822-B2',
#   'US20110215436-A1',
#   'US20100107403-A1',
#   'US7169624-B2',
#   'US7838341-B2',
#   'US4987099-A',
#   'US8723155-B2',
#   'US20060076548-A1',
#   'US7785978-B2',
#   'US20100165719-A1',
#   'US6764894-B2',
#   'US20110155984-A1',
#   'US8822969-B2',
#   'US20060186440-A1',
#   'US7332401-B2',
#   'US7638787-B2',
#   'US8013319-B2',
#   'US20040178425-A1',
#   'US20060113520-A1',
#   'US20080138929-A1',
#   'WO2013074353-A1',
#   'US7646631-B2',
#   'US6692898-B2',
#   'US7867832-B2',
#   'US20090127538-A1',
#   'US20080043520-A1',
#   'US20110284815-A1',
#   'US7888711-B2',
#   'US20080157053-A1',
#   'US20090147564-A1',
#   'US7803655-B2',
#   'US20080067486-A1',
#   'US20100001248-A1',
#   'US7719039-B2',
#   'US20100072453-A1',
#   'WO2014123661-A1',
#   'US20090166601-A1',
#   'US20070012905-A1',
#   'US20110300685-A1',
#   'US20120241705-A1',
#   'US7915602-B2',
#   'US20020177292-A1',
#   'US6815704-B1',
#   'US20070224726-A1',
#   'US20130099888-A1',
#   'US6143670-A',
#   'US20050117397-A1',
#   'US20070029676-A1',
#   'US5055423-A',
#   'US7800092-B2',
#   'US20110031461-A1',
#   'US6664182-B2',
#   'US20100207168-A1',
#   'US20050006681-A1',
#   'US20100001253-A1',
#   'US20080067485-A1',
#   'US20100301417-A1',
#   'US20020017701-A1',
#   'US20090039333-A1',
#   'US20110092041-A1',
#   'US20100054029-A1',
#   'US20100270529-A1',
#   'US20080137400-A1',
#   'US7148140-B2',
#   'US7974115-B2',
#   'US20090091971-A1',
#   'US8486743-B2',
#   'WO2013039496-A1; US2013256624-A1; TW201332173-A; KR2014053325-A; JP2014530491-W; TW479708-B1; KR2015129060-A; JP5858350-B2; US9287498-B2; US2016149127-A1; KR1699713-B1; US9698344-B2',
#   'US20100065530-A1',
#   'US20100213431-A1',
#   'US6611453-B2',
#   'US20040188668-A1',
#   'US20130126822-A1',
#   'US20070158698-A1',
#   'US20090298222-A1',
#   'US7453111-B2',
#   'US20100151652-A1',
#   'US20100163833-A1',
#   'US6613604-B2',
#   'US20080101109-A1',
#   'US20120256151-A1',
#   'US20130285002-A1',
#   'US4849247-A',
#   'US20110193049-A1',
#   'US20110074538-A1',
#   'US20090008621-A1',
#   'US20090321706-A1',
#   'US4752118-A',
#   'US20070108431-A1',
#   'US20080197394-A1',
#   'US20060286709-A1',
#   'WO2010073904-A1',
#   'US7935553-B2',
#   'US20100327251-A1',
#   'US20090194757-A1',
#   'US20050110983-A1',
#   'US20070235708-A1',
#   'US20020173101-A1',
#   'US20080093703-A1',
#   'US20110312178-A1',
#   'US20070279974-A1',
#   'US8546231-B2',
#   'US20100301304-A1',
#   'US20100072447-A1',
#   'US20080105862-A1',
#   'US20090072213-A1',
#   'US6700211-B2',
#   'US7772680-B2',
#   'WO2005041196-A1',
#   'US20080054470-A1',
#   'US20060284279-A1',
#   'US20070054486-A1',
#   'US5912839-A',
#   'US8507353-B2',
#   'US20090230505-A1',
#   'US20100323490-A1',
#   'US20130126816-A1',
#   'US7919766-B2',
#   'US20070075359-A1',
#   'US20130277796-A1',
#   'US20140117302-A1',
#   'US20100176368-A1',
#   'US8614433-B2',
#   'US8765555-B2',
#   'US20090194758-A1',
#   'US5341328-A',
#   'US20090032794-A1',
#   'US20140217350-A1',
#   'US7773413-B2',
#   'US20090108247-A1',
#   'US20100176911-A1',
#   'US20090017577-A1',
#   'US20090101883-A1',
#   'US20100055830-A1',
#   'US5166758-A',
#   'US20100301303-A1',
#   'US20100163830-A1',
#   'US20110001114-A1',
#   'US20100019221-A1',
#   'US20120256150-A1',
#   'US20060073652-A1',
#   'US20100221874-A1',
#   'US20100308296-A1',
#   'US5895963-A',
#   'US20090072341-A1',
#   'US7619933-B2',
#   'US20060157682-A1'],
#  ['US4646115-A',
#   'US4045248-A',
#   'US4063964-A',
#   'US5405794-A',
#   'US20040178444-A1',
#   'US7446374-B2',
#   'US20090035900-A1',
#   'US6351018-B1',
#   'US20070221952-A1',
#   'US4134123-A',
#   'US6825105-B2',
#   'US6921957-B2',
#   'US7952139-B2'],
#  ['CN102543271-A',
#   'CN105624625-A',
#   'CN109136869-A',
#   'CN102779944-A',
#   'CN108914077-A',
#   'CN104616726-A',
#   'CN111593320-A',
#   'JP2005314131-A',
#   'CN101752454-A',
#   'CN106637204-A',
#   'CN108385072-A',
#   'CN111593310-A',
#   'JP06068713-A',
#   'CN107254664-A',
#   'CN102134699-A'],
#  ['US4502208-A', 'US4763180-A', 'US4364074-A', 'US4200968-A'],
#  ['WO2017052565-A1',
#   'US20140269002-A1',
#   'US20170243924-A1',
#   'WO2018031217-A1',
#   'US20130001494-A1'],
#  [],
#  ['CN101232055-A', 'CN101404296-A', 'CN101431127-A'],
#  ['CN102208457-A',
#   'CN102800740-A',
#   'TW201245312-A',
#   'EP2184785-A1',
#   'WO2012021750-A1'],
#  [],
#  ['US7391153-B2', 'US7202558-B2', 'US20060076571-A1'],
#  [],
#  [],
#  ['JP95122282-A',
#   'JP2007250368-A',
#   'JP95235319-A',
#   'JP2008282653-A',
#   'JP2008192327-A',
#   'JP2007157370-A',
#   'JP2008059793-A',
#   'JP2007258027-A',
#   'JP2004087353-A',
#   'JP2007095566-A',
#   'JP95326375-A'],
#  [],
#  ['US5300788-A'],
#  ['JP01082572-A', 'JP01061958-A'],
#  ['CN102718409-A',
#   'CN103183479-A',
#   'CN101162753-A',
#   'CN201773856-U',
#   'CN103219454-A',
#   'CN101855317-A',
#   'CN103408229-A'],
#  ['US20020160271-A1',
#   'US5501915-A',
#   'US5567355-A',
#   'JP2003286376-A',
#   'JP2003093874-A',
#   'US4719145-A',
#   'JP2001525247-W',
#   'JP05293383-A',
#   'US4843105-A',
#   'JP08162133-A',
#   'WO1999061141-A1',
#   'US3493343-A',
#   'KR2002080826-A',
#   'US6232494-B1',
#   'US5068161-A',
#   'US4857493-A',
#   'CN1395335-A',
#   'US20040191602-A1',
#   'US4725568-A',
#   'JP2005066592-A',
#   'US6833487-B2',
#   'US6967183-B2'],
#  [],
#  ['US20110200885-A1',
#   'WO2016010090-A1',
#   'US10472571-B2',
#   'US20190148775-A1',
#   'US20160240896-A1',
#   'US20170187031-A1',
#   'US20180254524-A1',
#   'US20160248122-A1',
#   'US20180331393-A1',
#   'WO2015158755-A1',
#   'US20140342249-A1',
#   'US20160233549-A1',
#   'CN107978794-A',
#   'US10854923-B2',
#   'US20160020489-A1',
#   'US20160380314-A1',
#   'JP2002270222-A',
#   'US20170162910-A1',
#   'US20170352908-A1',
#   'US20160344063-A1',
#   'US20190123390-A1',
#   'US20200161706-A1',
#   'US20170098858-A1',
#   'WO2018160209-A1',
#   'JP2012169138-A',
#   'US20070243470-A1',
#   'US20160294005-A1',
#   'US20150364801-A1',
#   'US20110111308-A1',
#   'JP2000294281-A1',
#   'US20120141883-A1',
#   'US5830660-A',
#   'US20160254567-A1',
#   'US20190140322-A1',
#   'US10367232-B2',
#   'US20170331152-A1',
#   'US20160329567-A1',
#   'US20140125292-A1',
#   'US20180251681-A1',
#   'US20100209782-A1',
#   'US4086403-A',
#   'US20170062829-A1',
#   'US8815453-B1'],
#  ['US20050224888-A1',
#   'US20080157363-A1',
#   'US20040102044-A1',
#   'US8273643-B2',
#   'US6891227-B2',
#   'US7413971-B2',
#   'US20060207647-A1',
#   'US20120142158-A1',
#   'US20080293246-A1',
#   'US20070105356-A1',
#   'US20090200536-A1',
#   'US20020112049-A1',
#   'US20060292870-A1',
#   'US20080178924-A1',
#   'US20090014705-A1',
#   'US20090181535-A1',
#   'US20090045391-A1',
#   'US20080171430-A1',
#   'US7816175-B2',
#   'US20050095780-A1',
#   'US20080003768-A1',
#   'US8319259-B2',
#   'US20060169972-A1',
#   'US20020008237-A1',
#   'US20070012956-A1'],
#  ['US4700459-A',
#   'US5338700-A',
#   'US5506429-A',
#   'US5576763-A',
#   'US5541402-A',
#   'US5747840-A',
#   'US4319261-A',
#   'US4309624-A',
#   'US5151385-A',
#   'US5708263-A',
#   'US5612799-A',
#   'US5614744-A',
#   'US5760458-A',
#   'US5393997-A',
#   'US5625210-A',
#   'US5471515-A',
#   'US5608243-A',
#   'US5757045-A',
#   'US4262297-A',
#   'US5705846-A',
#   'US5319604-A',
#   'US6326652-B1',
#   'US4374700-A',
#   'US6495434-B1',
#   'US5461425-A'],
#  ['GB2207890-A', 'US4137123-A'],
#  ['US6297983-B1',
#   'US5801984-A',
#   'US5898547-A',
#   'US6295186-B1',
#   'US5640343-A',
#   'US5608593-A',
#   'US6153320-A',
#   'US6174582-B1',
#   'US5841692-A',
#   'US5281485-A',
#   'US5341118-A',
#   'US6097625-A'],
#  ['JP03183638-A',
#   'US20050277541-A1',
#   'US5273837-A',
#   'JP2000063146-A',
#   'US6291092-B1',
#   'EP982274-A2',
#   'US4946622-A',
#   'WO2003007400-A1',
#   'WO2004031088-A1',
#   'US5308803-A',
#   'JP2004123496-A',
#   'JP2004507424-A',
#   'JP94223848-A',
#   'JP2001319670-A'],
#  ['CN102157591-A; CN102157591-B',
#   'CN101878112-A',
#   'CN101582458-A',
#   'CN101645465-A',
#   'CN101097967-A'],
#  [],
#  [],
#  [],
#  ['US20030234430-A1',
#   'US20040195626-A1',
#   'US6906384-B2',
#   'US7115463-B2',
#   'US6724046-B2',
#   'US7018904-B2',
#   'US20050019999-A1',
#   'US20030057487-A1',
#   'US6333532-B1',
#   'US6825534-B2',
#   'US6214653-B1',
#   'US20030122124-A1',
#   'US20060040476-A1'],
#  ['US20090260681-A1',
#   'US4598164-A',
#   'US4179702-A',
#   'US4017332-A',
#   'US20110240121-A1',
#   'US4255211-A',
#   'EP300807-A',
#   'US20090165839-A1',
#   'US20040182433-A1'],
#  ['US5205871-A'],
#  [],
#  [],
#  [],
#  [],
#  ['US7468485-B1', 'US20100193027-A1', 'CN102214720-A'],
#  [],
#  ['US20030039742-A1',
#   'US5948465-A',
#   'US20030228523-A1',
#   'US4877694-A',
#   'US20040023317-A1',
#   'US5246582-A',
#   'US3628925-A',
#   'US5403675-A',
#   'US20020071915-A1',
#   'US20030124368-A1',
#   'US20030157250-A1',
#   'US20040044100-A1',
#   'US7414088-B1'],
#  ['US9537465-B1',
#   'US6909340-B2',
#   'US7268436-B2',
#   'US6384697-B1',
#   'US6617060-B2',
#   'US7250360-B2',
#   'US7365619-B2',
#   'US6812619-B1',
#   'US8304271-B2',
#   'US9299914-B2',
#   'US6841922-B2',
#   'US6472954-B1',
#   'US7875910-B2',
#   'US6051907-A',
#   'US6262637-B1',
#   'US5894647-A',
#   'US6377137-B1',
#   'US7982363-B2',
#   'US6879224-B2',
#   'US7514759-B1',
#   'US6114635-A',
#   'US5231327-A',
#   'US6864619-B2',
#   'US6933807-B2',
#   'US7112860-B2'],
#  ['EP1178555-A2',
#   'US5827602-A',
#   'US6030720-A',
#   'WO1997002252-A1',
#   'JP11307121-A',
#   'WO2001047088-A2',
#   'WO1999019931-A1',
#   'US4889779-A',
#   'WO2001043209-A2',
#   'US4643958-A',
#   'US6171522-B1',
#   'US20020045102-A1',
#   'CN1336696-A',
#   'JP08339826-A',
#   'US5965054-A',
#   'US6358643-B1',
#   'JP06338346-A',
#   'WO1999030379-A1'],
#  ['US20210104522-A1',
#   'US20190172755-A1',
#   'US10651291-B2',
#   'US20190058052-A1',
#   'US20190067456-A1',
#   'US10332985-B2',
#   'US10381438-B2',
#   'KR2018123422-A',
#   'US20190131396-A1',
#   'US20190172828-A1',
#   'US10008583-B1',
#   'US20190319095-A1',
#   'US20210104523-A1',
#   'US20190312132-A1'],
#  ['US4838952-A',
#   'US4427839-A',
#   'JP02051282-A',
#   'US4726850-A',
#   'US4748130-A',
#   'US4626613-A',
#   'US3903427-A',
#   'US3903428-A',
#   'US4227942-A'],
#  ['JP2010138033-A', 'JP2010126368-A', 'JP2010173915-A', 'WO2009113195-A1'],
#  ['GB590458-A', 'FR1475991-A', 'FR2302132-A'],
#  [],
#  ['KR2019026229-A',
#   'US8545708-B2',
#   'US20050189846-A1',
#   'US20130045374-A1',
#   'US20200274102-A1',
#   'US8349521-B2',
#   'US4888247-A',
#   'US20150221891-A1'],
#  [],
#  ['WO2002081390-A1',
#   'US7179527-B2',
#   'WO2009002648-A2',
#   'DE19719697-A1',
#   'WO2004035496-A3',
#   'EP1217144-A1',
#   'US20070116913-A1',
#   'WO2009120344-A3',
#   'US4514582-A',
#   'WO2012031102-A2',
#   'WO2009120330-A2',
#   'US3405025-A',
#   'WO2011150182-A1',
#   'WO2007110482-A1',
#   'US6538195-B1',
#   'US20080308146-A1',
#   'US4377723-A',
#   'WO2009120344-A2',
#   'WO2010016468-A1',
#   'WO2010072862-A1',
#   'US7517552-B2',
#   'US6420647-B1',
#   'US4644091-A',
#   'US6750394-B2',
#   'US20050029613-A1',
#   'US20020114883-A1',
#   'US5964962-A',
#   'CN1786747-A',
#   'WO2008156631-A2',
#   'US20020160166-A1',
#   'CN1236328-C',
#   'US3222204-A',
#   'US4500743-A',
#   'EP2133924-A1',
#   'US3005382-A',
#   'WO2006005889-A1; DE102004032810-A1; DE102004046554-A1; EP1766690-A1; US2007199591-A1; MX2006015018-A1; IN200700002-P2; CN101032033-A; JP2008506249-W; BR200512989-A; DE102004032810-B4; MX274266-B; CN101032033-B; US7994420-B2',
#   'WO2003019676-A1',
#   'US4081709-A',
#   'US20070110961-A1',
#   'US4497974-A',
#   'US6750384-B1',
#   'WO2010090142-A1',
#   'US20070151596-A1',
#   'US4265937-A',
#   'US6997018-B2',
#   'WO2004035496-A2',
#   'WO2010129462-A1'],
#  [],
#  [],
#  ['CN101090072-A', 'CN102306687-A'],
#  [],
#  ['US20030070611-A1',
#   'US20090056619-A1',
#   'US6214108-B1',
#   'US20080083366-A1',
#   'US5363800-A',
#   'US7569800-B2',
#   'US20050000406-A1',
#   'US20040144301-A1'],
#  ['US6846744-B1',
#   'US6498061-B2',
#   'US6780730-B2',
#   'US20050191807-A1',
#   'US20040002203-A1',
#   'US20060003560-A1',
#   'US20020048913-A1',
#   'US7179748-B1',
#   'US20050067648-A1',
#   'US6724035-B2',
#   'US20050077563-A1',
#   'US6802719-B2',
#   'US6130134-A',
#   'US6589844-B2',
#   'US6576558-B1',
#   'US20060220093-A1'],
#  [],
#  [],
#  [],
#  ['KR2002091984-A'],
#  ['US4410559-A',
#   'US4718947-A',
#   'JP60117711-A',
#   'US4499331-A',
#   'US4582721-A',
#   'JP62154650-A'],
#  [],
#  [],
#  ['US6486032-B1',
#   'US6573555-B1',
#   'US6569736-B1',
#   'US5940706-A',
#   'US6562673-B2'],
#  ['US20020134420-A1',
#   'US6287888-B1',
#   'JP2000101109-A',
#   'US6246524-B1',
#   'JP99260721-A',
#   'US7221340-B2',
#   'US20050236030-A1',
#   'JP2006156582-A',
#   'JP98163113-A',
#   'JP2004342693-A',
#   'US3636492-A',
#   'JP95142749-A',
#   'JP93048126-A',
#   'US4947219-A',
#   'JP2004186320-A',
#   'US20080000520-A1',
#   'US5700333-A',
#   'US6281427-B1',
#   'JP98012908-A',
#   'JP2000091625-A'],
#  ['KR2008015865-A',
#   'KR2008003413-A',
#   'KR2010018340-A',
#   'US20070252139-A1',
#   'US20020028348-A1',
#   'KR2010105099-A',
#   'EP906947-A1',
#   'US5942340-A',
#   'US20090096356-A1',
#   'US7592622-B2',
#   'WO2001014380-A1',
#   'US20080145708-A1',
#   'WO2009148015-A1',
#   'US20040228964-A1',
#   'KR2008055891-A',
#   'US20110253995-A1',
#   'WO2006122630-A1',
#   'KR2007051265-A',
#   'KR2010118700-A',
#   'KR2011018340-A',
#   'US20090253883-A1',
#   'US20020047822-A1',
#   'US20080220285-A1',
#   'US20140061629-A1'],
#  [],
#  ['US20070026680-A1',
#   'KR2006064177-A',
#   'KR2005116479-A',
#   'KR2006011612-A',
#   'JP2004336052-A',
#   'US5900659-A',
#   'KR2006082669-A',
#   'US5702969-A',
#   'JP10027894-A',
#   'JP2005252268-A',
#   'US6236079-B1',
#   'JP2004071935-A'],
#  ['CN102683484-A',
#   'US20150380598-A1',
#   'CN102842646-A',
#   'US4104091-A',
#   'WO2014101988-A1',
#   'WO2014101990-A1',
#   'DE102012101359-A1',
#   'DE102012203445-A1',
#   'US20130164887-A1',
#   'WO2014101989-A1',
#   'WO2012119685-A1',
#   'DE102010024308-A1'],
#  ['EP1703553-A2',
#   'EP2068369-A1',
#   'US20080009087-A1',
#   'US3903427-A',
#   'US20110227227-A1',
#   'US6156967-A',
#   'CN101088159-A',
#   'WO1989005521-A',
#   'EP528311-A2',
#   'US20030022475-A1',
#   'US4610077-A'],
#  ['GB2322964-A',
#   'US5330614-A',
#   'TW328632-A',
#   'DE4223878-A1',
#   'JP10340871-A',
#   'US5597756-A',
#   'JP09092794-A',
#   'JP10022467-A',
#   'JP07508136-W',
#   'US5358888-A',
#   'JP07130875-A',
#   'JP07263571-A',
#   'JP05218343-A',
#   'EP734060-A1',
#   'JP08097219-A',
#   'US5953608-A',
#   'JP06209086-A',
#   'JP11121707-A',
#   'US5792690-A',
#   'US5930623-A',
#   'US5346844-A',
#   'US5677222-A',
#   'JP10209394-A',
#   'EP337436-A',
#   'JP09275194-A',
#   'JP09116123-A',
#   'DE4220497-A1',
#   'US5392189-A'],
#  ['US20050235232-A1',
#   'TW201201340-A',
#   'US20120181510-A1',
#   'US20110114919-A1',
#   'US20110191776-A1',
#   'US20120074387-A1',
#   'WO2012010934-A1',
#   'US20110067029-A1',
#   'US8450779-B2',
#   'US20050204316-A1',
#   'US20120181508-A1',
#   'US20110296368-A1',
#   'US20040172603-A1'],
#  [],
#  ['WO9222929-A1; US5178685-A; AU9219229-A; EP542959-A1; JP6500670-W; AU647285-B',
#   'US4703553-A',
#   'US6989111-B2',
#   'US20030154592-A1',
#   'US7438829-B2',
#   'US7008891-B2',
#   'US6825104-B2',
#   'US6814795-B2',
#   'US6262359-B1',
#   'JP05298917-A',
#   'US6402839-B1',
#   'US20050172996-A1',
#   'US6835888-B2',
#   'US6987358-B2',
#   'US7052824-B2',
#   'US7435361-B2',
#   'US4492813-A',
#   'US5928438-A',
#   'US20050176164-A1',
#   'US5645765-A',
#   'US6093882-A',
#   'US20100071761-A1',
#   'US6784457-B2',
#   'US4070517-A',
#   'US6469243-B2',
#   'US6737340-B2',
#   'US6069065-A',
#   'US7098158-B2',
#   'US6710239-B2',
#   'US5584941-A',
#   'US5468652-A',
#   'US6576391-B1',
#   'US20060289055-A1',
#   'US20040155227-A1',
#   'US6784037-B2',
#   'US4899704-A',
#   'US6531181-B1',
#   'US6692981-B2',
#   'US4163678-A',
#   'JP2005079143-A',
#   'US4088502-A',
#   'US6695903-B1',
#   'EP468382-A',
#   'US20060102228-A1',
#   'US4235644-A; EP24775-A; JP56036172-A; EP24775-B; DE3067762-G',
#   'US6777716-B1',
#   'US20060231801-A1',
#   'US5074920-A',
#   'US20040116268-A1',
#   'US6977394-B2',
#   'US6626993-B2',
#   'US5942048-A',
#   'US3900945-A',
#   'US20040046154-A1',
#   'US6096968-A',
#   'US6909114-B1',
#   'JP2005005436-A',
#   'US5922627-A',
#   'JP2003069056-A',
#   'US20020005507-A1',
#   'US6071753-A',
#   'JP2000226232-A'],
#  ['US20150187787-A1'],
#  ['US6197653-B1',
#   'US6087226-A',
#   'US6004846-A',
#   'US5061650-A',
#   'JP09186297-A',
#   'US5629540-A',
#   'US5837581-A',
#   'US5994181-A',
#   'US6190992-B1',
#   'US6046093-A'],
#  ['JP2009260274-A',
#   'JP2006328354-A',
#   'US20110220195-A1',
#   'WO2010137500-A1',
#   'US7109528-B2',
#   'US20110232721-A1',
#   'JP2009208282-A',
#   'KR2008091337-A',
#   'US5782995-A',
#   'US20050121683-A1',
#   'US7968790-B2',
#   'WO2010067742-A1',
#   'US20100000874-A1',
#   'JP2000034326-A',
#   'US20120077668-A1',
#   'US20120107995-A1',
#   'KR2007119014-A',
#   'US20120103398-A1',
#   'JP2001329136-A',
#   'US20090176905-A1',
#   'US8338693-B2',
#   'US20110240095-A1',
#   'JP2009260270-A',
#   'US20100180928-A1',
#   'US20110178225-A1',
#   'US20130068304-A1'],
#  [],
#  ['JP06163933-A', 'JP59065486-A', 'JP59041871-A', 'JP09036359-A'],
#  [],
#  ['US6767386-B2',
#   'US5098880-A',
#   'US5972834-A',
#   'US20160250580-A1',
#   'US6916358-B2',
#   'US20050257685-A1',
#   'US4548799-A',
#   'US7645324-B2',
#   'US20140076164-A1',
#   'CN103787285-A',
#   'US9669349-B1',
#   'US5164355-A',
#   'US4938939-A',
#   'US9403118-B2',
#   'US9895646-B2',
#   'US4742040-A',
#   'EP2823872-A2',
#   'US9359203-B2',
#   'US9925514-B2',
#   'US4589888-A',
#   'EP620035-A1',
#   'CN101318634-A',
#   'US5240474-A',
#   'WO2015199227-A1',
#   'US7651549-B2',
#   'US3801513-A',
#   'WO2008089564-A1',
#   'US5871565-A',
#   'US20170144101-A1',
#   'KR1659760-B1',
#   'US5447557-A',
#   'US20080282886-A1',
#   'US20140060326-A1',
#   'US6451095-B1',
#   'CN1363412-A',
#   'CN202337689-U',
#   'US8470395-B2',
#   'US4458022-A',
#   'CN101511448-A',
#   'CN86102699-A',
#   'US6565628-B2',
#   'US7670408-B2',
#   'WO2017058486-A1',
#   'US6051050-A'],
#  ['CN1812135-A', 'EP1895598-A2', 'CN203386785-U', 'CN103084688-A'],
#  ['US20040032764-A1',
#   'US6022766-A',
#   'US20020005519-A1',
#   'US20070007532-A1',
#   'US20040080999-A1',
#   'US20040214379-A1',
#   'US20040246765-A1',
#   'US20050280156-A1',
#   'US20060049444-A1',
#   'US6844243-B1',
#   'WO2004015764-A2'],
#  [],
#  ['US4209849-A', 'US4698900-A', 'US4695979-A', 'US4668970-A'],
#  [],
#  ['US20070200477-A1', 'US20070045667-A1', 'US6946597-B2', 'US20020172820-A1'],
#  ['US20100029036-A1',
#   'US20070128439-A1',
#   'US20090253224-A1',
#   'US20100315703-A1',
#   'US20080078441-A1',
#   'US20120031486-A1',
#   'US20090117161-A1',
#   'US20050087102-A1',
#   'US8384064-B2',
#   'US20100237323-A1',
#   'US20080017242-A1',
#   'US8323772-B2'],
#  [],
#  [],
#  [],
#  ['US6176967-B1',
#   'US5332464-A',
#   'JP09283493-A',
#   'US5764842-A',
#   'WO1999056324-A2',
#   'US5503881-A',
#   'US20050241583-A1',
#   'JP62051223-A',
#   'US20020011215-A1',
#   'WO1999033097-A1',
#   'JP01119025-A',
#   'US5304250-A',
#   'US5868952-A',
#   'JP2001127142-A',
#   'US4243506-A',
#   'US6087274-A',
#   'WO2000026945-A1',
#   'JP10223736-A',
#   'US6261406-B1',
#   'US20050251990-A1',
#   'US6418941-B1',
#   'US5417798-A',
#   'US5986275-A',
#   'US4523971-A',
#   'JP09320799-A',
#   'WO1995013525-A1',
#   'US5770123-A',
#   'JP11102880-A',
#   'JP58032417-A',
#   'US6132805-A',
#   'JP60184771-A',
#   'JP2001527288-A',
#   'US5695564-A',
#   'US20020168166-A1',
#   'JP56076242-A',
#   'US5223108-A',
#   'JP09102625-A',
#   'JP62277730-A',
#   'US4681780-A',
#   'JP62047132-A',
#   'US5248371-A',
#   'JP02106925-A',
#   'US20010036744-A1',
#   'US5015331-A',
#   'JP11317396-A',
#   'DE2933850-C',
#   'US4661203-A',
#   'JP2002076404-A',
#   'WO2002009198-A1',
#   'US5968275-A',
#   'JP63164433-A',
#   'US4842679-A',
#   'WO1994005035-A1',
#   'JP08037097-A',
#   'US5679436-A',
#   'EP399998-B1',
#   'US5171732-A',
#   'US20060060138-A1',
#   'JP08274069-A',
#   'DE1621342-B',
#   'DE1621342-A',
#   'US6413880-B1',
#   'US4780169-A',
#   'US6171351-B1',
#   'US6214161-B1',
#   'JP2000261008-A',
#   'US20050011447-A1',
#   'US4771213-A',
#   'JP07500459-W',
#   'US20010006169-A1',
#   'JP06204181-A',
#   'US4810322-A',
#   'US5177398-A',
#   'JP61238981-A',
#   'JP09501271-W',
#   'US5254215-A',
#   'US3982976-A',
#   'EP40081-B',
#   'US5990016-A',
#   'JP08232086-A',
#   'US5665167-A',
#   'JP59219464-A',
#   'DE19819200-A1',
#   'US5753014-A',
#   'US6316289-B1'],
#  ['US5811348-A',
#   'US20060196535-A1',
#   'US6190937-B1',
#   'US4695674-A',
#   'US6391743-B1',
#   'US20080264477-A1',
#   'JP2003092422-A',
#   'US6258666-B1',
#   'US20050121068-A1',
#   'US6645833-B2',
#   'US20090227063-A1',
#   'US20040112426-A1',
#   'US20080179547-A1',
#   'US20070199591-A1',
#   'US6802926-B2',
#   'CN101553921-A',
#   'US4082570-A',
#   'US20050217722-A1',
#   'US20070107773-A1',
#   'EP1069602-A2; AU200048638-A; CN1283874-A; JP2001026500-A; JP2001111081-A; US6452091-B1; AU768197-B; CN1505174-A; CN1516291-A; CN1156919-C',
#   'US20100126551-A1',
#   'US6331208-B1',
#   'US20040200522-A1',
#   'US4561541-A',
#   'US20090194163-A1',
#   'US20080160661-A1'],
#  ['US7042052-B2',
#   'US6743681-B2',
#   'US6784480-B2',
#   'US6784484-B2',
#   'US6754108-B2',
#   'US6933572-B2',
#   'US6664589-B2',
#   'US6121654-A',
#   'US7005697-B2',
#   'US20050001232-A1',
#   'US6768156-B1',
#   'US6917078-B2',
#   'US6586797-B2',
#   'US6888200-B2',
#   'US6778441-B2',
#   'US6759713-B2',
#   'US20030045082-A1',
#   'US20030048666-A1',
#   'US20030043632-A1',
#   'US5886368-A',
#   'US20030089942-A1',
#   'US4870470-A',
#   'US20060110870-A1',
#   'US7012297-B2',
#   'US20060084214-A1',
#   'US20030042527-A1',
#   'US6900455-B2',
#   'US6514828-B2',
#   'US20030043637-A1',
#   'US6849464-B2',
#   'US6713810-B1',
#   'US20060192240-A1',
#   'US20030042532-A1',
#   'US20060192243-A1',
#   'US20060258090-A1',
#   'US20030043633-A1',
#   'US6864139-B2',
#   'US6642573-B1',
#   'US20030042534-A1',
#   'US20030151948-A1',
#   'US20070045706-A1',
#   'US20030235064-A1'],
#  ['US20120012988-A1',
#   'US20030107119-A1',
#   'US20130020665-A1',
#   'CN101055867-A',
#   'US20150325557-A1',
#   'CN102782862-A',
#   'CN101859752-A',
#   'US20070235882-A1',
#   'US20120313207-A1',
#   'US20100187697-A1',
#   'US20090166840-A1',
#   'CN101996953-A',
#   'US20110317371-A1'],
#  [],
#  ['JP2000357524-A',
#   'JP2001093543-A',
#   'JP2002245846-A',
#   'JP10097811-A',
#   'JP10069817-A'],
#  ['WO2010080446-A2; US2010269896-A1; WO2010080446-A3; TW201029208-A; EP2359411-A2; KR2011106889-A; CN102272950-A; JP2012513125-W; EP2359411-A4',
#   'WO2008079742-A2',
#   'US20100132792-A1',
#   'US20100147378-A1',
#   'US20100065117-A1',
#   'US6645833-B2',
#   'US6998288-B1',
#   'US20090020154-A1',
#   'US6477980-B1',
#   'US2008096376-A1; US7601558-B2',
#   'US6024044-A',
#   'US20060060138-A1',
#   'US20120031479-A1',
#   'US6534336-B1',
#   'US5788778-A',
#   'US7582515-B2',
#   'US20100059110-A1',
#   'US5091244-A',
#   'US20050251990-A1',
#   'US20120012171-A1'],
#  ['US5810945-A', 'US6331672-B1'],
#  ['JP2003112942-A',
#   'JP81032347-A',
#   'JP92325435-A',
#   'JP2010215463-A',
#   'JP86132536-A',
#   'JP2002003240-A'],
#  ['JP2008156692-A',
#   'WO2014010680-A1; JP2014031572-A; TW201406970-A; CN104379790-A; EP2871251-A1; JP5716054-B2; TW561645-B1; EP2871251-A4; CN104379790-B; EP2871251-B1',
#   'JP3910419-B2',
#   'JP2003328088-A',
#   'WO2012124528-A1',
#   'JP2011162843-A',
#   'JP2011190524-A',
#   'EP2639325-A1',
#   'JP3942876-B2',
#   'JP2002256398-A',
#   'JP2012211379-A',
#   'WO2013080526-A1',
#   'JP2013100595-A',
#   'JP2005206884-A',
#   'JP2012102376-A',
#   'JP2009167443-A',
#   'US20100122800-A1',
#   'JP3886785-B2',
#   'JP05320866-A',
#   'JP2012012674-A',
#   'JP2008101240-A'],
#  ['US6165375-A',
#   'US6281068-B1',
#   'US6315384-B1',
#   'US5817550-A',
#   'US6146938-A',
#   'US6245612-B1',
#   'US4529621-A',
#   'US4994409-A',
#   'US6096598-A'],
#  [],
#  ['US20170287648-A1', 'CN103956431-A'],
#  [],
#  [],
#  ['CN1499650-A',
#   'CN1638879-A',
#   'WO2005006451-A1',
#   'CN1543664-A',
#   'CA1292932-C',
#   'US20040121528-A1',
#   'WO2005017058-A1'],
#  [],
#  ['US6583052-B2',
#   'US6372640-B1',
#   'US6667204-B2',
#   'US6420273-B1',
#   'US6391767-B1',
#   'US6737291-B1',
#   'US20010012225-A1',
#   'US6194258-B1',
#   'US6414342-B1',
#   'US6143613-A',
#   'US6602774-B1',
#   'US6383882-B1',
#   'US6528381-B2',
#   'US6667233-B2',
#   'US6518618-B1',
#   'US20030082881-A1',
#   'US6700163-B2',
#   'US5086370-A'],
#  ['CN110882707-A', 'CN104941674-A', 'CN105016319-A', 'CN110607532-A'],
#  ['US20090278121-A1',
#   'TW200807736-A',
#   'US20020146871-A1',
#   'US20090009675-A1',
#   'US20090103161-A1',
#   'US20080303018-A1',
#   'US20080179762-A1',
#   'US20090185120-A1',
#   'US20070153177-A1'],
#  [],
#  [],
#  ['KR2006001009-A',
#   'US6472700-B2',
#   'KR2006076518-A',
#   'KR2006029376-A',
#   'KR2006005180-A',
#   'KR187679-B1'],
#  ['US5598285-A',
#   'US6356335-B1',
#   'JP2004214612-A',
#   'JP2009278115-A',
#   'JP2008311616-A',
#   'US7602360-B2',
#   'JP06224219-A',
#   'US7589799-B2',
#   'US20090200553-A1',
#   'US20070278490-A1',
#   'US6362028-B1',
#   'CN101359693-A',
#   'US7408606-B2',
#   'US20030160247-A1',
#   'US6815717-B2',
#   'US20040106250-A1',
#   'US20020197776-A1',
#   'US7071036-B2',
#   'US20040233365-A1',
#   'US20080308826-A1',
#   'US20090283763-A1',
#   'US20060121655-A1',
#   'US20100203673-A1',
#   'CN101840936-A',
#   'US5838037-A',
#   'US5926702-A',
#   'CN101356652-A',
#   'US6884569-B2',
#   'US20090065771-A1',
#   'US6580093-B2',
#   'JP2007250983-A',
#   'US6016178-A',
#   'US8003981-B2',
#   'US20040178429-A1'],
#  ['CN205723565-U', 'US20040063320-A1', 'JP2010251694-A'],
#  [],
#  ['US6919964-B2',
#   'US5880838-A',
#   'US6785638-B2',
#   'US20060126074-A1',
#   'US7068363-B2',
#   'EP882976-A1',
#   'US6768983-B1',
#   'US6699624-B2',
#   'US20060066855-A1',
#   'JP2006060214-A',
#   'US7061627-B2',
#   'US7061623-B2',
#   'US4723315-A',
#   'US5703692-A',
#   'WO2001013079-A1',
#   'US6608690-B2',
#   'US20040119970-A1',
#   'DE19745607-A1',
#   'US7061615-B1',
#   'US6721691-B2',
#   'US6738138-B2',
#   'US6928628-B2',
#   'US6772084-B2',
#   'US20060033921-A1',
#   'US5412473-A',
#   'US6856408-B2',
#   'US20060139592-A1',
#   'US6704661-B1',
#   'US6974962-B2',
#   'US20080198380-A1',
#   'US7369233-B2',
#   'US4931132-A',
#   'KR2006050488-A',
#   'US6987572-B2',
#   'US6819426-B2',
#   'US7046376-B2',
#   'US20040227951-A1',
#   'US6972852-B2',
#   'US7388668-B2',
#   'JP09504861-W',
#   'US6813034-B2',
#   'EP1628164-A2',
#   'US5963329-A',
#   'US6753961-B1'],
#  ['US20080165565-A1',
#   'US20090213637-A1',
#   'US20060023485-A1',
#   'US20070195578-A1',
#   'US20100019304-A1',
#   'US20080180985-A1',
#   'US20070211512-A1'],
#  ['US20190221261-A1',
#   'US20190221575-A1',
#   'US20180122461-A1',
#   'US20100038743-A1',
#   'US20170179026-A1',
#   'US20170358742-A1',
#   'US20020074584-A1',
#   'US20100252802-A1',
#   'US20200328220-A1',
#   'US20150262663-A1',
#   'US20100027318-A1',
#   'US20100290271-A1',
#   'US20050036392-A1',
#   'US20160064391-A1',
#   'US20130069141-A1',
#   'US20160172420-A1',
#   'US20190305045-A1',
#   'US20160012886-A1',
#   'US20190164587-A1'],
#  ['US9837533-B2',
#   'US9659939-B1',
#   'US20180026100-A1',
#   'US9741822-B1',
#   'US10147820-B1',
#   'US9634142-B1',
#   'US9812571-B2',
#   'US8623728-B2',
#   'US20180240875-A1',
#   'US10347762-B1',
#   'US20190019881-A1',
#   'US6924518-B2',
#   'US20180076040-A1'],
#  ['CN104118992-A',
#   'JP02296748-A',
#   'US20130270489-A1',
#   'CN106007389-A',
#   'CN107746184-A',
#   'CN104445962-A',
#   'CN108428492-A',
#   'US4904415-A',
#   'TW493729-B1',
#   'US2011232746-A1; WO2011140185-A1; WO2011140189-A1; WO2011140192-A1; WO2011140197-A1; WO2011140205-A1; TW201141964-A; TW201144250-A; TW201145311-A; TW201207053-A; KR2013016344-A; KR2013016345-A; KR2013016346-A; TW201241120-A; TW201245361-A; TW201247791-A; EP2566823-A1; EP2566824-A1; EP2566825-A1; EP2566826-A1; KR2013024923-A; CN102947235-A; CN102958861-A; CN102971268-A; TW201308355-A; JP2013531863-W; JP2013533187-W; JP2013533188-W; JP2013534023-W; CN103038186-A; HK1180295-A0; HK1180671-A0; HK1180672-A0; HK1181743-A0; JP5480448-B2; US8895843-B2; JP5711359-B2; JP5746325-B2; JP5782112-B2; KR1569568-B1; CN102958861-B; KR1569567-B1; KR1569566-B1; KR2015133297-A; EP2566824-B1; CN102947235-B; EP3070062-A1; EP2566823-B1; ES2570133-T3; EP2566825-B1; EP2566826-B1; HK1180672-A1; TW564351-B1; CN102971268-B; HK1180295-A1; TW589649-B1; CN107424662-A; TW611428-B1; KR2018041770-A; HK1180671-A1; CN103038186-B; CN109014180-A; CN107424662-B; KR2019131618-A; KR2048388-B1; HK1181743-A1; KR2177050-B1; CN109014180-B'],
#  ['US20070111488-A1',
#   'US20110284863-A1',
#   'US7154163-B2',
#   'US20070105259-A1',
#   'US20030146433-A1',
#   'US20100187497-A1',
#   'US20060126688-A1',
#   'US5773853-A',
#   'US20100176490-A1',
#   'US6596079-B1',
#   'US6345063-B1'],
#  ['CN107845692-A',
#   'CN106449800-A',
#   'JP2010177264-A',
#   'CN107369726-A',
#   'CN107195699-A'],
#  ['US5606179-A',
#   'US5569936-A',
#   'US5479955-A',
#   'US5595944-A',
#   'US5840600-A',
#   'US5624865-A',
#   'US5646075-A',
#   'US5382533-A',
#   'US5646424-A',
#   'US5595923-A',
#   'US5416045-A'],
#  ['US5169415-A',
#   'US5306411-A',
#   'US4761209-A',
#   'US5380467-A',
#   'US5547494-A',
#   'WO1995027810-A1',
#   'US5580497-A',
#   'US5989634-A',
#   'US5616223-A',
#   'US5152819-A',
#   'US5888272-A'],
#  ['US4763305-A', 'US4698900-A', 'US4408306-A'],
#  ['JP2001339084-A',
#   'JP2001015772-A',
#   'JP2004342723-A',
#   'JP2005039198-A',
#   'JP01290267-A',
#   'JP2007073545-A',
#   'JP10074753-A'],
#  [],
#  ['US6140157-A',
#   'US7585728-B2',
#   'US6674110-B2',
#   'US6589839-B1',
#   'US7045406-B2',
#   'US5907780-A'],
#  ['US6633498-B1',
#   'US7193823-B2',
#   'US20080191251-A1',
#   'US20060049472-A1',
#   'US6765819-B1',
#   'US7489541-B2',
#   'US20110147816-A1',
#   'US20090040855-A1',
#   'US7385842-B2',
#   'US20080259675-A1',
#   'US6835423-B2',
#   'US7189435-B2',
#   'US7379327-B2',
#   'US7576956-B2',
#   'US7242045-B2',
#   'US6847547-B2',
#   'US7495867-B2',
#   'US6473279-B2',
#   'US7411815-B2',
#   'US6845038-B1',
#   'US20070246787-A1',
#   'JP2007157840-A',
#   'US6584016-B2',
#   'US6744086-B2',
#   'US7190611-B2',
#   'JP2003229544-A',
#   'US6741492-B2',
#   'US20040008537-A1',
#   'US20090251956-A1',
#   'US7067866-B2',
#   'US7161829-B2',
#   'US6979586-B2',
#   'US6714444-B2',
#   'US7088624-B2',
#   'US7093347-B2',
#   'US20060245117-A1',
#   'US20100034009-A1',
#   'US7105372-B2',
#   'US20090218645-A1',
#   'US7515457-B2',
#   'US20050048674-A1',
#   'US7289356-B2',
#   'US7572645-B2',
#   'US6774391-B1',
#   'US6888742-B1',
#   'US20040090809-A1',
#   'US20050269612-A1',
#   'US7187577-B1',
#   'US20080277703-A1',
#   'US20060202244-A1',
#   'US20050282379-A1',
#   'US20080061388-A1',
#   'US20090296454-A1',
#   'US20100177558-A1',
#   'US20100090261-A1',
#   'US6700753-B2',
#   'US20100118600-A1',
#   'US6914807-B2',
#   'US6532164-B2',
#   'US7241631-B2',
#   'US7782661-B2',
#   'US7230265-B2',
#   'US6992359-B2',
#   'US7138648-B2',
#   'US7245462-B2',
#   'US6569745-B2',
#   'US20050150537-A1',
#   'US20080273380-A1',
#   'US6381106-B1',
#   'US6469926-B1',
#   'US20060061919-A1',
#   'US7110287-B2',
#   'US20100078743-A1',
#   'US20050068684-A1',
#   'US7486551-B1',
#   'US6920063-B2',
#   'US6930910-B2',
#   'US7057921-B2',
#   'US7242048-B2',
#   'US7486552-B2',
#   'US7935435-B2',
#   'US20070164380-A1',
#   'US4733371-A',
#   'US6963500-B2',
#   'US7881098-B2',
#   'US7126202-B2',
#   'US20080130354-A1',
#   'US6711067-B1',
#   'US6831312-B2',
#   'US7098494-B2',
#   'US5646419-A',
#   'US20080265347-A1',
#   'US20100176471-A1',
#   'US7110284-B2',
#   'US20050150535-A1',
#   'US7236336-B2',
#   'US20050184839-A1',
#   'US7282755-B2',
#   'US20080179699-A1',
#   'US20060083047-A1',
#   'US20090257154-A1',
#   'US20080291721-A1',
#   'US7196882-B2',
#   'US7477491-B2',
#   'US7274057-B2',
#   'US7480173-B2',
#   'US20050254286-A1',
#   'US6958927-B1',
#   'US6801415-B2',
#   'US5761115-A',
#   'US20070025164-A1',
#   'US6888709-B2',
#   'US6226197-B1',
#   'US20070047294-A1',
#   'US20070063237-A1',
#   'US20090027810-A1',
#   'US20030137864-A1',
#   'US6643168-B2',
#   'US7020024-B2',
#   'US6909633-B2',
#   'US7408806-B2',
#   'US20070029630-A1',
#   'US6178136-B1',
#   'US20050254287-A1',
#   'GB2422735-A',
#   'US6072718-A',
#   'US7345912-B2',
#   'US6965522-B2',
#   'US20040197579-A1',
#   'US5673225-A',
#   'US20040084702-A1',
#   'US20050237787-A1',
#   'US7430135-B2',
#   'US6542000-B1',
#   'US20080118778-A1',
#   'US20060171199-A1',
#   'US7285836-B2',
#   'US6943040-B2',
#   'US6850433-B2',
#   'US6781867-B2',
#   'US20040170055-A1',
#   'US5982670-A',
#   'US20070035890-A1',
#   'US8058697-B2',
#   'US6818961-B1',
#   'US20070007609-A1',
#   'US7230845-B1',
#   'US20070120210-A1',
#   'US6809909-B2',
#   'US7088609-B2',
#   'US20070097730-A1',
#   'US20020054462-A1',
#   'US20090302403-A1',
#   'US7369427-B2',
#   'US20070069314-A1',
#   'US20080026253-A1',
#   'US7099186-B1',
#   'US20070004421-A1',
#   'US20070064352-A1',
#   'US6602677-B1',
#   'US6781871-B2',
#   'US6252796-B1',
#   'US6864551-B2',
#   'US7728622-B2',
#   'US7241632-B2',
#   'US7098495-B2',
#   'US20080310219-A1',
#   'US7531830-B2',
#   'US7092279-B1',
#   'US6842368-B2',
#   'US7403418-B2',
#   'US7436632-B2',
#   'US20060233017-A1',
#   'US6838740-B2',
#   'US6643830-B1',
#   'US7539047-B2',
#   'US6933155-B2',
#   'US7272035-B1',
#   'US6703645-B2',
#   'US6834005-B1',
#   'US20040179311-A1',
#   'US20070054450-A1',
#   'US20050275003-A1',
#   'US7272034-B1',
#   'US5920446-A',
#   'US20060141640-A1',
#   'US20090073756-A1',
#   'US7411765-B2',
#   'US20080258247-A1',
#   'US6711051-B1',
#   'US20050185459-A1',
#   'US6985385-B2',
#   'US6998150-B2',
#   'US7881095-B2',
#   'US20110001203-A1',
#   'US20060060832-A1',
#   'US7009877-B1',
#   'US7233039-B2',
#   'US20070132049-A1',
#   'US20090050991-A1',
#   'US6781801-B2',
#   'US7067330-B2',
#   'US20070096229-A1',
#   'US20100078741-A1',
#   'US20070241392-A1',
#   'US20070230233-A1',
#   'US6759263-B2',
#   'US8169810-B2',
#   'US7518835-B2',
#   'US20070297220-A1',
#   'US7224601-B2',
#   'US20070008661-A1',
#   'US7573736-B2',
#   'US20050139883-A1',
#   'US7286395-B2',
#   'WO2008100868-A3',
#   'US20080310213-A1',
#   'US6829161-B2',
#   'US7485503-B2',
#   'US5191223-A',
#   'US20030011945-A1',
#   'US7502249-B1',
#   'US6967863-B2',
#   'US6985378-B2',
#   'US20070171694-A1',
#   'US20090185410-A1'],
#  ['CN108649206-A',
#   'EP143122-A',
#   'CN103137973-A',
#   'CN110429248-A',
#   'CN101805894-A',
#   'CN110182808-A'],
#  ['CN107026218-A',
#   'CN108417482-A',
#   'CN106011746-A',
#   'CN101230269-A',
#   'JP2013538009-A',
#   'CN109087965-A',
#   'CN107482078-A'],
#  ['JP07307482-A',
#   'JP2003273383-A',
#   'JP09129906-A',
#   'JP07335924-A',
#   'JP09162431-A'],
#  [],
#  ['US20100027598-A1',
#   'US20050022863-A1',
#   'US20070175508-A1',
#   'US20100275983-A1',
#   'US20120000517-A1',
#   'JP2007300128-A',
#   'US20090211627-A1',
#   'US4468853-A',
#   'US20050133084-A1',
#   'US20070137699-A1',
#   'US4994879-A',
#   'US20040063326-A1',
#   'US8298850-B2',
#   'DE3815512-A',
#   'US4166919-A',
#   'US20050016585-A1',
#   'CN101361168-A',
#   'US20080257399-A1',
#   'EP999598-A1',
#   'JP10190033-A',
#   'WO2009052511-A2',
#   'US20130056061-A1',
#   'US20050056312-A1',
#   'US5665175-A',
#   'US6096968-A',
#   'CN101132033-A',
#   'US7495167-B2',
#   'US8404970-B2',
#   'EP1722419-A1'],
#  [],
#  [],
#  ['CN205265623-U', 'CN105390428-A', 'CN105140145-A', 'JP2016046437-A'],
#  ['JP2008210845-A',
#   'JP2012107127-A',
#   'JP2007214543-A',
#   'JP2012211235-A',
#   'CN103881388-A',
#   'JP2015172173-A',
#   'CN103571209-A',
#   'CN101148542-A',
#   'JP2010013572-A'],
#  ['US8058118-B2',
#   'US7625803-B2',
#   'US7851827-B2',
#   'US6743681-B2',
#   'US7956426-B2',
#   'US7158410-B2',
#   'US7339239-B2',
#   'US7379336-B2',
#   'US7579242-B2',
#   'US8242554-B2',
#   'US7750395-B2',
#   'US8159875-B2',
#   'US7838362-B2',
#   'US6888200-B2',
#   'US20020187610-A1',
#   'US7759715-B2',
#   'US7440310-B2',
#   'US2004041212-A1; US7042027-B2',
#   'US7671407-B2',
#   'US7867850-B2',
#   'US8143657-B2',
#   'US7166888-B2',
#   'US8063436-B2',
#   'US7436018-B2',
#   'US7485513-B2',
#   'US7432562-B2',
#   'US7459740-B2',
#   'US7403416-B2',
#   'US6998667-B2',
#   'US2007045718-A1; US7629641-B2',
#   'US7898022-B2',
#   'US6888755-B2',
#   'US7749848-B2',
#   'US8125003-B2',
#   'US7273784-B2',
#   'US7339830-B2',
#   'US20070045706-A1',
#   'US7968402-B2',
#   'US7224002-B2',
#   'US7400012-B2',
#   'US7385245-B2',
#   'US7456054-B2',
#   'US7208793-B2',
#   'US7528043-B2',
#   'US6917078-B2',
#   'US7525149-B2',
#   'US7482651-B2',
#   'US8193568-B2',
#   'US7728350-B2',
#   'US4870470-A',
#   'US7544990-B2',
#   'US6743682-B2',
#   'US7612403-B2',
#   'US7145186-B2',
#   'US7662693-B2',
#   'US7250628-B2',
#   'US7349252-B2',
#   'US7768062-B2',
#   'US7440317-B2',
#   'US7553735-B2',
#   'US7184312-B2',
#   'US6903969-B2',
#   'US7130216-B2',
#   'US7457159-B2',
#   'US8228743-B2',
#   'US7365388-B2',
#   'US20080303080-A1',
#   'US7429767-B2',
#   'US20070034922-A1',
#   'US7279740-B2',
#   'US7964909-B2',
#   'US7012297-B2',
#   'US7476927-B2',
#   'US7244981-B2',
#   'US7786516-B2',
#   'US7276760-B2',
#   'US20100090265-A1',
#   'US7417893-B2',
#   'US7294547-B1'],
#  [],
#  [],
#  ['JP2019192904-A', 'CN109904253-A', 'CN109817752-A'],
#  ['US20170025414-A1',
#   'WO2016069487-A1',
#   'US20120007167-A1',
#   'US20020096689-A1',
#   'US20130313627-A1'],
#  ['US20090262766-A1', 'CN204067398-U'],
#  [],
#  ['US20190140095-A1', 'US20150303267-A1', 'US20190181261-A1'],
#  ['CN1746252-A', 'CN101072676-A'],
#  [],
#  ['EP2679639-A2', 'WO2011026769-A1', 'WO2016184975-A1', 'US20090250106-A1'],
#  [],
#  ['US6036932-A',
#   'US4312848-A',
#   'US4539194-A',
#   'US4312849-A',
#   'US6488743-B1',
#   'US5310412-A',
#   'US3069240-A',
#   'US20050139148-A1',
#   'US4241037-A',
#   'WO2007112592-A1'],
#  ['US20100324320-A1',
#   'RU2153397-C2',
#   'EA10793-B1',
#   'US20120041210-A1',
#   'CN104370296-A',
#   'CN1671622-A'],
#  ['US20130118559-A1',
#   'US20140152632-A1',
#   'US5276539-A',
#   'US20120206452-A1',
#   'CN102404657-A',
#   'US6544823-B1'],
#  ['JP06204345-A',
#   'US6917532-B2',
#   'JP07099245-A',
#   'US5760429-A',
#   'US20070222076-A1',
#   'JP2006512776-W',
#   'US20060197115-A1',
#   'JP2003142576-A',
#   'US7005350-B2',
#   'US7606059-B2',
#   'JP2006514393-A',
#   'US7291878-B2'],
#  ['US20030224564-A1',
#   'US20030030100-A1',
#   'US6885590-B1',
#   'CN1433064-A',
#   'US7098505-B1',
#   'US4173766-A',
#   'US6624028-B1',
#   'US7450423-B2',
#   'US5818761-A',
#   'US20050101089-A1',
#   'US20040079983-A1',
#   'US20040152260-A1',
#   'US6011725-A',
#   'US6680509-B1'],
#  ['US20040104405-A1',
#   'US20030205766-A1',
#   'US20040029323-A1',
#   'US20040245606-A1',
#   'US7238578-B2',
#   'US20040056278-A1',
#   'US20010001718-A1',
#   'US20050285202-A1',
#   'US20040222530-A1',
#   'US20060226490-A1',
#   'US20040150051-A1'],
#  ['JP2012038846-A',
#   'JP10312712-A',
#   'JP2012178456-A',
#   'JP2012023096-A',
#   'WO2012042780-A1',
#   'JP2013045742-A',
#   'JP2012022795-A',
#   'JP2012022804-A',
#   'JP2012022798-A',
#   'JP2012023095-A',
#   'JP2012151276-A'],
#  ['US20050275144-A1',
#   'US4710260-A',
#   'US4762687-A',
#   'US5360480-A',
#   'KR2010113925-A',
#   'US20040187771-A1',
#   'US20050279275-A1',
#   'US6361597-B1',
#   'EP2128088-A1',
#   'US6423137-B1',
#   'US4670096-A',
#   'US20110305891-A1',
#   'JP07256624-A',
#   'JP61026593-A',
#   'WO2008039816-A1',
#   'US20110303290-A1',
#   'KR2007042971-A',
#   'JP07256398-A'],
#  [],
#  ['US4720130-A',
#   'US6929299-B2',
#   'US20090293663-A1',
#   'US20120237329-A1',
#   'CN101209554-A',
#   'US20080129064-A1',
#   'US6244641-B1',
#   'JP2003142503-A',
#   'JP2003142503-A1',
#   'US6024393-A',
#   'WO2015048303-A1',
#   'US20160254176-A1',
#   'US20130057008-A1',
#   'US20060182603-A1',
#   'WO1999050891-A1',
#   'US20150290815-A1',
#   'US20080012906-A1',
#   'US20160001449-A1'],
#  [],
#  [],
#  ['US4328390-A',
#   'US6784358-B2',
#   'US3450568-A',
#   'US20050000561-A1',
#   'US3966499-A',
#   'US4756796-A',
#   'US4727047-A',
#   'US20020000561-A1',
#   'US20060207645-A1',
#   'US20140014172-A1',
#   'US20040089339-A1',
#   'US20090183768-A1',
#   'US4084985-A',
#   'US20060166480-A1',
#   'US20050241692-A1',
#   'US5476553-A',
#   'US20040093809-A1',
#   'US3539883-A',
#   'US20080014661-A1',
#   'US7759158-B2',
#   'JP59115576-A1',
#   'JP9153634-A1',
#   'US20050074898-A1',
#   'US6515217-B1',
#   'US20030006697-A1',
#   'US20080110492-A1',
#   'US4301592-A',
#   'US5158618-A',
#   'US4771017-A'],
#  [],
#  ['US20040097012-A1',
#   'US20050101153-A1',
#   'WO2003105209-A1; AU2003242229-A1; US2005101153-A1; DE10392752-T0; JP2004512182-X; US7135414-B2; JP4049329-B2'],
#  [],
#  [],
#  ['US5494848-A', 'US5206532-A', 'US5489790-A', 'US5196233-A'],
#  ['US20160240321-A1',
#   'US20150325884-A1',
#   'US20170352868-A1',
#   'US20190190068-A1',
#   'JP2019121603-A',
#   'KR2017007850-A'],
#  ['US6350665-B1',
#   'US20020145156-A1',
#   'US5955746-A',
#   'US6649490-B1',
#   'US20040188806-A1',
#   'US6555868-B2',
#   'US6451704-B1',
#   'US6271564-B1',
#   'US5945710-A',
#   'JP95321234-A',
#   'US5925912-A',
#   'US6429083-B1',
#   'US6853020-B1',
#   'US6031266-A',
#   'US6232221-B1',
#   'US20020056887-A1',
#   'US6545317-B2',
#   'US6150266-A',
#   'US5824588-A',
#   'US5789298-A',
#   'JP96330588-A',
#   'US6020242-A',
#   'US5929483-A',
#   'US5455444-A',
#   'US20030178688-A1',
#   'US4717684-A',
#   'JP2002231835-A',
#   'JP2000150873-A'],
#  [],
#  ['JP06500671-W',
#   'JP01041277-A',
#   'JP01089569-A',
#   'JP03250671-A',
#   'JP4504033-T',
#   'JP04504033-W',
#   'JP05275722-A',
#   'JP6500671-T',
#   'JP09283779-A',
#   'JP02123770-A',
#   'JP63119273-A'],
#  ['US20130240708-A1',
#   'US20110074960-A1',
#   'US20160274282-A1',
#   'KR2014029933-A',
#   'US20120001285-A1',
#   'US20090250594-A1',
#   'JP4741015-B2',
#   'US20150323385-A1',
#   'KR2012029324-A',
#   'US20130327927-A1'],
#  ['US4330680-A',
#   'US7670937-B2',
#   'US20050172996-A1',
#   'JP2001127370-A',
#   'US7339110-B1',
#   'US5595607-A',
#   'US4133698-A'],
#  [],
#  ['US20030160026-A1',
#   'US4557037-A',
#   'US4234352-A',
#   'US4478879-A',
#   'US5151168-A',
#   'US6638688-B2',
#   'GB2095904-A',
#   'US4927770-A',
#   'WO2001083391-A1',
#   'US5053083-A',
#   'WO1982001102-A',
#   'US5217751-A',
#   'US6551931-B1',
#   'US20020064729-A1',
#   'US5310699-A',
#   'US4920639-A',
#   'US6387726-B1'],
#  ['US20110000532-A1',
#   'US20110036404-A1',
#   'US20100243041-A1',
#   'JP2005310830-A',
#   'JP2006310373-A',
#   'CN101167191-A',
#   'JP2010147324-A',
#   'US8637340-B2',
#   'JP2003124483-A'],
#  [],
#  [],
#  [],
#  [],
#  ['US20200194671-A1', 'US20130126821-A1'],
#  ['US6034894-A',
#   'US6117756-A',
#   'US5767005-A',
#   'US6127227-A',
#   'US5889305-A',
#   'US6200856-B1',
#   'US5557122-A',
#   'US6136653-A',
#   'US6204159-B1',
#   'US5892257-A',
#   'US6342715-B1'],
#  [],
#  [],
#  ['JP09232235-A',
#   'JP2003158286-A',
#   'JP2009140941-A',
#   'JP2011192733-A',
#   'JP2003258286-A',
#   'JP09032235-A'],
#  [],
#  ['JP2004327630-A',
#   'JP2011066196-A',
#   'JP2009040951-A',
#   'JP2004311455-A',
#   'JP2011077160-A',
#   'JP2010177398-A',
#   'JP2011222811-A',
#   'JP2011517137-A'],
#  ['US20120100665-A1',
#   'US20120152330-A1',
#   'US20120000506-A1',
#   'US20030168578-A1',
#   'US20140224313-A1',
#   'US20130000722-A1',
#   'US20010032664-A1',
#   'US20090084425-A1',
#   'US20120222731-A1',
#   'JP2003324209-A',
#   'US20110272012-A1',
#   'US20030227017-A1',
#   'US20150280031-A1'],
#  ['US20090308438-A1',
#   'US20110279399-A1',
#   'CN101976140-A',
#   'CN202331407-U',
#   'CN102116949-A'],
#  ['US20060046149-A1',
#   'US4794057-A',
#   'US20050158630-A1',
#   'US20070148552-A1',
#   'US20090087728-A1',
#   'US6488721-B1',
#   'US5882721-A',
#   'US7112389-B1',
#   'US5069988-A'],
#  ['US20090283819-A1',
#   'US20080014739-A1',
#   'US6399286-B1',
#   'US20030027433-A1',
#   'US7387921-B2'],
#  ['US4857290-A',
#   'JP62270424-A',
#   'JP07242411-A',
#   'US5028360-A',
#   'US5028407-A',
#   'US4973462-A',
#   'JP63021213-A',
#   'DE10211958-A1'],
#  ['CN101092308-A',
#   'CN101901844-A',
#   'CN101271929-A',
#   'CN101345263-A',
#   'CN101295739-A',
#   'JP02213432-A'],
#  [],
#  ['US20060223293-A1',
#   'US20070151599-A1',
#   'US20070090450-A1',
#   'US20070256728-A1'],
#  ['US5436188-A',
#   'US5229326-A',
#   'JP03021030-A',
#   'EP534130-A1',
#   'US5275972-A',
#   'US5246882-A',
#   'US5478768-A'],
#  ['CN104751942-A', 'CN104867537-A', 'CN103000249-A'],
#  ['US20090211627-A1',
#   'US20100243036-A1',
#   'US20110272012-A1',
#   'US20110203664-A1',
#   'US20040103937-A1',
#   'US20090014063-A1',
#   'US20110203648-A1',
#   'US20100218826-A1',
#   'US20100105190-A1'],
#  ['US4338480-A',
#   'US6281426-B1',
#   'US4316049-A',
#   'US6939790-B2',
#   'US20040200523-A1',
#   'US4255211-A',
#   'US20020170592-A1',
#   'US6432741-B1'],
#  ['US20110284805-A1', 'US20110111303-A1', 'US20100310941-A1'],
#  ['JP2000149997-A',
#   'JP2000323173-A',
#   'JP05190208-A',
#   'JP10074502-A',
#   'JP2002025531-A'],
#  [],
#  ['CN103238238-A',
#   'US20140342222-A1',
#   'CN104362300-A',
#   'US20060286455-A1',
#   'WO2015107581-A1',
#   'CN102792498-A',
#   'CN104303356-A',
#   'US20120007028-A1',
#   'US20140248543-A1',
#   'CN1848487-A',
#   'US20150072246-A1',
#   'US20100273066-A1'],
#  ['US20090263958-A1',
#   'US6461581-B1',
#   'US7303736-B2',
#   'US5800794-A',
#   'US20120295160-A1',
#   'WO2000017104-A1'],
#  [],
#  [],
#  [],
#  ['US20130230722-A1',
#   'US20020076911-A1',
#   'US8632633-B2',
#   'US8685843-B2',
#   'US20130174968-A1',
#   'US20140183160-A1',
#   'US20130217222-A1',
#   'US20140162021-A1',
#   'US20110089404-A1',
#   'US4764026-A'],
#  [],
#  [],
#  ['US20060228842-A1',
#   'US7928427-B1',
#   'US20100148270-A1',
#   'US20110068403-A1',
#   'US20110027956-A1',
#   'US20120104498-A1',
#   'US20130099314-A1',
#   'US20050095799-A1',
#   'US20100025779-A1',
#   'US20130009216-A1',
#   'US20060234504-A1',
# ...
#   'US4481524-A',
#   'EP217307-A',
#   'US4425574-A'],
#  ['US5340765-A',
#   'US5679980-A',
#   'US4956683-A',
#   'US5754390-A',
#   'US5581436-A',
#   'US5695815-A',
#   'US5457063-A',
#   'US5407534-A',
#   'US4309295-A',
#   'US5665628-A',
#   'US5554866-A',
#   'US5459094-A',
#   'US5491356-A',
#   'US5652464-A',
#   'EP874393-A2',
#   'US5508223-A',
#   'US5278091-A',
#   'US5619393-A',
#   'US5292677-A',
#   'US5759262-A',
#   'US6238994-B1',
#   'US5362666-A',
#   'US6291289-B1',
#   'US6218260-B1',
#   'EP924752-A2',
#   'US6175129-B1',
#   'US4811078-A',
#   'US5340763-A',
#   'US5061650-A',
#   'US5956595-A',
#   'US6004857-A',
#   'US4784973-A',
#   'US5608247-A'],
#  ['US5001023-A',
#   'US20060223895-A1',
#   'JP2004273285-A',
#   'JP2006313659-A',
#   'JP2006282969-A'],
#  ['JP11131222-A',
#   'JP06236873-A',
#   'JP63175416-A',
#   'JP11001761-A',
#   'JP03241834-A',
#   'JP62143894-A',
#   'JP61044432-A',
#   'JP11279746-A'],
#  ['US5091415-A',
#   'CN1324796-A',
#   'WO2001083092-A1',
#   'US20030144450-A1',
#   'WO2001084657-A2',
#   'JP2002110200-A',
#   'US6713643-A1',
#   'US6214060-A',
#   'US6264857-A',
#   'US4623740-A',
#   'US6713643-B2',
#   'US5283310-A',
#   'US6531539-B2',
#   'US6531539-A1',
#   'US6310110-B1',
#   'JP06192427-A'],
#  ['US20070277874-A1',
#   'US20060219293-A1',
#   'US20080070340-A1',
#   'US20020134425-A1',
#   'US6743524-B2'],
#  ['US5580798-A',
#   'US5496745-A',
#   'US4333794-A',
#   'US5027183-A',
#   'US5206182-A',
#   'US4767723-A',
#   'US5656414-A',
#   'US5087579-A',
#   'US4228448-A',
#   'US4868135-A',
#   'US3820235-A',
#   'US5916821-A',
#   'US5882977-A',
#   'US5382824-A',
#   'US5696025-A'],
#  ['JP2007061929-A',
#   'JP2005183708-A',
#   'JP2005001083-A',
#   'JP2005052936-A',
#   'JP2000071167-A',
#   'JP11151660-A',
#   'JP2003516872-A',
#   'JP2005120253-A'],
#  [],
#  ['CN106299131-A',
#   'CN107591483-A',
#   'WO2012086121-A1',
#   'CN107068865-A',
#   'US20040058504-A1',
#   'CN108807689-A',
#   'CN108802878-A',
#   'KR1496609-B1',
#   'CN107452880-A',
#   'CN103901516-A',
#   'CN107591485-A',
#   'CN107479121-A'],
#  ['CN103794800-A',
#   'CN106848240-A',
#   'CN103985853-A',
#   'CN102642024-A',
#   'CN106328884-A',
#   'CN104752728-A',
#   'CN105958042-A',
#   'JP2016115435-A'],
#  ['US4267632-A',
#   'US5095344-A',
#   'US5312781-A',
#   'US5397724-A',
#   'US5374575-A',
#   'US4652334-A',
#   'US4385432-A',
#   'US4101344-A',
#   'US5045489-A',
#   'US5025494-A',
#   'US5385857-A',
#   'JP01260841-A',
#   'JP59004137-A',
#   'US5418176-A',
#   'JP03101252-A',
#   'US4849369-A',
#   'US3970486-A',
#   'US5196367-A',
#   'US5070032-A',
#   'US5343063-A'],
#  [],
#  ['US6191353-B1',
#   'US5681402-A',
#   'US20070131278-A1',
#   'US20030079772-A1',
#   'JP2006060028-A',
#   'US2785349-A',
#   'US20080318034-A1',
#   'US20070063156-A1',
#   'US20080289682-A1',
#   'US20050263183-A1',
#   'JP2000332284-A',
#   'US4239555-A',
#   'US6353211-B1',
#   'US20060054987-A1',
#   'US20060000506-A1',
#   'US20080115825-A1'],
#  ['US20120005547-A1',
#   'WO2012166974-A2',
#   'US20120055547-A1',
#   'WO2010123974-A1; AU2010239265-A1; CA2759708-A1; EP2422373-A1; MX2011011138-A1; US2012055547-A1; KR2012022970-A; CN102460715-A; JP2012525006-W; IN201108628-P1; VN30873-A; HK1169746-A0; SG175752-A1; MX316745-B; AU2010239265-B2; JP5576474-B2; JP2014207475-A; AU2014221242-A1; SG175752-B; VN42248-A; US9130074-B2; CN102460715-B; CN104952943-A; US2015357487-A1; JP5833710-B2; AU2014221242-B2; JP2016026409-A; AU2016202055-A1; VN10014725-B; VN46703-A; HK1169746-A1; KR1714097-B1; US9666732-B2; CN104952943-B; US2017236952-A1; JP6219902-B2; JP2018011082-A; CA2759708-C; JP6587664-B2; JP2019208079-A; VN10026066-B; JP7104007-B2',
#   'US20090149030-A1'],
#  ['US20050126627-A1',
#   'US20090223561-A1',
#   'US6787692-B2',
#   'US6340640-B1',
#   'WO2009104899-A2',
#   'US4829013-A',
#   'US20040152326-A1',
#   'EP1005095-A1',
#   'US4514582-A',
#   'US5370747-A'],
#  [],
#  ['CN102222733-A',
#   'CN101527326-A',
#   'CN102623572-A',
#   'CN1609270-A',
#   'CN102199760-A',
#   'JP2002270879-A'],
#  [],
#  ['US20060235178-A1',
#   'US4604457-A',
#   'CN101570644-A',
#   'CN104094435-A',
#   'CN105190927-A'],
#  ['WO2011033299-A1',
#   'CN101501906-A',
#   'CN101375443-A',
#   'CN102823045-A',
#   'JP07282825-A',
#   'CN101300710-A'],
#  ['US20060180199-A1',
#   'US20100282309-A1',
#   'US20100065829-A1',
#   'US20120313080-A1',
#   'US20150283265-A1',
#   'US20080288067-A1',
#   'US20160082272-A1',
#   'US20130184783-A1'],
#  [],
#  ['CN108496266-A',
#   'CN108370029-A',
#   'CN106959565-A',
#   'CN109192922-A',
#   'WO2018147558-A1',
#   'CN106829932-A',
#   'CN109494347-A',
#   'CN1830103-A',
#   'CN108417777-A',
#   'CN102931378-A',
#   'CN104332323-A',
#   'CN109075315-A'],
#  ['US20030207513-A1',
#   'US20080004197-A1',
#   'US20080160661-A1',
#   'US20050082651-A1',
#   'US4608451-A',
#   'US20010039101-A1',
#   'US5101260-A',
#   'US5589704-A',
#   'US6420647-B1',
#   'US3998659-A',
#   'US6451218-B1',
#   'US4514582-A',
#   'US20070278183-A1',
#   'US4683160-A',
#   'US20070072423-A1',
#   'US6093882-A',
#   'US6245245-B1'],
#  [],
#  ['US20130009124-A1'],
#  ['JP2005259548-A', 'JP2007012297-A'],
#  ['JP05110125-A',
#   'JP2003188401-A',
#   'JP07321362-A',
#   'JP2006120737-A',
#   'JP11274528-A',
#   'JP05206490-A',
#   'JP2003298088-A',
#   'JP2000150934-A'],
#  ['WO2017004624-A1',
#   'CN109216499-A',
#   'US20170133545-A1',
#   'CN109216498-A',
#   'CN109216491-A'],
#  ['KR2010036520-A',
#   'US20100078701-A1',
#   'JP2011066417-A',
#   'US8916926-B2',
#   'KR2013127791-A',
#   'KR2012121746-A',
#   'US20120276702-A1',
#   'US20110065270-A1'],
#  ['JP2009235478-A', 'KR2010080379-A', 'KR2009066866-A', 'JP2008303436-A'],
#  [],
#  ['US4174234-A',
#   'DE3036104-A',
#   'US3491675-A',
#   'DE3100245-A',
#   'US4252861-A',
#   'DE2604351-B',
#   'DE2704913-C',
#   'DE3010557-A',
#   'US4409263-A',
#   'US4251570-A'],
#  [],
#  [],
#  ['US5859453-A',
#   'US6605507-B2',
#   'US20020031886-A1',
#   'US6437394-B1',
#   'US5946240-A',
#   'US6614071-B1',
#   'US5600164-A',
#   'JP2000128428-A'],
#  ['US20060278497-A1',
#   'EP1089346-A2',
#   'US6268558-B1',
#   'JP2008544485-A',
#   'US4873201-A',
#   'US20080268560-A1',
#   'DE10050577-A1',
#   'DE3727826-A; US4879251-A',
#   'JP93183177-A',
#   'JP89171284-A',
#   'EP320089-A',
#   'JP63283077-A',
#   'US5348589-A',
#   'US4726849-A',
#   'DE3727826-A; US4879251-A',
#   'WO2000007249-A1',
#   'US6400722-B1',
#   'CN1866546-A',
#   'US5453134-A',
#   'WO2005024920-A1',
#   'JP2007119911-A',
#   'JP05183177-A',
#   'US6426235-B1',
#   'US6323056-B1',
#   'DE19651655-C2',
#   'US4746618-A',
#   'US20070123005-A1',
#   'US20070205462-A1',
#   'US20060111047-A1',
#   'GB1575888-A',
#   'US6870808-B1',
#   'US20060280588-A1',
#   'US20070205400-A1',
#   'US6578764-B1',
#   'JP2006222384-A',
#   'US5468974-A',
#   'JP2000058886-A',
#   'US20030044539-A1',
#   'JP88283077-A',
#   'US4758526-A'],
#  [],
#  ['CN102592972-A',
#   'CN109148262-A',
#   'US9453190-B1',
#   'CN103464415-A',
#   'CN104868020-A',
#   'CN109365384-A'],
#  [],
#  ['US5504031-A',
#   'US5395787-A',
#   'US5780349-A',
#   'US5637518-A',
#   'US5897357-A',
#   'US6313505-B2',
#   'US5731239-A',
#   'US6083798-A',
#   'US5915183-A',
#   'US6239472-B1',
#   'US4587710-A',
#   'US5314832-A',
#   'US5885877-A',
#   'US5773358-A',
#   'US5953605-A',
#   'US5998844-A',
#   'US6001698-A',
#   'US5811329-A',
#   'US4784971-A',
#   'US5352631-A',
#   'US5851883-A',
#   'US5674774-A',
#   'US5902125-A',
#   'US4948745-A',
#   'US5571733-A',
#   'US5496750-A',
#   'US5827768-A'],
#  [],
#  ['JP10021929-A', 'JP8273675-A'],
#  ['US2011001114-A1',
#   'US7729161-B2',
#   'US6096601-A',
#   'US2010295123-A1',
#   'US2005145911-A1; US7489002-B2',
#   'US2010295121-A1; JP2010272679-A; US8198674-B2',
#   'US2009286368-A1',
#   'US2008164452-A1'],
#  ['US6037228-A',
#   'US5545588-A',
#   'US6001541-A',
#   'US6074939-A',
#   'US6114230-A',
#   'US5759916-A',
#   'US5733712-A',
#   'US5554486-A'],
#  [],
#  ['KR2008024559-A', 'KR2010098897-A', 'KR783766-B1', 'KR2008049168-A'],
#  [],
#  ['CN102439709-A',
#   'CN102318078-A',
#   'JP2012514851-A',
#   'CN103674974-A',
#   'JP2013232607-A',
#   'JP2000065759-A',
#   'US6236044-B1',
#   'US20010054693-A1',
#   'WO2015132532-A1',
#   'US20140069498-A1',
#   'US8048814-B2',
#   'US20120040490-A1',
#   'TW201248893-A',
#   'JP2012527777-A',
#   'CN201824657-U',
#   'US8697987-B2',
#   'US8288176-B2',
#   'JP2014007188-A',
#   'US20120004049-A1'],
#  ['CN103112819-A',
#   'CN102249238-A',
#   'CN103022247-A',
#   'CN103337449-A',
#   'CN102280588-A',
#   'CN102263204-A',
#   'CN101723312-A'],
#  [],
#  ['CN103390694-A', 'CN103441183-A', 'JP2013117047-A'],
#  ['US20120091419-A1',
#   'US20080025078-A1',
#   'US20090168492-A1',
#   'US20090227067-A1',
#   'US20080219039-A1',
#   'US7706169-B2'],
#  [],
#  [],
#  ['JP07053272-A',
#   'JP2004250771-A',
#   'JP02153068-A',
#   'JP2003080077-A',
#   'JP2001187115-A',
#   'JP90014360-U',
#   'JP2014360-U',
#   'JP21533068-A'],
#  ['JP05013794-A',
#   'DE4332512-A1',
#   'US4968631-A',
#   'US5365068-A',
#   'US5772328-A',
#   'US5591975-A',
#   'US6285807-B1',
#   'DE3606557-A',
#   'US4891075-A',
#   'US5869972-A',
#   'US5656817-A',
#   'US4836012-A',
#   'US4957012-A',
#   'AT403961-B',
#   'DE4332512-C2',
#   'DE4018053-A',
#   'US5866433-A',
#   'DE19725050-A1',
#   'US4127738-A',
#   'US4629821-A',
#   'DE19707776-A1',
#   'US5037615-A'],
#  ['US6781180-B1',
#   'US20050056873-A1',
#   'US5177576-A',
#   'US6873003-B2',
#   'US6858893-B2',
#   'US6822281-B2',
#   'US20020066925-A1',
#   'US20030003651-A1',
#   'US20050085096-A1',
#   'US6066527-A',
#   'US20020076884-A1',
#   'US5949700-A',
#   'US20020090780-A1',
#   'US20050136631-A1',
#   'US6946345-B2',
#   'US20020089007-A1',
#   'US20050106831-A1',
#   'US6828192-B2',
#   'US6853025-B2',
#   'US20030062562-A1',
#   'US20050001286-A1',
#   'US6229173-B1',
#   'US6440793-B1',
#   'US6621112-B2',
#   'US6509599-B1',
#   'US6441422-B1',
#   'US20040241939-A1',
#   'US6777737-B2',
#   'US6255683-B1'],
#  [],
#  [],
#  [],
#  ['JP10257687-A',
#   'JP05310418-A',
#   'JP06036798-A',
#   'JP63276873-A',
#   'US4303748-A',
#   'JP09259857-A',
#   'JP10223221-A',
#   'JP08287915-A',
#   'JP04249073-A',
#   'JP03037964-A',
#   'US5296318-A',
#   'JP07296854-A',
#   'JP07029601-A',
#   'US5770333-A',
#   'JP05234593-A',
#   'JP3014054-B2',
#   'JP10509683-W',
#   'JP11135120-A',
#   'US5085952-A',
#   'JP07240201-A',
#   'JP06103976-A',
#   'JP06279049-A',
#   'JP10294112-A',
#   'JP11086853-A',
#   'JP55136131-A',
#   'US4302518-A',
#   'US5677081-A',
#   'JP09063651-A',
#   'US5460903-A',
#   'EP883199-B1',
#   'JP04206479-A',
#   'US4427751-A',
#   'EP730316-A1',
#   'JP06098473-A',
#   'US5589296-A',
#   'JP63274058-A',
#   'WO1998007729-A1',
#   'JP10316426-A',
#   'JP11185753-A',
#   'JP10092424-A',
#   'JP10003947-A',
#   'JP10036120-A',
#   'JP05062712-A',
#   'US5665265-A',
#   'US6090505-A',
#   'US5275750-A',
#   'JP08250117-A',
#   'WO1996010538-A1',
#   'US5223353-A',
#   'JP04242890-A',
#   'US5160712-A',
#   'EP883199-A1',
#   'JP04267053-A'],
#  [],
#  ['US5597765-A',
#   'US6011298-A',
#   'US5879971-A',
#   'US5079608-A',
#   'US6201279-B1',
#   'US7033876-B2',
#   'US6689662-B2',
#   'US5595927-A',
#   'US6346464-B1',
#   'US6184555-B1',
#   'US5897360-A',
#   'US5714781-A',
#   'US7345342-B2',
#   'US5895951-A',
#   'US5895952-A',
#   'US6362505-B1',
#   'US6037202-A',
#   'US6174773-B1',
#   'US20030032274-A1',
#   'US5275965-A',
#   'US4893160-A',
#   'US5877528-A',
#   'US20030073321-A1',
#   'US6368921-B1',
#   'US6359308-B1',
#   'US3564356-A',
#   'US5605852-A',
#   'US4992390-A',
#   'US5298781-A',
#   'US4823176-A',
#   'US5879994-A',
#   'US6351009-B1',
#   'US6174785-B1',
#   'US6677643-B2',
#   'US4326332-A',
#   'US7504306-B2',
#   'US6040600-A',
#   'US6015727-A',
#   'US5405794-A',
#   'US4579621-A',
#   'US6171935-B1',
#   'US6048772-A',
#   'US20030060013-A1',
#   'US6365930-B1',
#   'US6034415-A',
#   'US5623152-A',
#   'US6353252-B1',
#   'US7161208-B2',
#   'US6222233-B1',
#   'US5705409-A',
#   'US6037628-A',
#   'US5719409-A',
#   'US6049108-A',
#   'US6037632-A',
#   'US5592005-A',
#   'US4914058-A',
#   'US6724042-B2',
#   'US4801986-A',
#   'US5389815-A',
#   'US6168983-B1',
#   'US5294824-A',
#   'US6188105-B1',
#   'US5897343-A',
#   'US6190978-B1',
#   'US6346469-B1',
#   'US6337499-B1',
#   'US6184545-B1',
#   'US5283201-A',
#   'US4639761-A',
#   'US6534367-B2',
#   'US4636281-A',
#   'US6376314-B1',
#   'US6174769-B1',
#   'US5710072-A',
#   'US5105243-A',
#   'US6518127-B2',
#   'US6204097-B1',
#   'US6368920-B1',
#   'US6538280-B2',
#   'US6188104-B1',
#   'US5298761-A',
#   'US6376878-B1',
#   'US6376890-B1',
#   'US6509240-B2',
#   'US6207994-B1',
#   'US6191447-B1',
#   'US3497777-A',
#   'US6020250-A',
#   'US6168996-B1',
#   'US7344943-B2',
#   'US4638344-A',
#   'US4821095-A',
#   'US6362112-B1',
#   'US4990463-A',
#   'US6365462-B2',
#   'US6198127-B1',
#   'US5300447-A',
#   'US6376348-B1',
#   'US4003072-A'],
#  [],
#  ['EP3034568-A1', 'CN107400471-A', 'CN105646995-A', 'CN103013364-A'],
#  ['US10629898-B2',
#   'US10211454-B2',
#   'US9941509-B2',
#   'US9806328-B2',
#   'US20180062168-A1',
#   'US20170338481-A1',
#   'US5326732-A',
#   'US20110051322-A1',
#   'US20110229761-A1',
#   'US20150325848-A1',
#   'US7776473-B2',
#   'US20170338464-A1',
#   'US8889295-B2',
#   'US9190186-B2',
#   'US20140255785-A1',
#   'US20150295227-A1',
#   'US9997765-B2',
#   'US9553303-B2',
#   'US8071238-B2',
#   'US9178208-B2',
#   'US10461320-B1',
#   'US4515860-A',
#   'US10103378-B2',
#   'US20180090755-A1',
#   'US10615418-B1',
#   'US20140079997-A1',
#   'US20150318571-A1',
#   'US4154787-A',
#   'US20180269480-A1',
#   'US9570751-B2',
#   'US20180175390-A1',
#   'US10461325-B1',
#   'US9583757-B2',
#   'US10511048-B2',
#   'US10476071-B2',
#   'US20140264201-A1',
#   'US9397338-B2',
#   'US10608240-B1',
#   'US20130344391-A1',
#   'US7906238-B2',
#   'US20160013483-A1',
#   'US20190088939-A1',
#   'US10622632-B1'],
#  [],
#  [],
#  [],
#  ['JP159272-A',
#   'US4377857-A',
#   'US4754320-A',
#   'US4769786-A',
#   'US4451904-A',
#   'US4326331-A',
#   'JP62043179-A'],
#  ['WO2009044144-A2'],
#  ['US6046487-A',
#   'US5665619-A',
#   'US4914058-A',
#   'JP01022051-A',
#   'US4746630-A',
#   'US4990463-A',
#   'US4716126-A',
#   'US5429977-A',
#   'JP63288047-A',
#   'US5595927-A',
#   'US5567634-A',
#   'US4326332-A',
#   'US5498578-A',
#   'US4774556-A',
#   'US4967245-A',
#   'US5350937-A'],
#  ['US5998252-A',
#   'US5866451-A',
#   'US6133130-A',
#   'US6015730-A',
#   'US6177306-B1',
#   'US6174758-B1',
#   'US6004843-A',
#   'US6074908-A',
#   'US6069037-A'],
#  [],
#  ['JP2002231631-A',
#   'US5455673-A',
#   'KR2005111169-A',
#   'US20010002324-A1',
#   'JP62145775-A',
#   'KR2005076238-A',
#   'JP2002009012-A',
#   'US7563659-B2',
#   'JP2006066607-A',
#   'JP10107106-A',
#   'US20030232468-A1',
#   'KR2005054788-A',
#   'US5389580-A',
#   'KR2005106547-A'],
#  [],
#  ['US5027185-A',
#   'US4708904-A',
#   'US4640004-A',
#   'US5221853-A',
#   'US5883003-A',
#   'US4886764-A',
#   'US5023201-A',
#   'US5286678-A',
#   'US5550079-A',
#   'US5856237-A',
#   'US6080645-A',
#   'US5514902-A',
#   'US5849634-A',
#   'DE19603165-A1; JP9074195-A; KR97008645-A; US5801425-A; TW373265-A; US6180519-B1; DE19603165-C2',
#   'US5146309-A',
#   'US5518958-A'],
#  ['US20110018047-A1',
#   'US20100248465-A1',
#   'US20130092894-A1',
#   'US9876027-B2',
#   'US9269718-B1',
#   'US9997535-B2',
#   'US20150318038-A1',
#   'US6753570-B1',
#   'US20150263018-A1',
#   'US20170062456-A1',
#   'US20150060992-A1',
#   'US9484357-B2',
#   'US20090289306-A1',
#   'US20140070304-A1',
#   'US20190198630-A1',
#   'US9666525-B2',
#   'US20080265306-A1',
#   'US9524984-B1',
#   'US20160071861-A1',
#   'US20130126812-A1',
#   'US20160118391-A1',
#   'US9484358-B2',
#   'US10396125-B2',
#   'US9397143-B2',
#   'US20160104719-A1',
#   'US10147875-B1',
#   'US20150287916-A1',
#   'US9748267-B2',
#   'US6764966-B1',
#   'US2007010061-A1; US7674698-B2',
#   'US20160079434-A1',
#   'US9748266-B1',
#   'US9305933-B2',
#   'US9985098-B2',
#   'US20180090313-A1',
#   'US20130313576-A1',
#   'US20170117289-A1',
#   'US9281471-B2',
#   'US8053302-B2',
#   'US20160358933-A1'],
#  ['EP2031660-A2',
#   'US20050034755-A1',
#   'US20090211627-A1',
#   'US20090320910-A1',
#   'WO2009008323-A1',
#   'US4345107-A',
#   'JP2006134827-A',
#   'US20110005597-A1',
#   'WO2006132672-A2',
#   'EP1453117-A2'],
#  ['US4876162-A',
#   'US6605380-B2',
#   'US20050123420-A1',
#   'US20060099470-A1',
#   'US20070166587-A1',
#   'JP2001118596-A'],
#  ['JP2002212685-A',
#   'JP2000256808-A',
#   'JP2000265248-A',
#   'JP2001214286-A',
#   'JP07048654-A',
#   'JP09176800-A',
#   'JP2000294256-A'],
#  [],
#  ['US7042044-B2', 'US20090029511-A1', 'US7250651-B2'],
#  ['US6437374-B1',
#   'DE10228781-A1',
#   'US20120292648-A1',
#   'CN102157648-A',
#   'US20120074385-A1',
#   'US20100219445-A1',
#   'US20030016526-A1',
#   'DE102010052542-A1',
#   'EP2360745-A2',
#   'CN102468389-A'],
#  [],
#  ['US20070111408-A1',
#   'US20040202041-A1',
#   'US6869844-B1',
#   'US4554729-A',
#   'US5324982-A',
#   'US20080265236-A1',
#   'US5904518-A',
#   'US7109547-B2',
#   'US5386135-A',
#   'US6300194-B1',
#   'US7439591-B2',
#   'US6020643-A',
#   'US5148255-A',
#   'US6987036-B2',
#   'US20040014323-A1',
#   'US6831316-B1'],
#  ...]

# %%
PN=data['PN']

#pn的列表
pn_list=[]
for pn in PN:
    pn=pn.split(';')
    pn=list(set([i.strip() for i in pn])) #去除每个元素两端的空格
    pn_list.append(pn)

# %%
data.columns
# Out:
# Index(['index', 'PN', 'TI', 'AB', 'AU', 'AE', 'CP', 'TM', 'IPC', 'IPClass',
#        'class1', 'class3', 'class4', 'newClass'],
#       dtype='object')

# %%
from tqdm import tqdm #导入了 tqdm 库，用于在循环中显示进度条，提供了对处理进度的可视化

relationList=[]
for i in tqdm(range(len(data))):
#for i in range(10):
    #print(i)
    #生成四种关系的三元组
    #专利-专利
    if cp_list[i]!=[]:
        for cp in cp_list[i]: 
            relationList.append(data['PN'][i]+'\t'+'patent_patent'+'\t'+cp)
    #专利-权利人
    #权利人-权利人
    if data['AE'][i]!='':
        ae_list=data['AE'][i].split(';')
        ae_list=[i.strip() for i in ae_list]
        ae_list=list(set(ae_list)) #获得不重复的所有权利人的列表

        for ae in ae_list:
            relationList.append(data['PN'][i]+'\t'+'patent_author'+'\t'+ae)
        for a in range(len(ae_list)):
            for b in range(len(ae_list)):
                if a<b:
                    relationList.append(ae_list[a]+'\t'+'author_author'+'\t'+ae_list[b])
    #专利-年份
    relationList.append(data['PN'][i]+'\t'+'patent_year'+'\t'+str(data['TM'][i]).strip())
    #专利-国家
    for pn in pn_list[i]:
        relationList.append(data['PN'][i]+'\t'+'patent_nation'+'\t'+pn[:2]) #表示获取 pn 中的前两个字符，即国家代码
    

#然后存成txt文件
with open(r'/root/autodl-tmp/模型代码/DeepModel_Gui/embedding/transX/data/val.txt','w') as fp:
    for i in range(len(relationList)):
        fp.write(relationList[i])
        fp.write('\n')
# Out:
# 100%|██████████| 5577/5577 [00:01<00:00, 5527.92it/s]

# %%
len(data['PN'])
# Out:
# 5577

# %%
len(relationList)
# Out:
# 108361
