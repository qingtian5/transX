# %%
#把数据处理成transX输入的格式
import pandas as pd
data=pd.read_excel(r'/workspace/ysn_proj_0409/root/autodl-tmp/transX/train_test.xlsx')
data.head()
# Out:
#    index                             PN  \
# 0    297  US2002130356-A1; US6504206-B2
# 1  41817               IN201941010600-A
# 2   8981                 IN201200213-I2
# 3   4023     JP59055076-A; JP91051114-B
# 4  16582                 JP2018026594-A
#
#                                                   TI  \
# 0  Production of split gate multiple storage flas...
# 1  Melanin-based solar panel comprises melanin wh...
# 2  Method for plasma texturing of multicrystallin...
# 3  Amorphous silicon thin film solar cell - has N...
# 4  Plasma chemical vapor deposition (CVD) apparat...
#
#                                                   AB  \
# 0  NOVELTY - A split gate multiple storage flash ...
# 1  NOVELTY - A melanin-based solar panel comprise...
# 2  NOVELTY - The method involves introducing mixt...
# 3                                                NaN
# 4  NOVELTY - The apparatus has a reaction contain...
#
#                                                   AU  \
# 0                         SUNG H;KUO D;HSIEH C;LIN Y
# 1  SILI V S;ASWATHY B S;VISWANATHAN A A;ARCHANA C...
# 2       PATHAK M;SAXENA A K;BASUDEV P;BHATTACHARYA S
# 3              SUZUKI K;ASANO M;NAKATANI K;OKANIWA H
# 4                                           MURATA M
#
#                                                   AE  \
# 0  TAIWAN SEMICONDUCTOR MFG CO (TSMC-C);TAIWAN SE...
# 1  SILI V S (SILI-Individual);ASWATHY B S (ASWA-I...
# 2              BHARAT HEAVY ELECTRICALS LTD (BHAR-C)
# 3            AGENCY OF IND SCI & TECHNOLOGY (AGEN-C)
# 4                         MURATA M (MURA-Individual)
#
#                                                   CP      TM  \
# 0     US6504206-B2:US5067108-A   SILICON STORAGE ...  2002.0
# 1                                                NaN  2020.0
# 2                                                NaN  2016.0
# 3                                                NaN  1984.0
# 4                                                NaN  2018.0
#
#                                                  IPC  \
# 0          H01L-021/336; H01L-029/788; H01L-021/8247
# 1  A61B-018/14; B01J-019/08; C01B-003/00; G21K-00...
# 2                                       H01L-031/036
# 3                                        H01L-031/04
# 4  C23C-016/24; C23C-016/509; H01L-021/31; H05H-0...
#
#                                              IPClass  \
# 0  ['H01L-021/336', ' H01L-029/788', ' H01L-021/8...
# 1  ['A61B-018/14', ' B01J-019/08', ' C01B-003/00'...
# 2                                   ['H01L-031/036']
# 3                                    ['H01L-031/04']
# 4  ['C23C-016/24', ' C23C-016/509', ' H01L-021/31...
#
#                       class1                               class3  \
# 0                      ['H']                              ['H01']
# 1  ['G', 'A', 'H', 'B', 'C']  ['A61', 'B01', 'C01', 'G21', 'H05']
# 2                      ['H']                              ['H01']
# 3                      ['H']                              ['H01']
# 4                 ['H', 'C']                ['H05', 'H01', 'C23']
#
#                                      class4  newClass
# 0                                  ['H01L']  ['H01L']
# 1  ['C01B', 'B01J', 'H05H', 'G21K', 'A61B']  ['C01B']
# 2                                  ['H01L']  ['H01L']
# 3                                  ['H01L']  ['H01L']
# 4                  ['C23C', 'H01L', 'H05H']  ['H01L']

# %%
CP=data['CP']

cp_list=[]
for cp in CP:
    if pd.isna(cp): #是否是缺失值NAN
        cp_list.append([])
        continue
    else:
        List1=cp.split('**[EOP]**')
        #print(List1)
        List1=[l[l.index(':')+1:] for l in List1]#对 List1 中的每个元素，从第一个冒号 ':' 的位置开始截取子字符串，去除冒号及之前的部分
        List2=[i.split('--[EOL]--') for i in List1] #得到一个二维列表，i和对应的子集
        List=[j for i in List2 for j in i] #将二维列表 List2 扁平化为一维列表 List
        List=[i for i in List if i!=''] #去除列表 List 中的空字符串元素
        List=[i.split()[0] for i in List] #对 List 中的每个元素按空格进行分割，并取每个分割后的列表中的第一个元素，得到一个新的列表 List
        
        List=list(set(List)) #去重
        cp_list.append(List)

# %%
#看一下cp_list里的每个元素，找pn_list的对应的元素
#总的来说，这段代码的作用是检查 cp_list 中的每个元素是否出现在数据集中 'PN' 列的某个元素中，如果是，则将该元素替换为对应的 'PN' 列元素
from tqdm import tqdm #导入了 tqdm 库，用于在循环中显示进度条，提供了对处理进度的可视化

for i in tqdm(range(len(cp_list))):
    for j in range(len(cp_list[i])):
        for pn in data['PN']:
            if cp_list[i][j] in pn:
                cp_list[i][j]=pn
# Out:
# 100%|██████████| 512/512 [00:01<00:00, 509.65it/s]

# %%
cp_list
# Out:
# [['US5067108-A', 'US5679970-A', 'US5508955-A', 'US5440158-A', 'US5420060-A'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['CN203674224-U', 'US4234352-A', 'CN103367547-A'],
#  [],
#  ['US20080166842-A1',
#   'US20060078827-A1',
#   'US20070023396-A1',
#   'US4113551-A',
#   'US20060057855-A1',
#   'WO2008157345-A2',
#   'US20070262048-A1',
#   'US6632743-B1',
#   'US20020137357-A1',
#   'US20050189015-A1',
#   'US6589439-B2',
#   'US6083849-A',
#   'US20100216315-A1',
#   'WO2003104901-A2',
#   'US5466389-A',
#   'US20030207777-A1',
#   'US20040161933-A1',
#   'US20030153170-A1',
#   'US6391794-B1',
#   'CN1659480-A',
#   'JP2005217260-A',
#   'US6194319-B1',
#   'US6572453-B1',
#   'US20050095840-A1',
#   'US20040013858-A1',
#   'JP2005129714-A',
#   'US6100198-A',
#   'US6306774-B1',
#   'US6303515-B1',
#   'US20010016425-A1',
#   'US6344418-B1',
#   'US6468951-B1',
#   'US6044851-A',
#   'US20070190735-A1',
#   'US20070145009-A1',
#   'US20010056052-A1',
#   'US20070099806-A1',
#   'US20030211678-A1',
#   'US6358325-B1',
#   'US20070207622-A1',
#   'US20010052351-A1',
#   'US6169037-B1',
#   'US20030017962-A1',
#   'US20060057837-A1',
#   'US7419945-B2',
#   'US6235145-B1',
#   'US5705089-A',
#   'US20060219660-A1',
#   'US6265309-B1',
#   'US5855811-A',
#   'US6372410-B1'],
#  [],
#  [],
#  ['JP2001044461-A',
#   'WO2006087786-A1',
#   'WO2014054600-A1',
#   'JP2014165265-A',
#   'US20030168660-A1',
#   'US20050150543-A1',
#   'JP09129904-A',
#   'JP2002076397-A'],
#  ['US20120222741-A1',
#   'CN102360584-A',
#   'CN102479568-A',
#   'CN102347094-A',
#   'CN101113009-A'],
#  ['DE3815512-A',
#   'EP1635398-A2',
#   'US4347263-A',
#   'US6563141-B1',
#   'US20020185171-A1',
#   'US6692985-B2',
#   'US4994879-A',
#   'KR2005087248-A',
#   'KR2008054807-A',
#   'US6846984-B2',
#   'US20100059114-A1',
#   'EP1489667-A2',
#   'US5907766-A',
#   'US5720827-A',
#   'EP735597-A2',
#   'KR2008020351-A',
#   'US20050287479-A1',
#   'US3988167-A',
#   'US20070137699-A1',
#   'US4865999-A',
#   'US20040112426-A1',
#   'EP1722419-A1',
#   'EP1772419-A2'],
#  ['US5188976-A',
#   'US5861347-A',
#   'US4306353-A',
#   'US6235585-B1',
#   'US6248632-B1',
#   'US6274430-B1',
#   'US5856221-A',
#   'US3886000-A',
#   'US6074915-A',
#   'US6620693-B2'],
#  ['KR2005041193-A',
#   'KR668836-B1',
#   'US8895393-B2',
#   'US20120070944-A1',
#   'US7307002-B2',
#   'US20080242084-A1',
#   'US9543357-B2',
#   'US20170069684-A1',
#   'US6335285-B1',
#   'US8865481-B2'],
#  ['US201072-A', 'US20050230721-A1', 'US20040201072-A1'],
#  ['CN101359701-A', 'CN101475173-A', 'US7955977-B2'],
#  ['US5437762-A',
#   'US5411905-A',
#   'US4649520-A',
#   'US4453234-A',
#   'US5403762-A',
#   'US5188973-A'],
#  ['CN104112768-A', 'CN103824883-A', 'US20050230777-A1'],
#  ['US6796484-B2',
#   'DE3821073-A',
#   'US5234574-A',
#   'US4028200-A',
#   'US6391476-B2',
#   'WO2003045618-A1',
#   'US3963454-A',
#   'US4397721-A',
#   'US20030155409-A1',
#   'US5245847-A',
#   'US4177325-A',
#   'WO2001088226-A2',
#   'US4164454-A',
#   'US6379818-B1',
#   'US4602731-A',
#   'US4721653-A',
#   'US20020088717-A1',
#   'WO1997043467-A1',
#   'US4157154-A',
#   'JP05106059-A',
#   'US3482305-A',
#   'US3896009-A',
#   'WO2001068312-A2',
#   'US20030197050-A1',
#   'US2745799-A',
#   'US3242565-A',
#   'US5422191-A',
#   'US5997721-A',
#   'US3489657-A',
#   'US6165630-A',
#   'EP795048-A1',
#   'US3862018-A',
#   'US5961853-A',
#   'US6383661-B2',
#   'JP11097298-A',
#   'US2821505-A',
#   'WO2000071781-A2',
#   'US6503640-B2',
#   'WO2002060639-A1',
#   'US20030189082-A1',
#   'WO2000071784-A2',
#   'US6129262-A',
#   'US3597658-A',
#   'FR2617868-A',
#   'US6568584-B2',
#   'US20030042146-A1',
#   'US20030064242-A1',
#   'US6599645-B2',
#   'JP54013430-A',
#   'US3970237-A',
#   'US20020175205-A1',
#   'US3692583-A',
#   'US4741811-A',
#   'WO2002086197-A1',
#   'US5246565-A',
#   'US5643434-A',
#   'US4388159-A',
#   'WO2003043777-A1',
#   'FR2354171-A',
#   'US4126522-A',
#   'US2821014-A',
#   'GB1176688-A',
#   'WO2003045619-A1',
#   'US5601695-A',
#   'WO2002007928-A1',
#   'US4346128-A',
#   'WO2002038326-A2',
#   'CH655134-A',
#   'US3881999-A',
#   'US6060174-A',
#   'US20030091856-A1',
#   'US5069980-A',
#   'GB2000525-A',
#   'US4097342-A',
#   'US5466360-A',
#   'US20030098338-A1',
#   'EP227261-A'],
#  [],
#  ['US20030099884-A1',
#   'EP1331681-A2',
#   'WO2003041206-A1',
#   'US20030160589-A1',
#   'WO2005027245-A2',
#   'US20050181275-A1'],
#  ['US20020048200-A1', 'US9093319-B2', 'US20110095348-A1'],
#  ['US6255239-B1',
#   'JP2001057287-A',
#   'US20020108940-A1',
#   'JP2004227792-A',
#   'JP59079553-A',
#   'JP2002299043-A',
#   'JP61136247-A',
#   'US20030178937-A1',
#   'EP910228-A1',
#   'JP2005086032-A',
#   'EP1079666-A2',
#   'JP11121167-A',
#   'JP2000040585-A',
#   'EP1246272-A2',
#   'US6333460-B1',
#   'WO2003005774-A1'],
#  ['US6340613-B1',
#   'US6358793-B1',
#   'US6472266-B1',
#   'US6483194-B2',
#   'US6492245-B1',
#   'US6465301-B1',
#   'US6159874-A',
#   'US6455369-B1'],
#  ['JP2019161052-A',
#   'JP10199856-A',
#   'WO2015114922-A1',
#   'JP2004071828-A',
#   'JP08213479-A'],
#  ['US20040065914-A1',
#   'US6750499-B2',
#   'US4713678-A',
#   'US6808979-B1',
#   'US5821579-A',
#   'US20050285175-A1',
#   'US20030062568-A1'],
#  [],
#  ['US5997725-A',
#   'CN1552808-A',
#   'CN1042558-A',
#   'CN1388064-A',
#   'CN1102400-A',
#   'CN1552522-A'],
#  [],
#  ['US9793273-B2',
#   'US20190035908-A1',
#   'US9805985-B2',
#   'US20140239255-A1',
#   'US8693235-B2',
#   'US20150318282-A1',
#   'US20120068268-A1',
#   'US9613953-B2',
#   'US20200161315-A1',
#   'US20160190136-A1'],
#  ['JP2064006-A',
#   'JP2007077007-A',
#   'JP61008416-B1',
#   'JP84182221-A',
#   'JP2009091228-A'],
#  ['KR2000062712-A',
#   'KR2000017032-A',
#   'KR2003089977-A',
#   'US20040262654-A1',
#   'JP2004179187-A',
#   'US6381107-B1',
#   'US4385932-A',
#   'JP2004022599-A',
#   'KR2003017120-A',
#   'US20040257719-A1',
#   'KR2005019402-A',
#   'KR2006008166-A',
#   'KR2005019395-A',
#   'KR2004043048-A'],
#  ['US7417328-B2',
#   'US6395586-B1',
#   'US8645895-B2',
#   'US7649214-B2',
#   'US20050063112-A1',
#   'US8218277-B2',
#   'US8293578-B2',
#   'US6110222-A',
#   'US8247845-B2',
#   'US7420789-B2',
#   'CN101232017-A',
#   'US20050146380-A1'],
#  ['US20120321964-A1',
#   'US20200036040-A1',
#   'US20120100436-A1',
#   'US20050219678-A1'],
#  [],
#  ['JP10012717-A',
#   'US20020109187-A1',
#   'JP09260679-A',
#   'US6208010-B1',
#   'US2003071308-A1; JP2003124345-A; US6809381-B2; JP2008160103-A; JP4433324-B2',
#   'JP08330541-A',
#   'US5674760-A',
#   'JP08228145-A',
#   'JP09135030-A',
#   'US6407427-B1',
#   'JP05291574-A',
#   'JP2001044441-A',
#   'JP06291265-A',
#   'JP11298001-A',
#   'US6215155-B1',
#   'US6632710-B2',
#   'JP2001102442-A'],
#  ['CN110931601-A', 'CN110491949-A'],
#  ['CN101894875-A', 'CN102593203-A', 'CN201495699-U'],
#  ['CN102126831-A',
#   'WO2017034457-A1',
#   'CN102044581-A',
#   'CN105609576-A',
#   'CN105977331-A',
#   'US20140332073-A1'],
#  ['US20070293016-A1',
#   'US7079413-B2',
#   'US20020022308-A1',
#   'JP2007184549-A',
#   'US7339253-B2',
#   'US20030218494-A1',
#   'US7851859-B2',
#   'US20100038745-A1',
#   'US6909149-B2',
#   'US20080116513-A1',
#   'US8120094-B2',
#   'US20080272439-A1',
#   'US20070072388-A1',
#   'US7666771-B2',
#   'US6225664-B1',
#   'US20120261792-A1',
#   'US20100176482-A1',
#   'US7259428-B2',
#   'US7825488-B2'],
#  ['CN101159297-A', 'CN1588649-A'],
#  ['US20100165725-A1',
#   'US20110205782-A1',
#   'CN102610746-A',
#   'US20100238701-A1',
#   'CN102623631-A',
#   'US20110038195-A1'],
#  ['CN102101673-A', 'CN102500296-A', 'CN101734669-A', 'CN101037205-A'],
#  ['US20050017302-A1',
#   'US20080083950-A1',
#   'US20080258141-A1',
#   'US20090152506-A1',
#   'US20070052025-A1',
#   'JP2003086000-A',
#   'JP63265818-A',
#   'US20070187760-A1',
#   'US20060169973-A1',
#   'US20050199959-A1',
#   'US20130141961-A1',
#   'US7297977-B2',
#   'US8415731-B2',
#   'US20090280600-A1',
#   'JP05251705-A',
#   'US7105868-B2',
#   'WO2004114391-A1',
#   'JP2003086808-A',
#   'US20030218222-A1',
#   'US20070287296-A1',
#   'US20070002608-A1',
#   'US20110089414-A1',
#   'JP2004273614-A',
#   'US20090114910-A1',
#   'US20060108636-A1',
#   'US20030189401-A1',
#   'US5712817-A',
#   'JP63210024-A',
#   'US20060238135-A1',
#   'US20080258140-A1',
#   'US7732819-B2',
#   'US20060284171-A1',
#   'JP60198861-A',
#   'US20060228974-A1',
#   'US20070272922-A1',
#   'US20060284172-A1',
#   'US20070054507-A1',
#   'US20100065844-A1',
#   'US20070152217-A1',
#   'JP2002289859-A',
#   'US20120262979-A1',
#   'US6294274-B1',
#   'US6563174-B2',
#   'US7411209-B2',
#   'US20090002590-A1',
#   'US20100207253-A1',
#   'JP08264794-A',
#   'US20080006877-A1',
#   'US7061014-B2',
#   'JP2004525473-A',
#   'US20070108446-A1',
#   'US7323356-B2',
#   'US20080128689-A1',
#   'US20110182110-A1',
#   'US20040038446-A1',
#   'US20100193785-A1',
#   'US20080224133-A1',
#   'US20100148171-A1',
#   'US20070172591-A1',
#   'US20080182358-A1',
#   'US20050117394-A1',
#   'US7453065-B2',
#   'US7453087-B2',
#   'US20080106191-A1',
#   'JP2004273732-A',
#   'JP63215519-A',
#   'US20100109002-A1',
#   'US20010046027-A1',
#   'US20070046191-A1',
#   'US20060208977-A1',
#   'US7501293-B2',
#   'US20110216571-A1',
#   'US20080258143-A1',
#   'US20070194379-A1',
#   'US7674650-B2',
#   'US20100097838-A1',
#   'US6727522-B1',
#   'US7211825-B2',
#   'EP1737044-A1',
#   'JP63210022-A',
#   'US20060091793-A1',
#   'US20080038882-A1',
#   'US20090068773-A1',
#   'US20020056838-A1',
#   'US20090152541-A1',
#   'US20130140558-A1',
#   'US7462862-B2',
#   'US20080038929-A1',
#   'US20070090365-A1',
#   'JP2008545221-A',
#   'US7049190-B2',
#   'US20070187678-A1',
#   'US20060231882-A1',
#   'US7282782-B2',
#   'US20060244107-A1',
#   'US20060113539-A1',
#   'US20130308392-A1',
#   'US20080296568-A1',
#   'EP2226847-A2',
#   'US20060110867-A1',
#   'US7767106-B2',
#   'US20090134399-A1',
#   'US20090073325-A1',
#   'JP63210023-A',
#   'JP11505377-W',
#   'US20090278122-A1',
#   'US20060113549-A1',
#   'US20060043377-A1',
#   'US6304477-B1',
#   'JP2002076356-A',
#   'US4466081-A',
#   'US20080166834-A1',
#   'JP2000150900-A',
#   'US7385224-B2',
#   'US20080050595-A1',
#   'US20110101334-A1',
#   'US20070024187-A1',
#   'US7468304-B2',
#   'US7402506-B2',
#   'US20080254569-A1',
#   'US20060292777-A1',
#   'US5744864-A',
#   'US5731856-A',
#   'US20080073653-A1',
#   'US20060170111-A1',
#   'JP2000044236-A',
#   'JP2004103957-A',
#   'US20080129195-A1',
#   'US20060035452-A1',
#   'US20060108529-A1',
#   'JP63239117-A',
#   'US20020132454-A1',
#   'US7064346-B2',
#   'US20070252928-A1',
#   'US6127702-A',
#   'US5349366-A',
#   'US20060113565-A1',
#   'US20050169040-A1',
#   'US20060197092-A1',
#   'US20080258139-A1',
#   'US20100092800-A1',
#   'US20040127038-A1',
#   'US20060113536-A1'],
#  [],
#  ['US20040225025-A1',
#   'US20060107803-A1',
#   'US5028645-A',
#   'WO2006107803-A2',
#   'JP2006249040-A',
#   'WO2007050404-A1',
#   'WO2006107803-A3'],
#  ['KR2011023620-A',
#   'KR1329172-B1',
#   'KR2011131395-A',
#   'KR2012096850-A',
#   'JP2011519314-A',
#   'KR2007050333-A'],
#  ['EP2677554-A1',
#   'US20100147363-A1',
#   'WO1999056317-A1',
#   'WO2013168612-A1',
#   'US20130298965-A1',
#   'US20090250093-A1'],
#  [],
#  ['US7855114-B2',
#   'US20100074029-A1',
#   'JP8153814-A1',
#   'JP2006005006-A',
#   'US20060022252-A1',
#   'US20090021984-A1',
#   'US20080258271-A1',
#   'US8237217-B2',
#   'JP08017945-A',
#   'JP2007123825-A',
#   'US20080076224-A1',
#   'US8318534-B2',
#   'JP2007073969-A1',
#   'US20030107055-A1',
#   'US20110147827-A1',
#   'US8415736-B2',
#   'JP2007073926-A1',
#   'US8283228-B2',
#   'US7479425-B2',
#   'JP2006310662-A',
#   'JP2003068897-A1',
#   'US6693321-B1',
#   'JP2007123945-A',
#   'US20090001446-A1',
#   'US20080296653-A1',
#   'US20030080366-A1',
#   'US7956406-B2',
#   'US6353242-B1',
#   'US20040126972-A1',
#   'US20080311710-A1',
#   'JP2007053171-A1',
#   'US7781824-B2',
#   'US20050157549-A1',
#   'US7977190-B2',
#   'JP2007053392-A1',
#   'US20070051998-A1',
#   'KR648860-B1',
#   'US8030701-B2',
#   'US20130221315-A1',
#   'US20060160303-A1',
#   'JP2005311300-A',
#   'US20130153986-A1',
#   'US7989876-B2',
#   'US20080194066-A1',
#   'US20080093657-A1',
#   'US8232585-B2',
#   'US7902588-B2',
#   'US7037785-B2',
#   'US8426909-B2',
#   'US8466022-B2',
#   'JP2007134681-A',
#   'US20070004154-A1',
#   'US20040051134-A1',
#   'JP2007088422-A1'],
#  ['KR2008105280-A', 'KR2005087248-A', 'KR2008046439-A', 'KR2007049555-A'],
#  ['KR2004076301-A', 'KR2010018131-A', 'KR2007024382-A', 'JP2003173153-A'],
#  [],
#  ['US5591650-A',
#   'JP2005310830-A',
#   'JP2007088254-A',
#   'US20120018739-A1',
#   'US4825335-A',
#   'US6012336-A',
#   'US20090305456-A1',
#   'US7544544-B2',
#   'JP2005260157-A',
#   'JP2008311291-A',
#   'JP11274538-A',
#   'EP933822-A2'],
#  ['JP2001223172-A',
#   'JP2001247396-A',
#   'JP2004319621-A',
#   'JP2004035340-A',
#   'JP2004123433-A'],
#  ['US5487033-A',
#   'US4953928-A',
#   'US4816883-A',
#   'US5539688-A',
#   'EP618621-A1',
#   'EP255489-A',
#   'US4435790-A'],
#  [],
#  [],
#  ['US3833894-A',
#   'US6055180-A',
#   'US20040084670-A1',
#   'US6746971-B1',
#   'JP04145664-A',
#   'WO2004048637-A1',
#   'US6686263-B1',
#   'US5272359-A'],
#  [],
#  [],
#  ['US20100244255-A1',
#   'KR2006114181-A',
#   'US20110183516-A1',
#   'JP2005136152-A',
#   'KR2010122701-A',
#   'US20110249497-A1',
#   'KR2006005182-A',
#   'US20100130001-A1',
#   'US8030779-B2',
#   'KR2011078858-A',
#   'US20100029076-A1',
#   'US5904525-A',
#   'US20110027985-A1'],
#  ['KR2010063607-A', 'KR2013100743-A', 'KR1213228-B1', 'KR2014138817-A'],
#  ['US20090233090-A1',
#   'US20030051751-A1',
#   'US20100043871-A1',
#   'WO2010035935-A1',
#   'US20080248289-A1'],
#  ['US6835621-B2',
#   'US20090032864-A1',
#   'US7723789-B2',
#   'US6018178-A',
#   'US6806517-B2',
#   'US5661592-A',
#   'US7012297-B2',
#   'US20080049517-A1',
#   'US6040605-A',
#   'US7589368-B2',
#   'US7521317-B2',
#   'US20080315290-A1',
#   'US20040183106-A1',
#   'US20080017954-A1',
#   'US20060046403-A1',
#   'US6861307-B2',
#   'US20080182377-A1',
#   'US8114732-B2',
#   'US6268235-B1',
#   'US6538292-B2',
#   'US20070134914-A1',
#   'US20080153222-A1',
#   'US7732281-B1',
#   'CN101484993-A',
#   'US20090115318-A1',
#   'US5658822-A',
#   'US7915123-B1',
#   'US20060001075-A1',
#   'US20060134871-A1',
#   'US20080061359-A1',
#   'US20080213963-A1',
#   'US20040021172-A1',
#   'US6884734-B2',
#   'CN101523580-A',
#   'US7132337-B2',
#   'US7851285-B2',
#   'US7666739-B2',
#   'US20040142528-A1',
#   'US20090096014-A1'],
#  ['US5240874-A', 'US3873371-A', 'US4598460-A', 'US5147811-A'],
#  ['JP2011200780-A',
#   'US20140170345-A1',
#   'JP2013075430-A',
#   'US20060153979-A1',
#   'WO2014024602-A1',
#   'CN101391498-A',
#   'US6048953-A',
#   'US6146225-A',
#   'WO2013047522-A1',
#   'CN101244641-A',
#   'US7666920-B2',
#   'JP2013226767-A',
#   'CN104379464-A',
#   'JP2012134445-A',
#   'US20110232726-A1',
#   'JP2013043384-A',
#   'US20080281015-A1',
#   'US20150214405-A1'],
#  ['US20150280018-A1',
#   'US20020192885-A1',
#   'DE102011110171-B3',
#   'CN103811588-A',
#   'JP2011035252-A',
#   'CN104022188-B',
#   'DE102011110171-A1',
#   'CN103059666-A',
#   'CN102347223-A',
#   'US20150344651-A1',
#   'CN104022188-A',
#   'US20110240997-A1',
#   'US20120205593-A1',
#   'DE102012202367-A1',
#   'US8900915-B2'],
#  ['US5997757-A',
#   'US5464793-A',
#   'US5604367-A',
#   'US5928967-A',
#   'US5792703-A',
#   'JP06236998-A',
#   'US5691561-A',
#   'US5656861-A',
#   'US6057604-A',
#   'US5517045-A'],
#  [],
#  ['JP2005113061-A',
#   'JP98279886-A',
#   'JP2003286440-A',
#   'JP2003003030-A',
#   'JP2001064582-A',
#   'JP2002332354-A',
#   'WO2007069596-A1',
#   'JP2005166389-A',
#   'JP2009253203-A',
#   'JP2000068536-A',
#   'JP2008031297-A'],
#  ['JP2002141110-A',
#   'JP2016035820-A',
#   'JP2016110900-A',
#   'US20080153005-A1',
#   'JP2016157679-A',
#   'JP2012230897-A',
#   'WO2005104289-A1',
#   'JP2016066481-A',
#   'WO2017138453-A1',
#   'WO2017043576-A1',
#   'US20170271715-A1',
#   'WO2018016195-A1'],
#  [],
#  ['US6470392-B1',
#   'US6093265-A',
#   'US20020020920-A1',
#   'US5677244-A',
#   'US6208016-B1',
#   'US6288442-B1',
#   'US20030209775-A1',
#   'US6614099-B2',
#   'US6100176-A',
#   'US20040209456-A1',
#   'US5243222-A',
#   'US5789317-A',
#   'US20020076925-A1',
#   'US6541858-B1',
#   'US6444567-B1',
#   'US6376370-B1',
#   'US20040224507-A1',
#   'US6774035-B2',
#   'US6740392-B1',
#   'US6800554-B2',
#   'US6211049-B1',
#   'US6849927-B2',
#   'US5130274-A',
#   'US3986255-A',
#   'US4240845-A',
#   'US20040219788-A1',
#   'US6649522-B2',
#   'US6316356-B1',
#   'US6037257-A',
#   'US20010010403-A1',
#   'US6784550-B2',
#   'US6433431-B1',
#   'US6121126-A',
#   'US6143655-A',
#   'US6504224-B1',
#   'US6495919-B2',
#   'US6300234-B1',
#   'US5920121-A',
#   'US6818991-B1',
#   'US6541859-B1',
#   'US6063506-A'],
#  ['KR2008003624-A',
#   'US20110094575-A1',
#   'KR2008009346-A',
#   'US20020052127-A1',
#   'US20090084438-A1',
#   'US20090229663-A1',
#   'US20100243029-A1',
#   'US20060249197-A1',
#   'KR2008069089-A',
#   'US20080105302-A1',
#   'US6380480-B1'],
#  ['US20050047196-A1',
#   'CN1459864-A',
#   'CN1180231-A',
#   'US6442060-B1',
#   'US20050157537-A1'],
#  ['US4233085-A',
#   'EP121095-A',
#   'US4167644-A',
#   'FR2170026-A1',
#   'US5022930-A',
#   'US4636577-A',
#   'DE3105352-A',
#   'FR2170026-A'],
#  ['US20120313071-A1',
#   'DE102007049786-A1',
#   'US20050029505-A1',
#   'US20100264396-A1',
#   'WO2012167286-A1',
#   'US20020036931-A1',
#   'US20130214234-A1'],
#  ['US20080276990-A1',
#   'EP1443527-A1',
#   'US20070169805-A1',
#   'WO2006046397-A1',
#   'US20080128286-A1',
#   'EP1653519-A1',
#   'WO2000028603-A1',
#   'US20090165845-A1'],
#  ['JP2003332607-A',
#   'WO2012133778-A1',
#   'US20040089339-A1',
#   'WO2011125101-A1',
#   'JP2007335222-A',
#   'JP2007139540-A',
#   'CN101635316-A',
#   'CN1866573-A',
#   'US20070295381-A1',
#   'WO2006085515-A1',
#   'US20100126567-A1',
#   'EP2212917-A2',
#   'WO2012133777-A1',
#   'US20130081683-A1',
#   'CN101728486-A',
#   'WO2012133776-A1',
#   'US20100012189-A1',
#   'WO2012042831-A1'],
#  ['WO2014116631-A1',
#   'US20110155228-A1',
#   'KR2012078952-A',
#   'US8435472-B2',
#   'WO2007078262-A1',
#   'CN104656189-A'],
#  ['US6027971-A', 'US5950087-A', 'US6114723-A', 'US6046086-A', 'US5811853-A'],
#  [],
#  ['US20120264906-A1', 'WO2012133793-A1', 'WO2013021314-A1'],
#  ['US7096873-B2',
#   'JP2008529265-W',
#   'WO2008050889-A1',
#   'WO2009096539-A1',
#   'JP2008529265-A',
#   'JP2005101240-A',
#   'WO2010001848-A1',
#   'US20110132441-A1',
#   'US20050062041-A1',
#   'US20110000532-A1',
#   'CN1601759-A',
#   'US20080061293-A1',
#   'JP2005101151-A',
#   'JP2005101427-A',
#   'JP2009057173-A',
#   'CN101232058-A'],
#  [],
#  ['US5434815-A',
#   'US4333808-A',
#   'US5006192-A',
#   'US5714766-A',
#   'US20060001080-A1',
#   'US6203613-B1',
#   'US6005790-A',
#   'US6313518-B1',
#   'US6498362-B1',
#   'US5627785-A',
#   'US6110529-A',
#   'US20020003252-A1',
#   'US4888733-A',
#   'US6567303-B1',
#   'US6567312-B1',
#   'US5430670-A',
#   'JP06302828-A',
#   'US3665423-A',
#   'US5424993-A',
#   'US6225168-B1',
#   'US5959896-A',
#   'US6150687-A',
#   'US5912488-A',
#   'US6302964-B1',
#   'US5989958-A',
#   'US5539279-A',
#   'US6514828-B2',
#   'US20020155688-A1',
#   'US6566699-B2',
#   'US5943262-A',
#   'US20020155689-A1',
#   'US6243300-B1',
#   'US6545314-B2',
#   'US6140181-A',
#   'US20030235077-A1',
#   'US5600587-A',
#   'US20030017717-A1',
#   'US6438031-B1',
#   'US6232643-B1',
#   'US20020074565-A1',
#   'US6873539-B1',
#   'US6294813-B1',
#   'US5768192-A',
#   'US6185122-B1',
#   'US20040063276-A1',
#   'US5410504-A',
#   'US6368941-B1',
#   'US6618290-B1',
#   'US3641516-A',
#   'US5572459-A',
#   'US6444039-B1',
#   'US5530581-A',
#   'JP62199019-A',
#   'US6521958-B1',
#   'US6238976-B1',
#   'US6141238-A',
#   'US5449941-A',
#   'US3964085-A',
#   'US6351411-B2',
#   'US6559014-B1',
#   'US6160739-A',
#   'US5550770-A',
#   'US6490204-B2',
#   'US6714455-B2',
#   'US6320786-B1',
#   'US6020024-A',
#   'US6445030-B1',
#   'US6449188-B1',
#   'US5399516-A',
#   'US5541872-A',
#   'US6444895-B1',
#   'US20050023574-A1',
#   'US6303481-B2',
#   'US4507673-A',
#   'US5021999-A',
#   'US6166401-A',
#   'JP08255878-A',
#   'US6570787-B1',
#   'US20020192974-A1',
#   'US3877054-A',
#   'US6504755-B1',
#   'US20020089023-A1',
#   'US6387712-B1',
#   'US20020109158-A1',
#   'US5801105-A',
#   'US6125062-A',
#   'US20050085040-A1',
#   'US6580118-B2',
#   'US5293560-A',
#   'US5541871-A',
#   'US6141237-A',
#   'US6153468-A',
#   'US6465334-B1',
#   'US5388069-A',
#   'US5886368-A',
#   'US6013553-A',
#   'US6059885-A',
#   'US6124729-A',
#   'US6211035-B1',
#   'US6541816-B2',
#   'US5991225-A',
#   'US20050082599-A1',
#   'US20020036939-A1',
#   'US6380579-B1',
#   'US5111430-A',
#   'US20030235081-A1',
#   'US6031263-A',
#   'US5856688-A',
#   'US4661833-A',
#   'US5840897-A',
#   'US5973356-A',
#   'US5027171-A',
#   'US6580124-B1',
#   'US5303182-A',
#   'US5856306-A',
#   'US20030235085-A1',
#   'US6171900-B1',
#   'US6432779-B1',
#   'US5801401-A',
#   'US4939559-A',
#   'US6320784-B1',
#   'US6487121-B1',
#   'JP03222367-A',
#   'US5477485-A',
#   'US6143636-A',
#   'US6552387-B1',
#   'US6249020-B1',
#   'US6049479-A',
#   'US6407435-B1',
#   'US6490205-B1',
#   'US6456536-B1',
#   'US6027961-A',
#   'US20060008966-A1',
#   'US20020027264-A1',
#   'US4413022-A',
#   'US5298447-A',
#   'JP06224431-A',
#   'US6586785-B2',
#   'US6996009-B2',
#   'US5409859-A',
#   'US5485422-A',
#   'US6072209-A',
#   'US5508543-A',
#   'US20060002188-A1',
#   'US5754477-A',
#   'US6353554-B1',
#   'US5595606-A',
#   'US5280205-A',
#   'US4920071-A',
#   'US5457649-A',
#   'US6465306-B1',
#   'US6456531-B1',
#   'US6161500-A',
#   'US5317535-A',
#   'US6246606-B1',
#   'US6194228-B1',
#   'US5467306-A',
#   'US5735960-A',
#   'US6459618-B1',
#   'US4152627-A',
#   'US5602777-A',
#   'US5828605-A',
#   'US5438544-A',
#   'US20060008986-A1',
#   'US5042011-A',
#   'US6458701-B1',
#   'US6141260-A',
#   'US6281144-B1',
#   'US6034882-A',
#   'US5493140-A',
#   'US6212103-B1',
#   'US5852306-A',
#   'US6674138-B1',
#   'US5936274-A',
#   'US5740104-A',
#   'US20050026375-A1',
#   'US6269023-B1',
#   'US6429063-B1',
#   'US6445023-B1',
#   'US5530668-A',
#   'US6495436-B2',
#   'US5253196-A',
#   'US6115281-A',
#   'US4217601-A',
#   'US6521950-B1',
#   'US6122201-A',
#   'US5627781-A',
#   'US6337805-B1',
#   'US6534420-B2',
#   'US6521911-B2',
#   'US6252793-B1'],
#  ['US20060043521-A1',
#   'KR2005010251-A',
#   'US7064072-B1',
#   'US6486517-B2',
#   'US20020142616-A1',
#   'US20040126972-A1',
#   'US20050250298-A1',
#   'US20050136618-A1',
#   'US20030220708-A1',
#   'KR2005052006-A',
#   'JP2001015618-A'],
#  [],
#  ['CN101667602-A',
#   'CN101937944-A',
#   'CN101722155-A',
#   'CN102962226-A',
#   'CN102412172-A',
#   'CN103212551-A',
#   'US20050020463-A1'],
#  [],
#  ['JP2011192802-A', 'KR2012122292-A', 'KR847741-B1', 'KR2012045455-A'],
#  ['WO2011011301-A2',
#   'US5977476-A',
#   'US20100132774-A1',
#   'US20090020154-A1',
#   'CN101499496-A'],
#  [],
#  ['US6358613-B1',
#   'US6331329-B1',
#   'US6524655-B2',
#   'US20030008772-A1',
#   'US20020151556-A1',
#   'US20030167778-A1',
#   'US20020172820-A1',
#   'US6890505-B2',
#   'WO2002048701-A2',
#   'US6676159-B1',
#   'WO2000026019-A1',
#   'US20020096048-A1',
#   'US6481217-B1',
#   'WO1999037409-A1'],
#  ['US6569717-B1',
#   'US6847076-B1',
#   'CN1378262-A',
#   'US5385858-A',
#   'JP10027884-A',
#   'US4864464-A',
#   'US5451537-A'],
#  ['US20100294024-A1', 'US20040265508-A9'],
#  [],
#  ['JP2006173014-A',
#   'JP2009206073-A',
#   'US7709142-B2',
#   'JP2009004146-A',
#   'US8652577-B2',
#   'JP2006085912-A',
#   'JP2006216524-A',
#   'CN1950970-A',
#   'US20090197184-A1',
#   'JP2004214116-A',
#   'CN101510599-A',
#   'JP2002289188-A',
#   'CN101621139-A'],
#  ['US20070145455-A1',
#   'US5408115-A',
#   'US7067737-B2',
#   'US6177318-B1',
#   'US6949788-B2'],
#  ['US20110073169-A1', 'CN202363492-U', 'CN101979247-A', 'CN101615636-A'],
#  ['US20120255610-A1',
#   'US7264991-B1',
#   'EP2003699-A2',
#   'DE102009044038-A1',
#   'EP2003699-A3',
#   'CN101145586-A',
#   'US20120240995-A1',
#   'EP2056355-A1',
#   'JP06045024-A',
#   'US20100233868-A1',
#   'CN102259222-A',
#   'US20090260758-A1',
#   'CN102097531-A',
#   'US20100116314-A1',
#   'DE102010000520-A1',
#   'CN102248243-A',
#   'JP03183527-A',
#   'US20110048492-A1',
#   'CN101369563-A',
#   'JP03188180-A',
#   'US20080076307-A1',
#   'DE102010016814-B3',
#   'CN102074499-A',
#   'US20110120752-A1'],
#  ['KR166840-B1',
#   'JP92346439-A',
#   'US6153467-A',
#   'US5773343-A',
#   'US5990515-A',
#   'US4256514-A',
#   'KR2003019917-A',
#   'JP95142714-A',
#   'US6137132-A',
#   'DE10129958-A1',
#   'WO2002015276-A3',
#   'US6853587-B2',
#   'JP96316347-A',
#   'US6147377-A',
#   'US20020024092-A1',
#   'JP99224908-A',
#   'JP94350095-A',
#   'JP2001024075-A'],
#  ['CN101958364-A',
#   'CN101950780-A',
#   'CN101950770-A',
#   'TW201006893-A',
#   'US20110136960-A1'],
#  ['JP2003218367-A', 'JP11040871-A', 'EP41274-A', 'CN1325142-A', 'US5816238-A'],
#  ['WO2007129555-A1',
#   'KR1998072419-A',
#   'US7989346-B2',
#   'US20050247674-A1',
#   'US5964953-A',
#   'US20010029978-A1',
#   'EP1826829-A2',
#   'EP1753032-A1',
#   'KR98072419-A'],
#  [],
#  [],
#  ['JP2003055841-A',
#   'JP2010024135-A',
#   'JP2010108855-A',
#   'JP2002100418-A',
#   'JP2004146664-A'],
#  ['US20070202036-A1',
#   'US6129903-A',
#   'JP55154321-A',
#   'US5149682-A',
#   'WO2008017047-A2',
#   'WO1992018425-A1',
#   'US6887296-B2',
#   'US7179441-B2',
#   'US20030044347-A1',
#   'US6797648-B2',
#   'US5863867-A',
#   'JP2003192343-A',
#   'CN101115707-A',
#   'WO1991013043-A',
#   'US20080098932-A1',
#   'US6576156-B1',
#   'US5407618-A',
#   'US20020150531-A1',
#   'US6152148-A',
#   'US4019994-A',
#   'US4839339-A',
#   'US5211933-A',
#   'US5883828-A',
#   'JP63307102-A',
#   'US7252791-B2',
#   'US5082811-A',
#   'US5929259-A',
#   'US6078494-A',
#   'US5002926-A',
#   'US20070148065-A1',
#   'US7033406-B2',
#   'US7169370-B2',
#   'US5977041-A',
#   'WO1998039800-A1',
#   'US5196388-A',
#   'US5908802-A',
#   'WO1993016012-A1',
#   'US5087437-A',
#   'JP11147716-A',
#   'US4329241-A',
#   'US4877041-A',
#   'US4804649-A',
#   'JP63270348-A',
#   'US5252314-A',
#   'US20010039251-A1',
#   'US7504172-B2',
#   'JP88307102-A',
#   'US3215572-A',
#   'US20060018815-A1',
#   'US20080031796-A1',
#   'US5135732-A',
#   'US5116560-A',
#   'US4619817-A',
#   'US7001585-B2',
#   'US4618717-A',
#   'US4576921-A'],
#  ['US8262797-B1',
#   'US20120279437-A1',
#   'US5242531-A',
#   'US7635414-B2',
#   'US5087429-A',
#   'US20050279277-A1',
#   'US20130133567-A1',
#   'US20120060748-A1',
#   'US5891245-A',
#   'US6277192-B1',
#   'US5087321-A',
#   'US5474022-A',
#   'US5037503-A',
#   'US20120266808-A1',
#   'US5139750-A'],
#  [],
#  ['US20050282070-A1',
#   'US20070077490-A1',
#   'JP2001250542-A',
#   'US20040247872-A1',
#   'US5939224-A',
#   'US20070148544-A1',
#   'US6235427-B1',
#   'US20070190413-A1',
#   'US7316792-B2',
#   'WO2007015910-A1',
#   'US20060059771-A1',
#   'JP2007080835-A'],
#  [],
#  ['US7372059-B2',
#   'WO2008036496-A1',
#   'US20100075491-A1',
#   'WO2009080615-A2',
#   'WO2011051251-A1',
#   'JP05326460-A',
#   'WO2000030168-A1'],
#  ['US5792689-A',
#   'JP2001168215-A',
#   'JP11265950-A',
#   'JP2001015616-A',
#   'JP09134973-A',
#   'JP11003982-A',
#   'US5578516-A',
#   'JP2003007861-A',
#   'JP2002076308-A',
#   'JP2001284556-A'],
#  [],
#  ['US3986177-A', 'US3768081-A', 'US3918033-A'],
#  [],
#  ['CN1662808-A',
#   'EP930498-A2',
#   'US20050036136-A1',
#   'US20080036998-A1',
#   'US4795260-A',
#   'US20100295938-A1',
#   'US20060007434-A1',
#   'US20050214956-A1',
#   'US20030137664-A1',
#   'US5074669-A',
#   'US20070121106-A1',
#   'US5978074-A',
#   'US4750822-A',
#   'US20030234933-A1',
#   'US20090059215-A1',
#   'US20080231845-A1'],
#  ['US20100178468-A1',
#   'CN103632921-A',
#   'US20180233350-A1',
#   'US10043713-B1',
#   'US6238967-B1',
#   'US9455227-B1',
#   'US20180182856-A1',
#   'US20140299989-A1',
#   'US7300886-B1',
#   'US20170213792-A1',
#   'US7902064-B1',
#   'US20160049362-A1',
#   'US8969197-B2',
#   'US20150155359-A1'],
#  [],
#  ['JP2003223902-A',
#   'WO2009016969-A1',
#   'JP06173085-A',
#   'US4818572-A',
#   'WO2008130078-A1',
#   'US6814848-B2',
#   'US4070208-A',
#   'JP2008277146-A',
#   'JP2009224151-A',
#   'US20030170526-A1',
#   'WO2002013300-A1',
#   'JP2000239806-A',
#   'US6835466-B2',
#   'US5000828-A',
#   'BY7312-C1',
#   'CN1605133-A',
#   'JP2003297379-A',
#   'KR885041-B1',
#   'JP09291400-A',
#   'JP11323502-A'],
#  ['US5213992-A',
#   'US5278091-A',
#   'US5521408-A',
#   'US5134086-A',
#   'US5340763-A',
#   'US5492848-A',
#   'US5407534-A',
#   'US5447878-A',
#   'US5302540-A',
#   'US5350707-A'],
#  [],
#  ['US20010034126-A1',
#   'US5959358-A',
#   'US6699754-B2',
#   'US6815295-B1',
#   'US6165917-A',
#   'US6037257-A',
#   'US6249055-B1'],
#  ['JP05044032-A',
#   'JP08193280-A',
#   'JP04285173-A',
#   'JP08027566-A',
#   'JP09199477-A',
#   'JP94060138-U',
#   'JP05345974-A',
#   'JP95028960-U',
#   'JP07086258-A'],
#  [],
#  ['US4886470-A',
#   'US4846704-A',
#   'US4801273-A',
#   'JP62093964-A',
#   'US4691975-A',
#   'EP425110-A',
#   'JP62111673-A',
#   'EP390543-A',
#   'EP295046-A',
#   'US4799897-A',
#   'US4715823-A'],
#  [],
#  ['US5481133-A',
#   'US6908785-B2',
#   'US6562653-B1',
#   'US6187678-B1',
#   'US20030230805-A1',
#   'US6607938-B2',
#   'US8227904-B2',
#   'US7087538-B2',
#   'US7462511-B2',
#   'US20020063319-A1',
#   'US20070013063-A1',
#   'US6946384-B2',
#   'JP9260420-A1',
#   'WO2008057837-A1',
#   'US7037804-B2',
#   'US7402515-B2',
#   'DE10110203-A1',
#   'US20140264337-A1',
#   'US7402442-B2',
#   'US20120106117-A1',
#   'KR2005033254-A',
#   'US20060240595-A1',
#   'US7307005-B2',
#   'US6001493-A',
#   'US6570248-B1',
#   'US7531890-B2',
#   'US4811082-A',
#   'US20110101527-A1',
#   'US20090278263-A1',
#   'US20090244874-A1',
#   'US20140264769-A1',
#   'US20130134582-A1',
#   'US6279815-B1',
#   'US20130168854-A1',
#   'US8817511-B2',
#   'US20140252561-A1',
#   'US6790748-B2',
#   'US20060267188-A1',
#   'US6908565-B2',
#   'US6661085-B2',
#   'US20100072601-A1',
#   'US7494845-B2',
#   'US6943067-B2',
#   'US7317256-B2',
#   'JP2003309140-A',
#   'US5929521-A',
#   'US7215033-B2',
#   'US20130168848-A1',
#   'DE112007002587-A1',
#   'US6762076-B2',
#   'US6887769-B2',
#   'US7279795-B2',
#   'US6229216-B1',
#   'US7915741-B2',
#   'US7834450-B2',
#   'US6271059-B1',
#   'US20020135055-A1',
#   'US20140048928-A1',
#   'US20110068465-A1',
#   'US20100213608-A1',
#   'US6220499-B1',
#   'DE112007002587-T5',
#   'US6236115-B1',
#   'US20080315409-A1',
#   'US5447264-A',
#   'US7432592-B2',
#   'US20020045293-A1',
#   'US20080057837-A1',
#   'US7528494-B2',
#   'US7402901-B2',
#   'US7151009-B2',
#   'US7276799-B2',
#   'DE102013106965-A1; US2014264769-A1; US9646894-B2; US2017236813-A1; US9911725-B2; US2018197846-A1; US10361181-B2; US2019341379-A1; US10629580-B2; US2020251463-A1; US10879228-B2; DE102013106965-B4',
#   'US20070080442-A1',
#   'DE3705828-A',
#   'US5075253-A',
#   'US6448661-B1',
#   'JP09260420-A',
#   'US5380681-A',
#   'US5773880-A',
#   'US7557597-B2',
#   'DE102013106965-A1; US2014264769-A1; US9646894-B2; US2017236813-A1; US9911725-B2; US2018197846-A1; US10361181-B2; US2019341379-A1; US10629580-B2; US2020251463-A1; US10879228-B2; DE102013106965-B4',
#   'US6461895-B1',
#   'US6894378-B2',
#   'US4990462-A',
#   'US20100244024-A1',
#   'US7576435-B2',
#   'US6975016-B2',
#   'US6924551-B2',
#   'US20110092064-A1',
#   'US6434016-B2',
#   'US7056807-B2',
#   'US6355501-B1',
#   'US6002177-A',
#   'US7320928-B2',
#   'US6600222-B1',
#   'US7345350-B2',
#   'US7157787-B2',
#   'US7410884-B2'],
#  [],
#  ['CN101700872-A', 'WO2011029197-A1', 'CN101074492-A'],
#  ['JP2012019138-A',
#   'US20160126399-A1',
#   'US20160204287-A1',
#   'US135655-A',
#   'CN104854708-A',
#   'US19138-A',
#   'US20140182675-A1',
#   'WO2012029847-A1',
#   'US204287-A',
#   'US20110146765-A1',
#   'US197959-A',
#   'US20110197959-A1',
#   'US20100294356-A1',
#   'US90334-A',
#   'JP2009290234-A',
#   'US20130306129-A1',
#   'US182675-A',
#   'JP2014232817-A',
#   'US20070107773-A1',
#   'US5582653-A',
#   'WO2014185537-A1',
#   'US190563-A',
#   'US240998-A',
#   'US306129-A',
#   'US294724-A',
#   'WO2013077038-A1',
#   'US582653-A',
#   'US20150032806-A1',
#   'JP2008135655-A',
#   'US20130312827-A1',
#   'US20080135655-A1',
#   'US20150090334-A1',
#   'WO2015032806-A1',
#   'JP5695283-B1',
#   'US6294724-B1',
#   'US20120240998-A1',
#   'US20130031282-A1',
#   'US20140190563-A1',
#   'CN103474483-A'],
#  [],
#  ['US20090212373-A1',
#   'US20100118455-A1',
#   'WO2012138697-A1',
#   'US20150041946-A1',
#   'US20050212071-A1',
#   'US20150349144-A1',
#   'EP580213-A1',
#   'EP1071135-A2',
#   'US6215168-B1',
#   'WO2013036723-A1',
#   'US20110227152-A1',
#   'US20130168761-A1',
#   'US20120256192-A1',
#   'US20160005843-A1',
#   'US20060068571-A1',
#   'US20100055882-A1',
#   'US20130020671-A1',
#   'US7768093-B2',
#   'US20160197171-A1',
#   'US20100289032-A1',
#   'US9224806-B2',
#   'US4927772-A'],
#  ['CN103227286-A'],
#  ['US20050082602-A1',
#   'US7622354-B2',
#   'US20060278919-A1',
#   'US7144778-B2',
#   'US7411246-B2',
#   'US20060148227-A1',
#   'US6316298-B1',
#   'US7326614-B2',
#   'US20020191455-A1',
#   'US20050158953-A1',
#   'US7713819-B2',
#   'US20020055228-A1',
#   'US20060284225-A1',
#   'US7074672-B2',
#   'US7605037-B2',
#   'US20020079527-A1',
#   'US20080153226-A1',
#   'US20080203586-A1',
#   'US7368352-B2',
#   'US20030235955-A1',
#   'US7034408-B1',
#   'US20020030214-A1'],
#  ['CN1697890-A',
#   'CN108796389-A',
#   'JP2018035397-A',
#   'CN1244735-A',
#   'KR2017074038-A',
#   'JP09053153-A',
#   'CN105755381-A',
#   'CN109072366-A',
#   'EP413029-A4',
#   'JP62096632-A',
#   'CN105018795-A',
#   'CN101421179-A',
#   'CN105371105-A',
#   'CN108149070-A',
#   'JP5493127-B2',
#   'CN102027283-A',
#   'CN108977715-A',
#   'JP10172554-A',
#   'CN103789573-A',
#   'CN108998736-A',
#   'JP63072851-A',
#   'CN102952969-A',
#   'US5962156-A'],
#  ['US20160284896-A1', 'KR2013037395-A', 'US20190386160-A1'],
#  ['EP1355361-A1',
#   'US20050279992-A1',
#   'US20040026749-A1',
#   'EP1357603-A2',
#   'US6830962-B1',
#   'US5019882-A',
#   'US20040124488-A1',
#   'US7238555-B2',
#   'US6687152-B2'],
#  ['US20130214442-A1',
#   'US4113666-A',
#   'US9228276-B2',
#   'US3529934-A',
#   'US20150184317-A1',
#   'US20150354094-A1',
#   'US4070446-A',
#   'US20090142581-A1',
#   'US20130299748-A1'],
#  [],
#  ['CN110890432-A',
#   'CN111509054-A',
#   'CN109786476-A; CN109786476-B',
#   'CN111628047-A',
#   'CN110034193-A'],
#  ['KR620076-B1', 'WO2011006905-A1', 'JP2000329904-A', 'KR2009098520-A'],
#  ['US4359487-A',
#   'US20070186970-A1',
#   'US6211454-B1',
#   'US20070113881-A1',
#   'US20040063320-A1',
#   'US20080047603-A1',
#   'US4497974-A',
#   'US20090007966-A1',
#   'DE102007012268-A1',
#   'US4528418-A',
#   'US20080202577-A1',
#   'US4561171-A',
#   'US4126150-A',
#   'US20020050289-A1',
#   'US5782995-A',
#   'US5418019-A',
#   'WO2007027498-A1',
#   'US3811954-A',
#   'US20080210303-A1'],
#  ['CN103904082-A', 'CN103456359-A', 'CN101752417-A', 'US20150214238-A1'],
#  ['JP2016225427-A', 'JP2017143125-A', 'JP2016225428-A', 'JP2017005195-A'],
#  ['US4620211-A',
#   'EP405205-A3',
#   'EP279403-A',
#   'US4803532-A',
#   'JP57113219-A',
#   'EP405205-A',
#   'EP310047-A'],
#  [],
#  ['US3585088-A', 'DE2503864-A'],
#  [],
#  ['US20060078772-A1',
#   'US20090092865-A1',
#   'US20050130007-A1',
#   'US20020172853-A1',
#   'US20090117445-A1',
#   'DE102008003836-A1',
#   'JP2007184157-A',
#   'US6118658-A',
#   'US20080138692-A1',
#   'US20030096146-A1',
#   'US8068340-B1',
#   'JP2008198374-A',
#   'US20060046111-A1',
#   'JP59134570-A',
#   'US20090098428-A1',
#   'US20070059572-A1'],
#  ['US6402974-B1',
#   'US6465727-B2',
#   'US5538902-A',
#   'US4270018-A',
#   'US4528082-A',
#   'US3961997-A',
#   'US6060400-A',
#   'US5401331-A',
#   'US5693957-A',
#   'US5639314-A',
#   'US4755475-A',
#   'US5705828-A',
#   'US5114498-A',
#   'US20090120493-A1',
#   'US6252785-B1',
#   'US6410843-B1',
#   'US5066340-A',
#   'US20100116335-A1',
#   'US6384316-B1',
#   'US4668840-A',
#   'US20030203547-A1',
#   'US6849917-B2',
#   'US7781669-B2',
#   'US5401336-A',
#   'US7030413-B2',
#   'CN1532952-A',
#   'US4084024-A',
#   'US4818337-A',
#   'US3969163-A',
#   'US6878921-B2',
#   'US7164150-B2',
#   'US6667434-B2',
#   'US6380479-B2',
#   'US6100166-A',
#   'US5455430-A',
#   'US5155051-A',
#   'US5907766-A',
#   'US6124545-A',
#   'US20050109388-A1',
#   'EP1460693-A2',
#   'US6521883-B2',
#   'US4124410-A',
#   'US20020175143-A1',
#   'US4981525-A',
#   'US5785769-A',
#   'US4689438-A',
#   'US5951785-A',
#   'US6749685-B2',
#   'US6175512-B1',
#   'US5614785-A',
#   'US5584941-A',
#   'US5549763-A',
#   'US20040118337-A1',
#   'US4722880-A',
#   'US4077818-A',
#   'US6207890-B1',
#   'US5935344-A',
#   'US5213628-A',
#   'US20060283499-A1',
#   'US7951640-B2',
#   'US20080121280-A1',
#   'US6342669-B1',
#   'US7863518-B2',
#   'US20070166219-A1',
#   'US5370747-A',
#   'US4450316-A'],
#  [],
#  ['US8377592-B2',
#   'CN1513922-A',
#   'JP2006244813-A',
#   'JP2007234255-A',
#   'US20140287315-A1',
#   'US20080176137-A1',
#   'JP2001185127-A',
#   'JP2008177346-A',
#   'US20100243951-A1',
#   'US20060099507-A1',
#   'JP2006114454-A',
#   'US20070218365-A1',
#   'CN104603993-A',
#   'WO2013054481-A1',
#   'JP2010003642-A',
#   'US20030215711-A1',
#   'JP2009205950-A',
#   'JP2009212074-A',
#   'CN101038962-A',
#   'JP2009070825-A',
#   'US20150221950-A1',
#   'JP2004349057-A',
#   'US20090202911-A1',
#   'JP2008282819-A',
#   'JP2002042806-A',
#   'JP2006164954-A',
#   'JP2997741-B2',
#   'US5395711-A',
#   'JP2008251369-A',
#   'CN104058404-A',
#   'JP2007280926-A',
#   'US7459236-B2'],
#  ['US5708263-A',
#   'US5323049-A',
#   'US5319604-A',
#   'US4833519-A',
#   'US5461425-A',
#   'US4818723-A',
#   'US5757045-A',
#   'US5625210-A',
#   'US5471515-A',
#   'US5576763-A',
#   'US5541402-A',
#   'US5614744-A',
#   'US5705846-A',
#   'US5612799-A',
#   'US4374700-A'],
#  [],
#  ['US6836172-B2',
#   'JP2006173529-A',
#   'US20130134553-A1',
#   'CN1685607-A',
#   'US8134224-B2',
#   'US20140061866-A1',
#   'JP2010067664-A',
#   'JP2003298305-A',
#   'CN1455458-A',
#   'US20120280374-A1',
#   'JP2003347553-A',
#   'JP2005184224-A',
#   'JP2008227084-A',
#   'US20110095806-A1',
#   'US20040233648-A1',
#   'US6853072-B2',
#   'JP2012065186-A'],
#  ['RU2003132193-A', 'RU2258274-C1', 'US20010020726-A1', 'RU2300158-C1'],
#  ['US1936078-A',
#   'US5316998-A',
#   'US4639259-A',
#   'US6221132-B1',
#   'US20030024390-A1',
#   'US6709487-B1',
#   'GB1090521-A',
#   'US20020112608-A1',
#   'US6110258-A',
#   'DE2617689-A',
#   'US5958356-A',
#   'US20060086247-A1',
#   'GB1186941-A',
#   'US6395070-B1',
#   'US5284638-A',
#   'US3029575-A',
#   'US7175696-B2',
#   'WO2006014655-A1',
#   'DE2413043-A',
#   'US4009214-A',
#   'US4053558-A',
#   'US4663052-A',
#   'US4128626-A',
#   'US20040123736-A1',
#   'DE730177-C'],
#  [],
#  ['JP02202018-A', 'JP05275354-A', 'JP2007165717-A'],
#  ['US4873317-A',
#   'US20040159633-A1',
#   'US20040163758-A1',
#   'US3634159-A',
#   'US20100119429-A1',
#   'US7041232-B2',
#   'US6180239-B1',
#   'US6866791-B1',
#   'US6780492-B2',
#   'US5512131-A',
#   'US6413587-B1',
#   'US20080152835-A1',
#   'US5900160-A'],
#  ['US20070169808-A1'],
#  ['US3028324-A',
#   'US5158655-A',
#   'US4680094-A',
#   'US4774052-A',
#   'US4374761-A',
#   'US4610857-A',
#   'WO9725294-A1; AU9715741-A; US5753382-A; EP873285-A1; AU722168-B; US6194096-B1',
#   'US4824531-A',
#   'US5527442-A',
#   'US4560448-A',
#   'US4650552-A',
#   'US5397450-A',
#   'US5149595-A',
#   'US4769074-A',
#   'US4460440-A',
#   'US4333813-A',
#   'US5217583-A',
#   'US4439491-A',
#   'FR1107113-A',
#   'US4145242-A',
#   'US5213730-A',
#   'US5316718-A',
#   'US5534119-A',
#   'US4567103-A',
#   'US3330756-A',
#   'US5409589-A',
#   'US3881039-A',
#   'US5534130-A',
#   'US3348929-A',
#   'US4279709-A',
#   'US4535035-A',
#   'US3856650-A',
#   'US5472578-A',
#   'US5486278-A',
#   'US4808372-A',
#   'WO1994028200-A1',
#   'US4532017-A',
#   'US5362366-A',
#   'US5250324-A',
#   'US5112654-A',
#   'US5376421-A',
#   'US5486287-A',
#   'US4308114-A',
#   'US5194330-A',
#   'US4929328-A',
#   'US4533452-A',
#   'US4613375-A',
#   'US4678760-A',
#   'US5320717-A',
#   'US5364442-A',
#   'US4836982-A',
#   'US4605440-A',
#   'US5413689-A',
#   'US5110688-A',
#   'US5364513-A',
#   'US4751048-A',
#   'US4770825-A',
#   'US6001236-A',
#   'US5374342-A',
#   'WO1993025731-A1',
#   'US5985114-A',
#   'US5378327-A',
#   'US5188678-A',
#   'US5514495-A',
#   'US4342637-A',
#   'US4772452-A',
#   'US4582553-A',
#   'US4655830-A',
#   'US4559270-A',
#   'US4595545-A',
#   'US4610726-A',
#   'US3969124-A',
#   'US4710348-A',
#   'US5019225-A',
#   'US4540475-A',
#   'US5340014-A',
#   'US4961778-A',
#   'US3705791-A',
#   'US3939028-A',
#   'US4466996-A',
#   'US4738389-A',
#   'US4439382-A',
#   'US5077246-A',
#   'US5342491-A',
#   'US5340448-A',
#   'US4268582-A',
#   'US4909842-A',
#   'US4948676-A',
#   'US3442787-A',
#   'US4915903-A',
#   'US5071533-A',
#   'US4988645-A',
#   'US3852107-A',
#   'US4308115-A',
#   'US4600481-A',
#   'US4670201-A',
#   'US4985202-A'],
#  ['US20040014304-A1',
#   'US6574143-B2',
#   'US20030042534-A1',
#   'US3964085-A',
#   'US6653174-B1',
#   'US6653175-B1',
#   'US5621683-A',
#   'US6243296-B1',
#   'US20030151948-A1',
#   'US5043946-A',
#   'US5488243-A',
#   'US5557569-A',
#   'US20030089942-A1',
#   'US6638627-B2',
#   'US3918033-A',
#   'US5801993-A',
#   'US20040007734-A1',
#   'US5396454-A',
#   'US6600188-B1',
#   'US6201734-B1',
#   'JP61166078-A',
#   'US5814853-A',
#   'US6104045-A',
#   'US6294427-B1',
#   'US6462359-B1',
#   'US4488262-A',
#   'US20020105023-A1',
#   'US20040041206-A1',
#   'US6545297-B1',
#   'US20030160277-A1',
#   'US3978577-A',
#   'US20030072126-A1',
#   'US4870470-A',
#   'US4829482-A',
#   'US5981335-A',
#   'US6248626-B1',
#   'US4791604-A',
#   'US20020048190-A1',
#   'US5627779-A',
#   'US5963476-A'],
#  ['JP2007080569-A',
#   'CN1395323-A',
#   'US20060060939-A1',
#   'WO2004032575-A1',
#   'US20030155573-A1',
#   'WO2010005301-A1',
#   'JP2005266616-A',
#   'US20030027369-A1',
#   'JP2004014447-A',
#   'CN101030628-A',
#   'CN101309531-A'],
#  ['US6744073-B1',
#   'US20050178431-A1',
#   'US20110168246-A1',
#   'US20100275965-A1',
#   'CN1625812-A',
#   'US4409422-A',
#   'JP2006073985-A',
#   'US4131984-A',
#   'US20090056698-A1',
#   'CN102171840-A',
#   'CN101924150-A',
#   'US20090194162-A1',
#   'CN101527327-B',
#   'US20110005575-A1',
#   'US20090250113-A1',
#   'US20060043390-A1',
#   'US20110186114-A1',
#   'US20080185033-A1',
#   'JP2004281758-A',
#   'US7829781-B2',
#   'JP2011086647-A',
#   'US5071490-A',
#   'US20080083448-A1',
#   'CN102232246-B',
#   'US20120152322-A1',
#   'US20090211633-A1',
#   'US20120266953-A1',
#   'US20100018579-A1',
#   'US20080303131-A1',
#   'US8450717-B1',
#   'TW416877-U',
#   'JP2001313401-A',
#   'WO2011099318-A1',
#   'US20080308156-A1',
#   'US20090268446-A1',
#   'JP62105485-A',
#   'US6350945-B1',
#   'FR2666453-A',
#   'US3454843-A',
#   'US20120152340-A1',
#   'WO2003094248-A1',
#   'US20110132427-A1',
#   'US20090223558-A1',
#   'JP01111887-A',
#   'US3422527-A',
#   'TW201113389-A',
#   'US20030005954-A1',
#   'JP02009176-A',
#   'CN201801461-U'],
#  ['US6156606-A'],
#  ['US5837584-A', 'US5474947-A', 'US5306658-A', 'US5273923-A'],
#  ['US20060019443-A1', 'US6096595-A', 'US20130087799-A1', 'US5362666-A'],
#  ['JP05053511-A',
#   'JP50137488-A',
#   'US4643817-A',
#   'JP50124586-A',
#   'US3025335-A',
#   'JP53043885-U',
#   'JP05036997-A',
#   'JP52044587-A',
#   'US5498576-A',
#   'JP91008455-U',
#   'JP61220482-A',
#   'JP06302853-A',
#   'JP60041063-U',
#   'US4100051-A',
#   'JP08125210-A',
#   'JP78043885-U',
#   'JP61121179-A',
#   'US5469020-A',
#   'US3921026-A',
#   'US4021323-A',
#   'US3350775-A',
#   'JP53043885-A',
#   'JP05217229-A',
#   'JP60041063-A',
#   'US3411952-A',
#   'JP85041063-U',
#   'EP396266-A',
#   'US5037105-A',
#   'JP52017229-A',
#   'US2904613-A',
#   'JP62048928-A',
#   'US4037241-A',
#   'JP03029685-A',
#   'US4136436-A',
#   'US4173494-A',
#   'JP08064860-A',
#   'JP49046398-A',
#   'JP09162434-A',
#   'US3998659-A',
#   'JP53121493-A',
#   'US4358782-A'],
#  ['US20090263749-A1',
#   'US20100155959-A1',
#   'JP2009260309-A',
#   'US20070158688-A1',
#   'US20110237081-A1',
#   'US20110256723-A1',
#   'US20100038795-A1',
#   'JP2010511306-A',
#   'US20090154240-A1'],
#  ['US6292424-B1',
#   'EP727820-A1',
#   'EP788165-A2',
#   'US5877978-A',
#   'US6897098-B2',
#   'EP1191596-A2',
#   'US6297090-B1',
#   'US6567330-B2',
#   'US20030168677-A1',
#   'JP2002246571-A',
#   'US4791610-A',
#   'JP62272561-A',
#   'EP689252-A1',
#   'EP1209747-A2',
#   'EP726601-A1',
#   'EP844671-A1',
#   'US6888200-B2',
#   'US6300649-B1',
#   'US6384445-B1',
#   'US20050145935-A1',
#   'EP300157-A',
#   'EP731972-A1',
#   'EP599388-A1',
#   'US6350653-B1',
#   'EP869511-A2',
#   'US6650565-B1',
#   'EP253631-A',
#   'EP564204-A2',
#   'US6566177-B1',
#   'EP359551-A',
#   'EP725402-A2',
#   'JP2003243528-A',
#   'US4262340-A',
#   'US6556477-B2',
#   'US5466625-A',
#   'EP1162663-A2',
#   'US4298962-A',
#   'US4250569-A',
#   'US6177708-B1',
#   'US5448513-A',
#   'US5489792-A',
#   'US4979014-A',
#   'US6351426-B1',
#   'US6661042-B2',
#   'JP10065031-A; IE79078-B; KR98008685-A; US5886376-A; US5960265-A; KR324973-B1',
#   'US20040041206-A1',
#   'US6617651-B2',
#   'US20050111255-A1',
#   'JP2000274221-A',
#   'US20020160581-A1',
#   'US20020076880-A1',
#   'EP245515-A',
#   'US6590259-B2',
#   'EP350057-A',
#   'US5897351-A',
#   'WO2002103703-A2',
#   'US5929479-A',
#   'US5811283-A',
#   'US5740099-A',
#   'US6320227-B1',
#   'US3997799-A',
#   'US20010055859-A1',
#   'EP1280205-A2',
#   'US5696718-A',
#   'US20050141290-A1',
#   'EP207619-A',
#   'US20020030214-A1',
#   'US5930648-A',
#   'US6424016-B1',
#   'EP362961-A',
#   'EP1271547-A1',
#   'EP465961-A',
#   'US20030102497-A1',
#   'EP924766-A2',
#   'US20030213994-A1',
#   'US20050189576-A1',
#   'US20030057490-A1',
#   'EP1237193-A2',
#   'US6909151-B2',
#   'EP366882-A',
#   'EP1180799-A2',
#   'EP1253634-A2',
#   'EP1288955-A2',
#   'US6466511-B2',
#   'US5943258-A',
#   'JP2002353080-A',
#   'EP682370-A1',
#   'JP03171768-A',
#   'JP2002009081-A',
#   'US20030112659-A1',
#   'US6081443-A',
#   'US20020114191-A1',
#   'EP202515-A',
#   'US6097056-A',
#   'US6778424-B2',
#   'US6518105-B1',
#   'US5939745-A',
#   'EP579566-A2',
#   'US6590258-B2',
#   'US20030003608-A1',
#   'EP175378-A',
#   'JP2003203967-A',
#   'US20040240306-A1',
#   'US6441436-B1',
#   'US5977578-A',
#   'US20030123279-A1',
#   'US20020034855-A1',
#   'EP1073121-A2',
#   'JP2003100900-A',
#   'JP2002094027-A',
#   'US20030057487-A1',
#   'US6714436-B1',
#   'US4371955-A',
#   'US5528062-A',
#   'JP2003132682-A',
#   'US20020072155-A1',
#   'US20020070411-A1',
#   'JP02294076-A',
#   'US20040021137-A1',
#   'US4630089-A',
#   'US20020051378-A1',
#   'EP744772-A1',
#   'EP933820-A1',
#   'US20030015757-A1',
#   'US6225158-B1',
#   'EP1179850-A2',
#   'EP836194-A2',
#   'EP980101-A2',
#   'US6214694-B1',
#   'JP2003086712-A',
#   'US20030151112-A1',
#   'EP1204147-A1',
#   'US20030146488-A1',
#   'US6424011-B1',
#   'US20040042268-A1',
#   'EP694977-A2',
#   'US5631186-A',
#   'US6407427-B1',
#   'US6171923-B1',
#   'EP1233454-A2',
#   'JP09082912-A',
#   'US6359802-B1',
#   'EP739097-A2',
#   'EP1204146-A1',
#   'JP11087649-A',
#   'US5778243-A',
#   'US20050135169-A1',
#   'US4032947-A',
#   'EP858109-A2',
#   'US6252281-B1',
#   'US20050062088-A1',
#   'JP2003031693-A',
#   'US5968840-A',
#   'US20050141262-A1',
#   'EP606758-A1',
#   'US20020086463-A1',
#   'EP860878-A2',
#   'GB1414228-A',
#   'US6913964-B2',
#   'US6627952-B1',
#   'US6538916-B2',
#   'US6544837-B1',
#   'US5780906-A',
#   'US6492211-B1',
#   'FR2197494-A',
#   'US20050167751-A1',
#   'US6632723-B2',
#   'US20020110018-A1',
#   'US6403435-B1',
#   'EP513923-A2',
#   'US6333532-B1',
#   'US5593912-A',
#   'US6552398-B2',
#   'US5388068-A',
#   'US5627092-A',
#   'JP2002176154-A',
#   'EP599506-A1',
#   'EP993037-A2',
#   'US5784311-A',
#   'EP801427-A2',
#   'US5568356-A',
#   'US20040108532-A1',
#   'US20050064659-A1',
#   'EP642173-A1',
#   'US20050145886-A1',
#   'EP727822-A2',
#   'US5943581-A',
#   'EP920059-A2',
#   'EP1162744-A1',
#   'JP10242470-A',
#   'JP2003100641-A',
#   'US5144390-A',
#   'US20020130341-A1',
#   'US20050001269-A1',
#   'EP951072-A1',
#   'US6721222-B2',
#   'US20020180069-A1',
#   'US6018172-A',
#   'JP09046688-A',
#   'US4527181-A',
#   'US20040238890-A1',
#   'US5446299-A',
#   'US20040041208-A1',
#   'JP2001180633-A',
#   'US6096598-A',
#   'US6121077-A',
#   'EP30856-A',
#   'US6621725-B2',
#   'US6391658-B1',
#   'EP878804-A2',
#   'US6441435-B1',
#   'JP10065031-A; IE79078-B; KR98008685-A; US5886376-A; US5960265-A; KR324973-B1',
#   'EP537677-A2',
#   'EP510607-A1',
#   'US6903984-B1',
#   'JP2002329795-A',
#   'US5886385-A',
#   'US5936265-A',
#   'US6177300-B1',
#   'US3439214-A',
#   'US20020064913-A1',
#   'EP354348-A',
#   'US20020098643-A1',
#   'US6157216-A',
#   'US6440872-B1',
#   'EP971360-A1',
#   'US20040052142-A1',
#   'JP08274277-A',
#   'US20020089038-A1',
#   'EP1241708-A2',
#   'US6245613-B1',
#   'US5578865-A',
#   'JP08213624-A',
#   'JP2002343886-A',
#   'US6111778-A',
#   'US20020036322-A1',
#   'US5258635-A',
#   'US20050105342-A1',
#   'US5606188-A',
#   'US6549450-B1',
#   'US20030035324-A1',
#   'US6548848-B2',
#   'EP601590-A2',
#   'US6781875-B2',
#   'US6771546-B2',
#   'JP2000247735-A',
#   'US6531754-B1',
#   'JP2000389106-A',
#   'US6756637-B2',
#   'US6421269-B1',
#   'EP333426-A',
#   'US5982003-A',
#   'US6429477-B1'],
#  ['US20030170524-A1', 'US20040072047-A1', 'US6713206-B2', 'US20040058217-A1'],
#  ['JP03001577-A',
#   'US4162505-A',
#   'EP978883-A1',
#   'WO1999038216-A1',
#   'WO1999039390-A1',
#   'JP08051225-A',
#   'US4732621-A',
#   'JP06122982-A',
#   'US5667631-A',
#   'JP55121685-A',
#   'JP09061806-A'],
#  [],
#  [],
#  ['US7061050-B2',
#   'US20040160825-A1',
#   'US20050282318-A1',
#   'US20070029618-A1',
#   'US6054734-A',
#   'US6913964-B2',
#   'US20070012988-A1'],
#  ['US3976330-A',
#   'US5571339-A',
#   'US5911837-A',
#   'US4705760-A',
#   'US5683816-A',
#   'US5727578-A',
#   'US6173720-B1',
#   'US5451542-A'],
#  [],
#  ['WO2016022026-A1',
#   'WO2011142666-A1',
#   'US20130186460-A1',
#   'WO2013151430-A1',
#   'US20140224313-A1'],
#  ['US4064521-A', 'US4085257-A', 'US4084043-A', 'US4142195-A', 'US4152490-A'],
#  ['US9893222-B2',
#   'DE102012216740-B4',
#   'US7754962-B2',
#   'CN110071178-A',
#   'DE102019111061-A1',
#   'CN110137271-A'],
#  [],
#  ['JP2014096352-A',
#   'WO2013175993-A1',
#   'JP2011086610-A',
#   'JP2009181873-A',
#   'WO2008111324-A1',
#   'WO2013137224-A1',
#   'JP2001023653-A',
#   'WO2011065388-A1'],
#  [],
#  ['US20110198695-A1', 'US20110049613-A1', 'US20040217434-A1'],
#  ['US20040203256-A1',
#   'KR2013000786-A',
#   'US20130022752-A1',
#   'KR1236138-B1',
#   'US20130299217-A1',
#   'US20130329366-A1',
#   'KR2013006868-A',
#   'US20100065818-A1',
#   'US20070278448-A1',
#   'KR2011073296-A',
#   'US20140377670-A1',
#   'US20090052029-A1',
#   'KR2012125906-A'],
#  [],
#  ['US3916041-A',
#   'DE2406339-A; NL7401987-A; BE810945-A; FR2217804-A; US3949463-A; GB1452635-A; CA1019053-A',
#   'DE1956964-A',
#   'US4142195-A',
#   'DE736411-C',
#   'FR2025098-A',
#   'FR1496520-A',
#   'DE2408235-A',
#   'FR896925-A',
#   'FR91559-E'],
#  [],
#  ['JP2006351995-A', 'WO2007058604-A1', 'JP4256374-A', 'JP2004172271-A'],
#  ['US6962959-B2',
#   'US6387230-B1',
#   'US4148812-A',
#   'US6607856-B2',
#   'US7387732-B2',
#   'WO2005114772-A2; EP1747600-A2; US2007128490-A1; JP2007537578-W; US7811693-B2; US2011009504-A1; WO2005114772-A3; US8465857-B2; EP1747600-A4',
#   'US7358288-B2',
#   'WO2001084657-A2',
# ...
#   'US4610734-A',
#   'EP28213-A',
#   'US20060105218-A1',
#   'JP2000328205-A',
#   'JP2000303151-A',
#   'US5800152-A',
#   'JP2003187828-A',
#   'US20080107947-A1',
#   'WO2008013498-A1',
#   'US7211346-B2',
#   'US4049431-A',
#   'US6936217-B2'],
#  ['US4466380-A',
#   'US20020073922-A1',
#   'US6390020-B1',
#   'US6143078-A',
#   'US4460673-A'],
#  ['US6476432-B1',
#   'US6236078-B1',
#   'US5428238-A',
#   'US5583359-A',
#   'US6800892-B2'],
#  ['US8705280-B2',
#   'US7550137-B2',
#   'US5604367-A',
#   'US8493794-B2',
#   'US9704569-B1',
#   'US9659655-B1',
#   'US7508025-B2',
#   'US7700993-B2',
#   'US8477539-B2'],
#  ['US20110146747-A1',
#   'US20110247688-A1',
#   'WO2013004928-A2',
#   'US20130056044-A1',
#   'US20140090689-A1',
#   'US20120288990-A1',
#   'US20100200045-A1',
#   'US20110186117-A1',
#   'US20120247554-A1',
#   'WO1995006320-A1'],
#  ['JP2005136400-A',
#   'US6899612-B2',
#   'WO2005007799-A3',
#   'KR2001105961-A',
#   'US5578362-A',
#   'US7074115-B2',
#   'KR2005034554-A',
#   'US20030139122-A1',
#   'CN1559082-A',
#   'US20050276967-A1',
#   'US6860802-B1',
#   'JP2006518943-A',
#   'JP2001518852-A',
#   'KR2005107760-A',
#   'US7169030-B1',
#   'US20050079806-A1',
#   'KR2001005961-A',
#   'US20060276109-A1'],
#  [],
#  [],
#  ['US4577395-A',
#   'US5413898-A',
#   'US5963814-A',
#   'US5523258-A',
#   'DE4235702-A1',
#   'US5354711-A'],
#  ['US6037014-A',
#   'US4649062-A',
#   'WO2011158805-A1',
#   'JP95232939-A',
#   'US6617371-B2',
#   'US20060160918-A1',
#   'JP95146401-A',
#   'US5178685-A',
#   'JP96283560-A',
#   'US5643657-A',
#   'WO2007091082-A1',
#   'US20060275588-A1',
#   'JP58174477-A',
#   'US6140386-A',
#   'US20070281136-A1',
#   'WO2008071994-A9',
#   'WO2008053235-A1',
#   'WO2008117092-A1',
#   'US20100113685-A1',
#   'US20090035535-A1',
#   'WO2010140594-A1',
#   'WO2005047405-A1',
#   'WO2008071994-A1',
#   'US4677179-A',
#   'US5476894-A',
#   'US20100004376-A1',
#   'US3994764-A'],
#  ['US20020028528-A1',
#   'US6911667-B2',
#   'US6841411-B1',
#   'US5869843-A',
#   'US6703249-B2'],
#  [],
#  ['WO2008045813-A2',
#   'CN103337540-A',
#   'US6335534-B1',
#   'US20130213469-A1',
#   'US20090309039-A1',
#   'KR2013070466-A',
#   'CN203038931-U',
#   'US2695852-A',
#   'CN102760791-A',
#   'US7459246-B2',
#   'US6614033-B2',
#   'US20090263928-A1',
#   'US4448865-A',
#   'US8563352-B2',
#   'KR2012080500-A',
#   'EP548863-B1',
#   'US20090227061-A1',
#   'US6087274-A',
#   'US20130071580-A1',
#   'KR2011038901-A',
#   'US2010124799-A1; WO2010065204-A2; WO2010065204-A3; US7816239-B2; TW201031010-A; EP2351101-A2; KR2011101166-A; CN102203955-A; JP2012516551-W; CN102203955-B; JP5572167-B2; EP2351101-A4',
#   'US20090139868-A1',
#   'US3790412-A',
#   'CN103339741-A',
#   'CN103201849-A',
#   'CN101657904-A',
#   'US20130171767-A1',
#   'US20140154834-A1',
#   'CN102569477-A',
#   'US20080072953-A1',
#   'US20120122302-A1',
#   'US20130065404-A1',
#   'CN1158011-A',
#   'CN201859877-U',
#   'US4381956-A',
#   'US6417078-B1',
#   'US8222053-B2',
#   'US20100184250-A1',
#   'US20110059571-A1',
#   'US20100055822-A1',
#   'US7208381-B2',
#   'US4086102-A',
#   'US3736425-A',
#   'US8440571-B2',
#   'US7179569-B2',
#   'US7838062-B2',
#   'US5871591-A',
#   'CN102760777-A',
#   'US7888249-B2',
#   'US5972794-A',
#   'US7531216-B2',
#   'CN102403401-A',
#   'WO2010138976-A1',
#   'US20130313633-A1',
#   'US6253441-B1',
#   'US8420435-B2',
#   'US4994405-A',
#   'US20110139230-A1',
#   'US4557037-A',
#   'US5385849-A',
#   'US20100229928-A1',
#   'WO2013003282-A2',
#   'CN102931269-A',
#   'US5907766-A',
#   'US7745073-B2',
#   'US7820460-B2',
#   'US4448797-A',
#   'US7727866-B2',
#   'CN1198841-A',
#   'JP2002185002-A',
#   'US8470616-B2',
#   'US20040112426-A1',
#   'US20090068783-A1',
#   'US20110000540-A1',
#   'EP773589-A2',
#   'KR2011020062-A',
#   'US7094612-B2',
#   'US20110104618-A1',
#   'US7638438-B2',
#   'CN103026505-A'],
#  ['KR2017059170-A', 'JP2018182312-A', 'US20130092872-A1', 'US4092211-A'],
#  [],
#  ['US5874768-A', 'US20100203703-A1', 'US20100019311-A1'],
#  [],
#  ['US20090159976-A1', 'US20080206988-A1', 'US20080211000-A1', 'US7396767-B2'],
#  [],
#  ['JP11017202-A',
#   'WO2010113792-A1',
#   'JP2006278409-A',
#   'JP2000323736-A',
#   'EP1826829-A2',
#   'JP2002057139-A',
#   'US11220146-B',
#   'JP11220146-A',
#   'WO1998043304-A1',
#   'US6391145-B1'],
#  ['CN103633239-A',
#   'US20120280339-A1',
#   'WO2016011435-A1',
#   'US20140121649-A1',
#   'CN104051611-A',
#   'US20150200003-A1',
#   'CN102800803-A',
#   'US20160043305-A1',
#   'US20120300542-A1',
#   'US9773972-B1',
#   'CN104704564-A'],
#  ['EP203560-A', 'US4572759-A', 'DE3318566-A', 'US3984301-A'],
#  ['US20040173256-A1',
#   'GB2188924-A',
#   'JP2003221256-A',
#   'US20080115828-A1',
#   'EP991129-A1'],
#  ['US20090223549-A1',
#   'US20100186822-A1',
#   'US20100229926-A1',
#   'US20120318347-A1',
#   'US20120216857-A1'],
#  [],
#  ['CN102792498-A',
#   'US20110311873-A1',
#   'US20160164081-A1',
#   'CN103996835-A',
#   'US20120082893-A1',
#   'US20150228980-A1',
#   'CN103474666-A',
#   'CN1848487-A'],
#  ['US5434815-A',
#   'US6011725-A',
#   'US5714766-A',
#   'US20060001080-A1',
#   'US6313518-B1',
#   'US7494873-B2',
#   'US7369435-B2',
#   'US5016215-A',
#   'US20020003252-A1',
#   'US5430670-A',
#   'US6567303-B1',
#   'US5424993-A',
#   'US5959896-A',
#   'US6150687-A',
#   'US5912488-A',
#   'US6566699-B2',
#   'US5943262-A',
#   'US6545314-B2',
#   'US6232643-B1',
#   'US20020074565-A1',
#   'US6873539-B1',
#   'US6294813-B1',
#   'US20040063276-A1',
#   'US6365470-B1',
#   'US6618290-B1',
#   'US5530581-A',
#   'US5449941-A',
#   'US6351411-B2',
#   'US7193893-B2',
#   'US6714455-B2',
#   'US6320786-B1',
#   'US6445030-B1',
#   'US20090002025-A1',
#   'US20050023574-A1',
#   'US4507673-A',
#   'US5021999-A',
#   'US6570787-B1',
#   'US5677867-A',
#   'US20050085040-A1',
#   'US6580118-B2',
#   'US5293560-A',
#   'US6630009-B2',
#   'US5388069-A',
#   'US20070015331-A1',
#   'US4173791-A',
#   'US5508544-A',
#   'US6541816-B2',
#   'US20050082599-A1',
#   'US6525969-B1',
#   'US5111430-A',
#   'US6031263-A',
#   'US4661833-A',
#   'US5027171-A',
#   'US5303182-A',
#   'US7045430-B2',
#   'US7489545-B2',
#   'US4939559-A',
#   'US5107977-A',
#   'US20030032270-A1',
#   'US6320784-B1',
#   'US6552387-B1',
#   'US20070178643-A1',
#   'US6049479-A',
#   'US7221017-B2',
#   'US20060008966-A1',
#   'US20050036370-A1',
#   'US493140-A',
#   'US5298447-A',
#   'US5670790-A',
#   'US5409859-A',
#   'US20060258097-A1',
#   'US5485422-A',
#   'US6072209-A',
#   'US5508543-A',
#   'US20060002188-A1',
#   'US5754477-A',
#   'US6353554-B1',
#   'US2005036370-A1; US7166509-B2',
#   'US5317535-A',
#   'US6246606-B1',
#   'US6194228-B1',
#   'US5467306-A',
#   'US7221586-B2',
#   'US5602777-A',
#   'US5828605-A',
#   'US6222768-B1',
#   'US5438544-A',
#   'US7476586-B2',
#   'US6255683-B1',
#   'US6674138-B1',
#   'US20050026375-A1',
#   'US6429063-B1',
#   'US5253196-A',
#   'US6521950-B1',
#   'US7433237-B2',
#   'US6122201-A',
#   'US5627781-A',
#   'US7348237-B2',
#   'US6465306-B1'],
#  ['JP2008052942-A',
#   'JP08138721-A',
#   'US20100062298-A1',
#   'US2009246576-A1; CN101546840-A; JP2009238581-A; JP2009238585-A; JP2009238603-A; JP4544328-B2; JP4544329-B2; JP4600502-B2; JP2011050953-A; CN101546840-B; JP5549509-B2',
#   'JP2005314207-A',
#   'US20090155646-A1',
#   'US20020081471-A1',
#   'JP2004303695-A',
#   'US20040043263-A1',
#   'US2009246576-A1; CN101546840-A; JP2009238581-A; JP2009238585-A; JP2009238603-A; JP4544328-B2; JP4544329-B2; JP4600502-B2; JP2011050953-A; CN101546840-B; JP5549509-B2',
#   'US7622208-B2',
#   'JP2002240449-A',
#   'US20020106540-A1',
#   'US20030054215-A1',
#   'JP2007200867-A',
#   'JP2008084690-A',
#   'JP2005260198-A',
#   'JP2008052943-A',
#   'JP2007026928-A',
#   'CN1992411-A',
#   'US2009246576-A1; CN101546840-A; JP2009238581-A; JP2009238585-A; JP2009238603-A; JP4544328-B2; JP4544329-B2; JP4600502-B2; JP2011050953-A; CN101546840-B; JP5549509-B2',
#   'JP2007179927-A',
#   'US20070151151-A1',
#   'JP2009199985-A',
#   'JP2002160903-A',
#   'JP2008001579-A',
#   'JP2005183089-A',
#   'US20070295734-A1',
#   'US20060127729-A1',
#   'US20090202875-A1'],
#  ['JP60238467-A', 'JP02161711-A', 'JP2000277784-A', 'JP2002263880-A'],
#  ['US20080271781-A1',
#   'US20100224249-A1',
#   'US20100258179-A1',
#   'WO2009145418-A1'],
#  ['US6644703-B1',
#   'US6152444-A',
#   'JP97002628-A',
#   'JP2005154040-A',
#   'WO2003060961-A1',
#   'JP97278181-A',
#   'US7314344-B2',
#   'US3680677-A',
#   'JP96244946-A',
#   'JP88059132-U',
#   'JP99322059-A',
#   'US4804081-A',
#   'US6367609-B2',
#   'US6572321-B1',
#   'JP2004338893-A',
#   'US6523572-B1',
#   'US20060000690-A1',
#   'WO2001014782-A1',
#   'JP97278179-A',
#   'US5964568-A'],
#  ['US20070001222-A1',
#   'US20170125483-A1',
#   'US20150255619-A1',
#   'US9412745-B1',
#   'US20160027950-A1',
#   'US20150333131-A1',
#   'US20050276093-A1',
#   'US20150069320-A1',
#   'US20140065785-A1'],
#  ['US20010041405-A1',
#   'US20090072289-A1',
#   'US20060060916-A1',
#   'US20090121318-A1'],
#  ['CN101736354-A', 'CN104752698-A', 'CN102244240-A'],
#  [],
#  ['US20010001497-A1',
#   'KR2003082820-A',
#   'US20090200604-A1',
#   'KR414735-B1',
#   'US20080203484-A1',
#   'KR2001064961-A',
#   'US5841172-A',
#   'US20070230234-A1',
#   'CN101043050-A',
#   'CN101009243-A',
#   'US7339254-B1',
#   'US20040094805-A1',
#   'US5567968-A',
#   'KR351894-B1',
#   'US6160293-A',
#   'US7071039-B2',
#   'US20050212056-A1',
#   'US20070007596-A1',
#   'US20080224209-A1'],
#  [],
#  [],
#  ['US5712199-A',
#   'US6331208-B1',
#   'US20020108559-A1',
#   'US5462011-A',
#   'US6258698-B1',
#   'US6566277-B1',
#   'US6258666-B1',
#   'US6464762-B1',
#   'US20030060044-A1',
#   'US6682990-B1',
#   'US4627887-A',
#   'US6248948-B1',
#   'US6387780-B1',
#   'US6384313-B2',
#   'US3846082-A',
#   'US5510151-A',
#   'US20020092464-A1',
#   'US5981864-A',
#   'US6653554-B2',
#   'US20040065251-A1',
#   'US5986204-A',
#   'US3998686-A',
#   'US6110347-A',
#   'US6664169-B1',
#   'US7022180-B2',
#   'US6429035-B2',
#   'US4661200-A',
#   'US6756289-B1',
#   'US5486238-A',
#   'US6136091-A',
#   'US5714010-A',
#   'US20040118337-A1',
#   'US4944925-A',
#   'US5770463-A',
#   'US5268061-A',
#   'US6452091-B1',
#   'US6566235-B2',
#   'US6211038-B1',
#   'US6190937-B1',
#   'US20020076882-A1',
#   'US6500731-B1',
#   'US6391743-B1'],
#  ['US5580813-A', 'US5552334-A', 'US5545582-A'],
#  ['WO2010049268-A1',
#   'EP2068369-A1',
#   'US20090301549-A1',
#   'US20110100459-A1',
#   'US20110272020-A1',
#   'US20090151782-A1',
#   'US20100258177-A1',
#   'US20070186971-A1',
#   'US3903427-A',
#   'WO2009071561-A2',
#   'WO2010081505-A2',
#   'US20110253211-A1',
#   'EP528311-A2'],
#  ['US20130175504-A1',
#   'US20090065848-A1',
#   'US20050236678-A1',
#   'US20120025297-A1',
#   'US20100001335-A1'],
#  ['US20050045962-A1',
#   'US20040219780-A1',
#   'US6172393-B1',
#   'US20030119314-A1',
#   'EP1231646-A2',
#   'US5168334-A',
#   'US20050032290-A1',
#   'US5434109-A',
#   'US20050277247-A1',
#   'US20020195416-A1',
#   'US20030107038-A1',
#   'US5939746-A',
#   'US6680509-B1',
#   'US20020110976-A1',
#   'US20020149066-A1',
#   'US20030185071-A1',
#   'US20040197995-A1'],
#  ['US20040051165-A1',
#   'US8236600-B2',
#   'US20080127916-A1',
#   'US6150603-A',
#   'US20050133919-A1',
#   'US5100808-A',
#   'US5330585-A',
#   'US4829269-A',
#   'US4301321-A',
#   'US20060185725-A1',
#   'US5425816-A',
#   'US20060076049-A1',
#   'US20100075175-A1',
#   'US4795501-A',
#   'US20080308891-A1',
#   'US4094704-A',
#   'US20080115823-A1',
#   'US20060107991-A1',
#   'US20060001118-A1',
#   'US8187907-B1',
#   'US20110290312-A1',
#   'US4838952-A',
#   'US4385430-A',
#   'US20090008738-A1',
#   'US20030230761-A1',
#   'US4710254-A',
#   'US20050056312-A1',
#   'US20050081910-A1',
#   'US20100326518-A1',
#   'US20110287578-A1',
#   'US20070138636-A1',
#   'US20090229659-A1',
#   'US6340788-B1',
#   'US5508206-A',
#   'US20100263707-A1',
#   'US20060065297-A1',
#   'US6489635-B1',
#   'US4698455-A',
#   'US20120058591-A1',
#   'US4289920-A',
#   'US20070145507-A1',
#   'US20110259936-A1',
#   'US6281426-B1',
#   'US20070068572-A1',
#   'US4963949-A',
#   'US20070131275-A1',
#   'US20060162767-A1',
#   'US20070131977-A1',
#   'US20050199281-A1',
#   'US20060162768-A1',
#   'US20060185582-A1',
#   'US6255580-B1',
#   'US20080092942-A1',
#   'US20040261838-A1',
#   'US20060144435-A1',
#   'US5391236-A',
#   'US20130243021-A1',
#   'US7095050-B2',
#   'US5420043-A',
#   'US5460659-A',
#   'US20060144438-A1',
#   'US5034068-A',
#   'US20120138130-A1',
#   'US4561541-A',
#   'US20060045431-A1',
#   'US5322572-A',
#   'US20040200523-A1',
#   'US20040166681-A1',
#   'US20070113884-A1',
#   'US20100186822-A1',
#   'US667-H',
#   'US6380601-B1',
#   'US20060202243-A1',
#   'US5091018-A',
#   'US20080121866-A1',
#   'US7326970-B2',
#   'US5080504-A',
#   'US4703553-A',
#   'US5019177-A'],
#  ['JP55134989-A',
#   'JP60043869-A',
#   'JP62061376-A',
#   'JP59220978-A',
#   'JP61164274-A',
#   'JP06043869-A',
#   'US4755475-A',
#   'US4675466-A',
#   'JP05929475-A',
#   'EP113959-A',
#   'JP58101468-A',
#   'US4532371-A',
#   'JP58078473-A',
#   'US4623751-A',
#   'JP60031258-A',
#   'JP05878473-A',
#   'JP59029475-A',
#   'WO1982002284-A',
#   'JP06031258-A'],
#  ['US5981341-A', 'US6103622-A', 'US5796135-A', 'US5908311-A', 'US6004829-A'],
#  ['WO2007103224-A2',
#   'US20080002460-A1',
#   'US7294779-B2',
#   'CN101174595-A',
#   'US20040201806-A1',
#   'CN1030499-A',
#   'US3736425-A',
#   'US5868952-A',
#   'EP732624-A2',
#   'US4751191-A',
#   'DE2835136-A',
#   'CN1489793-A',
#   'US20080099067-A1'],
#  ['CN1871728-A', 'CN2691140-Y', 'US20040229107-A1', 'CN1396308-A'],
#  [],
#  ['KR2004058964-A', 'KR99025905-A', 'KR2001061080-A', 'KR2007058141-A'],
#  ['WO2012020694-A1',
#   'US20140008587-A1',
#   'US9039937-B1',
#   'CN101651155-A',
#   'JP2016193813-A',
#   'CN103077764-A',
#   'WO2017159762-A1',
#   'CN102081986-B',
#   'JP2005243500-A',
#   'US20180033897-A1',
#   'JP2014207262-A',
#   'EP3270421-A1',
#   'KR2014092745-A1',
#   'US20180272425-A1',
#   'WO2012144335-A1',
#   'TW201618123-A',
#   'JP2012033291-A',
#   'EP2903034-A4',
#   'JP2014022194-A',
#   'JP2014164994-A',
#   'CN103578603-A',
#   'TW201527244-A',
#   'WO2016147867-A1',
#   'TW201616514-A',
#   'US20150357490-A1',
#   'WO2017158865-A1',
#   'US20190027620-A1',
#   'US20150191609-A1',
#   'JP2011096747-A1',
#   'US10030156-B2',
#   'WO2014050703-A1',
#   'US20140021417-A1',
#   'US20160141068-A1',
#   'US20150280024-A1',
#   'US20150318419-A1',
#   'US20110095240-A1',
#   'KR2015146105-A1',
#   'US10460851-B2',
#   'JP2014022194-A1'],
#  ['US5622883-A', 'US5552343-A', 'US5180689-A', 'US5453403-A'],
#  [],
#  [],
#  ['US5278087-A',
#   'US5970342-A',
#   'US5879978-A',
#   'US5504022-A',
#   'US5429965-A',
#   'US4947221-A',
#   'US5631482-A',
#   'US5429966-A',
#   'US5963480-A',
#   'US5544103-A',
#   'US4486769-A',
#   'US4757360-A',
#   'US5304505-A',
#   'US5502668-A',
#   'US5888870-A',
#   'US6043124-A',
#   'US5089867-A'],
#  [],
#  ['US9478679-B2', 'CN105047765-A', 'CN106992226-A'],
#  ['US20110141333-A1',
#   'US5691548-A',
#   'US20050133723-A1',
#   'US20060255417-A1',
#   'US5039204-A',
#   'CN101436605-A',
#   'CN1802750-A',
#   'US20090200625-A1',
#   'US20100062559-A1',
#   'US7449359-B2',
#   'US8274586-B2',
#   'US20060138412-A1',
#   'US20110115948-A1',
#   'US20130134535-A1',
#   'US8610227-B2',
#   'US7064405-B2',
#   'KR2010080135-A',
#   'US7968888-B2',
#   'CN101673747-A',
#   'US8530266-B1',
#   'US20060006485-A1',
#   'US20050056901-A1'],
#  ['EP514615-A1',
#   'JP93072153-U',
#   'JP03109772-A',
#   'JP06085268-A',
#   'JP04290270-A',
#   'DE3723150-A',
#   'JP03218643-A',
#   'US5376815-A',
#   'DE3538815-A',
#   'EP433650-A',
#   'JP59115558-A',
#   'US5324971-A',
#   'FR2077332-A7',
#   'FR2077332-A'],
#  ['US4680471-A', 'US4641165-A'],
#  [],
#  [],
#  [],
#  ['US20070132043-A1',
#   'US20100176822-A1',
#   'US20020127495-A1',
#   'US20100291385-A1',
#   'US7302146-B2',
#   'US7947430-B2',
#   'US20080036038-A1',
#   'US6593065-B2',
#   'US20070126079-A1'],
#  ['EP1189243-A2',
#   'US5772934-A',
#   'US3901852-A',
#   'CN103403093-A',
#   'WO2012118882-A1',
#   'WO2013062991-A1',
#   'US4131731-A',
#   'WO1997044843-A1'],
#  ['US4156622-A',
#   'US6136673-A',
#   'US6163673-A',
#   'DE4401782-A1',
#   'US4156822-A',
#   'US4142200-A',
#   'US5013396-A',
#   'EP680099-A3',
#   'US6206996-B1',
#   'US4201798-A',
#   'US2999240-A',
#   'US4152824-A',
#   'US4133698-A',
#   'DE2425908-A',
#   'US6278053-B1',
#   'EP680099-A2',
#   'US4001864-A',
#   'US4377901-A',
#   'JP54098189-A',
#   'US6146483-A',
#   'US6096968-A',
#   'US4478879-A',
#   'DE4217428-A1',
#   'US5543333-A',
#   'GB1470241-A',
#   'US4104091-A'],
#  [],
#  ['CN202502996-U',
#   'CN106856214-A',
#   'CN104091839-A',
#   'CN105489709-A',
#   'CN106098839-A',
#   'CN105470337-A'],
#  ['US3361594-A', 'US3533850-A', 'US3672987-A'],
#  ['WO1997035941-A1',
#   'US3873024-A',
#   'CN101331625-A',
#   'WO1993011209-A1',
#   'US4952293-A',
#   'US20120263938-A1',
#   'GB1099713-A',
#   'US6531142-B1',
#   'US20030203991-A1',
#   'SU1092224-A',
#   'US20040021017-A1',
#   'US4082860-A',
#   'US5792558-A',
#   'US20070113530-A1'],
#  [],
#  ['US20100197068-A1', 'US4694116-A', 'US5728231-A'],
#  [],
#  []]

# %%
PN=data['PN']

#pn的列表
pn_list=[]
for pn in PN:
    pn=pn.split(';')
    pn=list(set([i.strip() for i in pn])) #去除每个元素两端的空格并去重
    pn_list.append(pn)

# %%
data.columns #显示列标签名
# Out:
# Index(['index', 'PN', 'TI', 'AB', 'AU', 'AE', 'CP', 'TM', 'IPC', 'IPClass',
#        'class1', 'class3', 'class4', 'newClass'],
#       dtype='object')

# %%
from tqdm import tqdm #导入了 tqdm 库，用于在循环中显示进度条，提供了对处理进度的可视化

relationList=[]
for i in tqdm(range(len(data))):
#for i in range(10):
    #print(i)
    #生成四种关系所有可能的三元组
    #专利-专利
    if cp_list[i]!=[]:
        for cp in cp_list[i]: 
            relationList.append(data['PN'][i]+'\t'+'patent_patent'+'\t'+cp)
    #专利-权利人
    #权利人-权利人
    if data['AE'][i]!='':
        ae_list=data['AE'][i].split(';')
        ae_list=[i.strip() for i in ae_list]
        ae_list=list(set(ae_list)) #获得不重复的所有权利人的列表

        for ae in ae_list:
            relationList.append(data['PN'][i]+'\t'+'patent_author'+'\t'+ae)
        for a in range(len(ae_list)):
            for b in range(len(ae_list)):
                if a<b:
                    relationList.append(ae_list[a]+'\t'+'author_author'+'\t'+ae_list[b])
    #专利-年份
    relationList.append(data['PN'][i]+'\t'+'patent_year'+'\t'+str(data['TM'][i]).strip())
    #专利-国家
    for pn in pn_list[i]:
        relationList.append(data['PN'][i]+'\t'+'patent_nation'+'\t'+pn[:2]) #表示获取 pn 中的前两个字符，即国家代码
    

#然后存成txt文件
with open(r'/root/autodl-tmp/transX/data/train_test.txt','w') as fp:
    for i in range(len(relationList)):
        fp.write(relationList[i])
        fp.write('\n')
# Out:
# 100%|██████████| 512/512 [00:00<00:00, 6855.12it/s]

# %%
len(data['PN'])
# Out:
# 512

# %%
len(relationList)
# Out:
# 9911
